// %%
%useLatestDescriptors
%use ggdsl-echarts(0.3.0-rc-1)
// Out:
// The problem is found in one of the loaded libraries: check library resources definitions
// java.lang.Exception: No resource fallback found! Related exceptions: [java.io.IOException: Resource js/echarts.min.js not found on classpath]
// org.jetbrains.kotlinx.jupyter.exceptions.ReplLibraryException: The problem is found in one of the loaded libraries: check library resources definitions
// 	at org.jetbrains.kotlinx.jupyter.exceptions.ReplLibraryExceptionKt.rethrowAsLibraryException(ReplLibraryException.kt:30)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.addLibraries(CellExecutorImpl.kt:169)
// 	at org.jetbrains.kotlinx.jupyter.libraries.LibrariesScanner.addLibrariesFromClassLoader(LibrariesScanner.kt:59)
// 	at org.jetbrains.kotlinx.jupyter.libraries.LibrariesScanner.addLibrariesFromClassLoader$default(LibrariesScanner.kt:49)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$3.invoke(CellExecutorImpl.kt:99)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$3.invoke(CellExecutorImpl.kt:98)
// 	at org.jetbrains.kotlinx.jupyter.config.LoggingKt.catchAll(logging.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.config.LoggingKt.catchAll$default(logging.kt:40)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute(CellExecutorImpl.kt:98)
// 	at org.jetbrains.kotlinx.jupyter.repl.CellExecutor$DefaultImpls.execute$default(CellExecutor.kt:15)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.execute(CellExecutorImpl.kt:211)
// 	at org.jetbrains.kotlinx.jupyter.api.libraries.CodeExecution$toExecutionCallback$1.invoke(CodeExecution.kt:20)
// 	at org.jetbrains.kotlinx.jupyter.api.libraries.CodeExecution$toExecutionCallback$1.invoke(CodeExecution.kt:16)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.execute(CellExecutorImpl.kt:233)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.runChild(CellExecutorImpl.kt:142)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.runChild(CellExecutorImpl.kt:138)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.access$runChild(CellExecutorImpl.kt:128)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext$addLibraries$1.invoke(CellExecutorImpl.kt:152)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext$addLibraries$1.invoke(CellExecutorImpl.kt:151)
// 	at org.jetbrains.kotlinx.jupyter.exceptions.ReplLibraryExceptionKt.rethrowAsLibraryException(ReplLibraryException.kt:28)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.addLibraries(CellExecutorImpl.kt:151)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute(CellExecutorImpl.kt:60)
// 	at org.jetbrains.kotlinx.jupyter.repl.CellExecutor$DefaultImpls.execute$default(CellExecutor.kt:15)
// 	at org.jetbrains.kotlinx.jupyter.ReplForJupyterImpl$evalEx$1.invoke(repl.kt:460)
// 	at org.jetbrains.kotlinx.jupyter.ReplForJupyterImpl$evalEx$1.invoke(repl.kt:449)
// 	at org.jetbrains.kotlinx.jupyter.ReplForJupyterImpl.withEvalContext(repl.kt:413)
// 	at org.jetbrains.kotlinx.jupyter.ReplForJupyterImpl.evalEx(repl.kt:449)
// 	at org.jetbrains.kotlinx.jupyter.ReplForJupyterImpl.eval(repl.kt:501)
// 	at org.jetbrains.kotlinx.jupyter.messaging.ProtocolKt$shellMessagesHandler$2$res$1.invoke(protocol.kt:318)
// 	at org.jetbrains.kotlinx.jupyter.messaging.ProtocolKt$shellMessagesHandler$2$res$1.invoke(protocol.kt:317)
// 	at org.jetbrains.kotlinx.jupyter.JupyterExecutorImpl$runExecution$execThread$1.invoke(execution.kt:33)
// 	at org.jetbrains.kotlinx.jupyter.JupyterExecutorImpl$runExecution$execThread$1.invoke(execution.kt:31)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)
// Caused by: java.lang.Exception: No resource fallback found! Related exceptions: [java.io.IOException: Resource js/echarts.min.js not found on classpath]
// 	at org.jetbrains.kotlinx.jupyter.libraries.JsLibraryResourcesProcessor.loadBunch(JsLibraryResourcesProcessor.kt:49)
// 	at org.jetbrains.kotlinx.jupyter.libraries.JsLibraryResourcesProcessor.loadResourceAsText(JsLibraryResourcesProcessor.kt:53)
// 	at org.jetbrains.kotlinx.jupyter.libraries.JsLibraryResourcesProcessor.wrapLibrary(JsLibraryResourcesProcessor.kt:63)
// 	at org.jetbrains.kotlinx.jupyter.libraries.LibraryResourcesProcessorImpl.wrapLibrary(LibraryResourcesProcessorImpl.kt:16)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext$addLibraries$11.invoke(CellExecutorImpl.kt:171)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext$addLibraries$11.invoke(CellExecutorImpl.kt:169)
// 	at org.jetbrains.kotlinx.jupyter.exceptions.ReplLibraryExceptionKt.rethrowAsLibraryException(ReplLibraryException.kt:28)
// 	... 32 more

// %%
val simpleDataset = mapOf(
    "time" to listOf(0, 1, 2, 4, 5, 7, 8, 9),
    "temperature" to listOf(12.0, 14.2, 15.1, 15.9, 17.9, 15.6, 14.2, 24.3),
    "humidity" to listOf(0.5, 0.32, 0.11, 0.89, 0.68, 0.57, 0.56, 0.5)
)

// %%
import org.jetbrains.kotlinx.ggdsl.dsl.column.*

// %%
plot(simpleDataset) {
    x("time"<Int>())

    y("temperature"<Double>().scaled(
        continuousPos(0.0 to 25.5)
    ))

    bars {
        color("humidity"<Double>().scaled(continuous(
            rangeLimits = Color.YELLOW to Color.RED
        )))
        borderLine.width(0.0)
    }

    line {
        width(3.0)
        color(Color.hex("#6e5596"))
        type(LineType.DOTDASH)
    }

    layout {
        title = "Simple plot with lets-plot"
        caption = "See `examples` section for more\n complicated and interesting examples!"
    }

}
// Out:
//    <div id="dLqfWz"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"Simple plot with lets-plot"
// },
// "mapping":{
// },
// "data":{
// "temperature":[12.0,14.2,15.1,15.9,17.9,15.6,14.2,24.3],
// "humidity":[0.5,0.32,0.11,0.89,0.68,0.57,0.56,0.5],
// "time":[0.0,1.0,2.0,4.0,5.0,7.0,8.0,9.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"y",
// "limits":[0.0,25.5]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_gradient",
// "high":"#ee6666",
// "low":"#fac858"
// },{
// "aesthetic":"x"
// },{
// "aesthetic":"y",
// "limits":[0.0,25.5]
// }],
// "layers":[{
// "mapping":{
// "x":"time",
// "y":"temperature",
// "fill":"humidity"
// },
// "stat":"identity",
// "size":0.0,
// "position":"identity",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// "x":"time",
// "y":"temperature"
// },
// "stat":"identity",
// "size":3.0,
// "color":"#6e5596",
// "linetype":"dotdash",
// "position":"identity",
// "geom":"line",
// "data":{
// }
// }],
// "caption":{
// "text":"See `examples` section for more\n complicated and interesting examples!"
// }
// };
//            var plotContainer = document.getElementById("dLqfWz");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
