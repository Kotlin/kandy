// %% [markdown]
// # Pie chart

// %%
%useLatestDescriptors
%use kandy
%use dataframe

// %%
val dataset = dataFrameOf(
    "name" to listOf('a', 'b', 'c', 'd', 'b'),
    "value" to listOf(40, 90, 10, 50, 20)
)

// %% [markdown]
// ## Basic Pie Chart

// %%
dataset.plot {
    pie {
        slice(value)
        fillColor(name)
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;FwRLdL&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;name&quot;:[&quot;a&quot;,&quot;b&quot;,&quot;c&quot;,&quot;d&quot;,&quot;b&quot;],
// &quot;value&quot;:[40.0,90.0,10.0,50.0,20.0]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;discrete&quot;:true
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;slice&quot;:&quot;value&quot;,
// &quot;fill&quot;:&quot;name&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;data&quot;:{
// }
// }]
// };
//        var plotContainer = document.getElementById(&quot;FwRLdL&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=a337d134-929c-4475-995c-a5ed9984a71a width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pXiacKt .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pXiacKt .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pXiacKt .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pXiacKt .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pXiacKt .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pXiacKt .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pXiacKt .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dcN52JH .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pXiacKt .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pXiacKt .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dcN52JH .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pXiacKt .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pXiacKt .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dcN52JH .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dcN52JH .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dcN52JH .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pXiacKt">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 6.5 ) ">
//       <g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="46.82455058123537" y1="0.0" x2="46.82455058123537" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="140.47365174370617" y1="0.0" x2="140.47365174370617" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="234.12275290617694" y1="0.0" x2="234.12275290617694" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="327.7718540686477" y1="0.0" x2="327.7718540686477" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="421.4209552311185" y1="0.0" x2="421.4209552311185" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="306.9" x2="468.2455058123539" y2="306.9" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="238.7" x2="468.2455058123539" y2="238.7" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="170.5" x2="468.2455058123539" y2="170.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="102.3" x2="468.2455058123539" y2="102.3" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="34.099999999999994" x2="468.2455058123539" y2="34.099999999999994" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#ctKjsaV)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (468.2455058123539, 341.0)]">
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <g>
//               <g>
//                 <path d="M234.12275290617694 170.5 L187.57906547396675 152.23294878168025 A50.0 50.0 0.0 0 1 234.12275290617694 120.5 L234.12275290617694 170.5 A0.0 0.0 0.0 0 0 234.12275290617694 170.5 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M234.12275290617694 170.5 L234.12275290617694 120.5 A50.0 50.0 0.0 0 1 255.81693986205485 215.54844339512096 L234.12275290617694 170.5 A0.0 0.0 0.0 0 0 234.12275290617694 170.5 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M234.12275290617694 170.5 L255.81693986205485 215.54844339512096 A50.0 50.0 0.0 0 1 241.57486621498566 219.94154131125643 L234.12275290617694 170.5 A0.0 0.0 0.0 0 0 234.12275290617694 170.5 " fill="rgb(77,175,74)" stroke-width="1.0" fill-opacity="1.0">

// %% [markdown]
// #### Improve appearance
//
// * configure stroke
// * make the pie bigger
// * add hole to draw donut-like chart
// * use blank style
// * use better colors

// %%
dataset.plot {
    pie {
        slice(value)
        fillColor(name) {
            scale = categoricalColorBrewer(BrewerPalette.Qualitative.Set1)
        }
        size = 20.0
        stroke = 1.0
        strokeColor = Color.WHITE
        hole = 0.5
    }
    layout {
        style(Style.Void)
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;OCCvAT&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;name&quot;:[&quot;a&quot;,&quot;b&quot;,&quot;c&quot;,&quot;d&quot;,&quot;b&quot;],
// &quot;value&quot;:[40.0,90.0,10.0,50.0,20.0]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_brewer&quot;,
// &quot;palette&quot;:&quot;Set1&quot;
// }],
// &quot;layers&quot;:[{
// &quot;hole&quot;:0.5,
// &quot;mapping&quot;:{
// &quot;slice&quot;:&quot;value&quot;,
// &quot;fill&quot;:&quot;name&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:20.0,
// &quot;color&quot;:&quot;#ffffff&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;stroke&quot;:1.0,
// &quot;data&quot;:{
// }
// }],
// &quot;theme&quot;:{
// &quot;name&quot;:&quot;classic&quot;,
// &quot;axis&quot;:{
// &quot;blank&quot;:true
// },
// &quot;line&quot;:{
// &quot;blank&quot;:true
// },
// &quot;axis_ontop&quot;:false,
// &quot;axis_ontop_y&quot;:false,
// &quot;axis_ontop_x&quot;:false
// }
// };
//        var plotContainer = document.getElementById(&quot;OCCvAT&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=ef88994e-6ec0-42e9-b3c2-e06d1b93244c width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pEWfzTR .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEWfzTR .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEWfzTR .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEWfzTR .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEWfzTR .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEWfzTR .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEWfzTR .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dYlog3z .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEWfzTR .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEWfzTR .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dYlog3z .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEWfzTR .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pEWfzTR .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dYlog3z .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dYlog3z .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dYlog3z .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pEWfzTR">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(6.5 6.5 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="translate(0.0 387.0 ) ">
//         </g>
//         <g transform="">
//         </g>
//       </g>
//       <g clip-path="url(#cBYKzmS)" clip-bounds-jfx="[rect (0.0, 0.0), (526.2608124881035, 387.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M216.58671881184154 175.23294878168025 L170.04303137963134 156.96589756336047 A100.0 100.0 0.0 0 1 263.13040624405176 93.5 L263.13040624405176 143.5 A50.0 50.0 0.0 0 0 216.58671881184154 175.23294878168025 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M263.13040624405176 143.5 L263.13040624405176 93.5 A100.0 100.0 0.0 0 1 306.5187801558076 283.5968867902419 L284.82459319992967 238.54844339512096 A50.0 50.0 0.0 0 0 263.13040624405176 143.5 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M284.82459319992967 238.54844339512096 L306.5187801558076 283.5968867902419 A100.0 100.0 0.0 0 1 278.0346328616692 292.38308262251286 L270.5825195528605 242.94154131125643 A50.0 50.0 0.0 0 0 284.82459319992967 238.54844339512096 " fill="rgb(77,175,74)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M270.5825195528605 242.94154131125643 L278.0346328616692 292.38308262251286 A100.0 100.0 0.0 0 1 165.6376150258694 215.75209339563145 L214.3840106349606 204.62604669781572 A50.0 50.0 0.0 0 0 270.5825195528605 242.94154131125643 " fill="rgb(152,78,163)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M214.3840106349606 204.62604669781572 L165.6376150258694 215.75209339563145 A100.0 100.0 0.0 0 1 170.04303137963132 156.96589756336056 L216.58671881184154 175.23294878168028 A50.0 50.0 0.0 0 0 214.3840106349606 204.62604669781572 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M170.04303137963134 156.96589756336047 A100.0 100.0 0.0 0 1 263.13040624405176 93.5 M263.13040624405176 143.5 A50.0 50.0 0.0 0 0 216.58671881184154 175.23294878168025 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M263.13040624405176 93.5 A100.0 100.0 0.0 0 1 306.5187801558076 283.5968867902419 M284.82459319992967 238.54844339512096 A50.0 50.0 0.0 0 0 263.1304062

// %% [markdown]
// ## Explode

// %%
val length = dataFrameOf(
    "name" to listOf(
        "20-50 km",
        "50-75 km",
        "10-20 km",
        "75-100 km",
        "3-5 km",
        "7-10 km",
        "5-7 km",
        ">100 km",
        "2-3 km"
    ),
    "count" to listOf(1109, 696, 353, 192, 168, 86, 74, 65, 53),
    "explode" to listOf(.0, .0, .0, .1, .1, .2, .3, .4, .6)
)

// %%
length.plot {
    pie {
        fillColor(name) {
            scale = continuous(Color.named("dark_blue"), Color.LIGHT_GREEN)
        }
        slice(count)
        explode(explode)
        stroke = 1.0
        strokeColor = Color.BLACK
        size = 20.0
    }
    layout.style(Style.Void)
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;IhHrBA&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;explode&quot;:[0.0,0.0,0.0,0.1,0.1,0.2,0.3,0.4,0.6],
// &quot;name&quot;:[&quot;20-50 km&quot;,&quot;50-75 km&quot;,&quot;10-20 km&quot;,&quot;75-100 km&quot;,&quot;3-5 km&quot;,&quot;7-10 km&quot;,&quot;5-7 km&quot;,&quot;>100 km&quot;,&quot;2-3 km&quot;],
// &quot;count&quot;:[1109.0,696.0,353.0,192.0,168.0,86.0,74.0,65.0,53.0]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_gradient&quot;,
// &quot;high&quot;:&quot;#91cc75&quot;,
// &quot;low&quot;:&quot;dark_blue&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;fill&quot;:&quot;name&quot;,
// &quot;slice&quot;:&quot;count&quot;,
// &quot;explode&quot;:&quot;explode&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;color&quot;:&quot;#000000&quot;,
// &quot;size&quot;:20.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;stroke&quot;:1.0,
// &quot;data&quot;:{
// }
// }],
// &quot;theme&quot;:{
// &quot;name&quot;:&quot;classic&quot;,
// &quot;axis&quot;:{
// &quot;blank&quot;:true
// },
// &quot;line&quot;:{
// &quot;blank&quot;:true
// },
// &quot;axis_ontop&quot;:false,
// &quot;axis_ontop_y&quot;:false,
// &quot;axis_ontop_x&quot;:false
// }
// };
//        var plotContainer = document.getElementById(&quot;IhHrBA&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=2d82dc77-5149-4b60-8650-ff194c2b2e65 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pwSn5zP .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pwSn5zP .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pwSn5zP .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pwSn5zP .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pwSn5zP .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pwSn5zP .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pwSn5zP .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dcA4zMs .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pwSn5zP .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pwSn5zP .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dcA4zMs .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pwSn5zP .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pwSn5zP .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dcA4zMs .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dcA4zMs .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dcA4zMs .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pwSn5zP">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(6.5 6.5 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="translate(0.0 387.0 ) ">
//         </g>
//         <g transform="">
//         </g>
//       </g>
//       <g clip-path="url(#cIrFTPu)" clip-bounds-jfx="[rect (0.0, 0.0), (467.70648929740446, 387.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M233.85324464870223 193.5 L173.37901441115528 273.1421212498522 A100.0 100.0 0.0 0 1 233.85324464870223 93.5 L233.85324464870223 193.5 A0.0 0.0 0.0 0 0 233.85324464870223 193.5 " fill="rgb(0,0,128)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M233.85324464870223 193.5 L233.85324464870223 93.5 A100.0 100.0 0.0 0 1 333.85097218857663 192.82584359304573 L233.85324464870223 193.5 A0.0 0.0 0.0 0 0 233.85324464870223 193.5 " fill="rgb(50,31,129)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M233.85324464870223 193.5 L333.85097218857663 192.82584359304573 A100.0 100.0 0.0 0 1 304.4844274522588 264.2900841627595 L233.85324464870223 193.5 A0.0 0.0 0.0 0 0 233.85324464870223 193.5 " fill="rgb(73,55,129)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M239.237291874738 201.926863916536 L309.86847467829455 272.71694807929555 A100.0 100.0 0.0 0 1 273.7910124987032 295.7673689825306 L239.237291874738 201.926863916536 A0.0 0.0 0.0 0 0 239.237291874738 201.926863916536 " fill="rgb(91,79,129)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M235.48635646893922 203.3657460834243 L270.0400770929044 297.2062511494189 A100.0 100.0 0.0 0 1 233.01468265276733 303.335195559484 L235.48635646893922 203.3657460834243 A0.0 0.0 0.0 0 0 235.48635646893922 203.3657460834243 " fill="rgb(105,103,128)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M231.43221527410768 213.35292464014685 L228.9605414579358 313.32237411620656 A100.0 100.0 0.0 0 1 209.80653707064857 310.98657684183615 L231.43221527410768 213.35292464014685 A0.0 0.0 0.0 0 0 231.43221527410768 213.35292464014685 " fill="rgb(117,128,127)" stroke-width="1.0" fill-opacity="1.0">

// %%
val calories = dataFrameOf(
    "slice" to listOf(35, 25, 25, 15),
    "label" to listOf("Apples", "Bananas", "Cherries", "Dates"),
    "explode" to listOf(.1, .0, .0, .0)
)

// %%
plotGrid(
    listOf(
        calories.plot {
            pie {
                slice(slice)
                explode(explode)
                fillColor(label) {
                    scale = categoricalColorBrewer(BrewerPalette.Qualitative.Set1)
                }
                size = 15.0
            }
            layout {
                style(Style.Void)
            }
        },
        calories.plot {
            pie {
                slice(slice)
                explode(explode)
                fillColor(label) {
                    scale = categoricalColorBrewer(BrewerPalette.Qualitative.Set1)
                }
                size = 15.0
                hole = 0.8
            }
            layout {
                style(Style.Void)
            }
        }
    )
)
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;WVsq8e&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;layout&quot;:{
// &quot;name&quot;:&quot;grid&quot;,
// &quot;ncol&quot;:2,
// &quot;nrow&quot;:1,
// &quot;fit&quot;:true,
// &quot;align&quot;:false
// },
// &quot;figures&quot;:[{
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;slice&quot;:[35.0,25.0,25.0,15.0],
// &quot;explode&quot;:[0.1,0.0,0.0,0.0],
// &quot;label&quot;:[&quot;Apples&quot;,&quot;Bananas&quot;,&quot;Cherries&quot;,&quot;Dates&quot;]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_brewer&quot;,
// &quot;palette&quot;:&quot;Set1&quot;
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;slice&quot;:&quot;slice&quot;,
// &quot;explode&quot;:&quot;explode&quot;,
// &quot;fill&quot;:&quot;label&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:15.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;theme&quot;:{
// &quot;name&quot;:&quot;classic&quot;,
// &quot;axis&quot;:{
// &quot;blank&quot;:true
// },
// &quot;line&quot;:{
// &quot;blank&quot;:true
// },
// &quot;axis_ontop&quot;:false,
// &quot;axis_ontop_y&quot;:false,
// &quot;axis_ontop_x&quot;:false
// }
// },{
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;slice&quot;:[35.0,25.0,25.0,15.0],
// &quot;explode&quot;:[0.1,0.0,0.0,0.0],
// &quot;label&quot;:[&quot;Apples&quot;,&quot;Bananas&quot;,&quot;Cherries&quot;,&quot;Dates&quot;]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_brewer&quot;,
// &quot;palette&quot;:&quot;Set1&quot;
// }],
// &quot;layers&quot;:[{
// &quot;hole&quot;:0.8,
// &quot;mapping&quot;:{
// &quot;slice&quot;:&quot;slice&quot;,
// &quot;explode&quot;:&quot;explode&quot;,
// &quot;fill&quot;:&quot;label&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:15.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;theme&quot;:{
// &quot;name&quot;:&quot;classic&quot;,
// &quot;axis&quot;:{
// &quot;blank&quot;:true
// },
// &quot;line&quot;:{
// &quot;blank&quot;:true
// },
// &quot;axis_ontop&quot;:false,
// &quot;axis_ontop_y&quot;:false,
// &quot;axis_ontop_x&quot;:false
// }
// }],
// &quot;kind&quot;:&quot;subplots&quot;
// };
//        var plotContainer = document.getElementById(&quot;WVsq8e&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=0ad70b9a-33cc-44fb-ac56-5f6ed0de6f80 width="100%" height="100%" style="max-width: 900.0px; max-height: 400.0px;" viewBox="0 0 900.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <g id="pPPTqGE">
//     <rect x="0.0" y="0.0" height="400.0" width="900.0" fill="rgb(255,255,255)" fill-opacity="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0">
//     </rect>
//   </g>
//   <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="448.0" height="400.0" x="0.0" y="0.0">
//     <style type="text/css">
//     .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pDPwErb .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDPwErb .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDPwErb .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDPwErb .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDPwErb .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDPwErb .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDPwErb .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d7mKX0S .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDPwErb .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDPwErb .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d7mKX0S .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDPwErb .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDPwErb .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d7mKX0S .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d7mKX0S .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #d7mKX0S .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//     </style>
//     <g id="pDPwErb">
//       <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L448.0 400.0 L448.0 0.0 Z">
//       </path>
//       <g transform="translate(6.5 6.5 ) ">
//         <g>
//           <g transform="">
//             <g>
//             </g>
//           </g>
//           <g transform="">
//             <g>
//             </g>
//           </g>
//           <g transform="translate(0.0 387.0 ) ">
//           </g>
//           <g transform="">
//           </g>
//         </g>
//         <g clip-path="url(#cAGr2Pa)" clip-bounds-jfx="[rect (0.0, 0.0), (330.2785026964189, 387.0)]">
//           <g transform="">
//             <g>
//               <g>
//                 <g>
//                   <path d="M158.4567024167967 190.09507125195339 L97.78042783867564 234.17896517388886 A75.0 75.0 0.0 0 1 158.4567024167967 115.09507125195339 L158.4567024167967 190.09507125195339 A0.0 0.0 0.0 0 0 158.4567024167967 190.09507125195339 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                   </path>
//                 </g>
//                 <g>
//                   <path d="M165.13925134820946 193.5 L165.13925134820946 118.5 A75.0 75.0 0.0 0 1 240.13925134820946 193.5 L165.13925134820946 193.5 A0.0 0.0 0.0 0 0 165.13925134820946 193.5 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                   </path
