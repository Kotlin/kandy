// %% [markdown]
// # Pie chart

// %%
%useLatestDescriptors
%use kandy
%use dataframe

// %%
val dataset = dataFrameOf(
    "name" to listOf('a', 'b', 'c', 'd', 'b'),
    "value" to listOf(40, 90, 10, 50, 20)
)

// %% [markdown]
// ## Basic Pie Chart

// %%
dataset.plot {
    pie {
        slice(value)
        fillColor(name)
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;25WzsI&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;name&quot;:[&quot;a&quot;,&quot;b&quot;,&quot;c&quot;,&quot;d&quot;,&quot;b&quot;],
// &quot;value&quot;:[40.0,90.0,10.0,50.0,20.0]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;discrete&quot;:true
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;slice&quot;:&quot;value&quot;,
// &quot;fill&quot;:&quot;name&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;data&quot;:{
// }
// }]
// };
//        var plotContainer = document.getElementById(&quot;25WzsI&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" id=b0a1ce65-07db-4e53-a98d-6796e95fded4 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #p9BEjAE .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9BEjAE .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9BEjAE .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9BEjAE .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9BEjAE .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9BEjAE .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9BEjAE .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dxjYyB8 .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9BEjAE .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9BEjAE .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dxjYyB8 .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9BEjAE .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9BEjAE .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dxjYyB8 .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dxjYyB8 .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dxjYyB8 .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="p9BEjAE">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(23.0 10.0 ) ">
//       <g transform="translate(35.01530667574961 0.0 ) ">
//         <line x1="47.12455058123538" y1="344.0" x2="47.12455058123538" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//         </line>
//         <line x1="141.37365174370615" y1="344.0" x2="141.37365174370615" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//         </line>
//         <line x1="235.62275290617694" y1="344.0" x2="235.62275290617694" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//         </line>
//         <line x1="329.87185406864774" y1="344.0" x2="329.87185406864774" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//         </line>
//         <line x1="424.1209552311185" y1="344.0" x2="424.1209552311185" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//         </line>
//       </g>
//       <g transform="translate(35.01530667574961 344.0 ) ">
//         <g transform="translate(47.12455058123538 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//               <tspan>-0.4</tspan>
//             </text>
//           </g>
//         </g>
//         <g transform="translate(141.37365174370615 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//               <tspan>-0.2</tspan>
//             </text>
//           </g>
//         </g>
//         <g transform="translate(235.62275290617694 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//               <tspan>0.0</tspan>
//             </text>
//           </g>
//         </g>
//         <g transform="translate(329.87185406864774 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//               <tspan>0.2</tspan>
//             </text>
//           </g>
//         </g>
//         <g transform="translate(424.1209552311185 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//               <tspan>0.4</tspan>
//             </text>
//           </g>
//         </g>
//         <line x1="0.0" y1="0.0" x2="471.2455058123539" y2="0.0" stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0">
//         </line>
//       </g>
//       <g transform="translate(35.01530667574961 0.0 ) ">
//         <line x1="0.0" y1="309.6" x2="471.2455058123539" y2="309.6" stroke="rgb(233,233,233)" stroke-opaci

// %% [markdown]
// #### Improve appearance
//
// * configure stroke
// * make the pie bigger
// * add hole to draw donut-like chart
// * use blank style
// * use better colors

// %%
dataset.plot {
    pie {
        slice(value)
        fillColor(name) {
            scale = categoricalColorBrewer(BrewerPalette.Qualitative.Set1)
        }
        size = 20.0
        stroke = 1.0
        strokeColor = Color.WHITE
        hole = 0.5
    }
    layout {
        style(Style.Void)
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;qPhjcX&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;name&quot;:[&quot;a&quot;,&quot;b&quot;,&quot;c&quot;,&quot;d&quot;,&quot;b&quot;],
// &quot;value&quot;:[40.0,90.0,10.0,50.0,20.0]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_brewer&quot;,
// &quot;palette&quot;:&quot;Set1&quot;
// }],
// &quot;layers&quot;:[{
// &quot;hole&quot;:0.5,
// &quot;mapping&quot;:{
// &quot;slice&quot;:&quot;value&quot;,
// &quot;fill&quot;:&quot;name&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:20.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;stroke_color&quot;:&quot;#ffffff&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;stroke&quot;:1.0,
// &quot;data&quot;:{
// }
// }],
// &quot;theme&quot;:{
// &quot;name&quot;:&quot;classic&quot;,
// &quot;axis&quot;:{
// &quot;blank&quot;:true
// },
// &quot;line&quot;:{
// &quot;blank&quot;:true
// },
// &quot;axis_ontop&quot;:false,
// &quot;axis_ontop_y&quot;:false,
// &quot;axis_ontop_x&quot;:false
// }
// };
//        var plotContainer = document.getElementById(&quot;qPhjcX&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" id=bb642e68-1041-47b7-98a3-463534433c15 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pvyrYT2 .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvyrYT2 .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvyrYT2 .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvyrYT2 .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvyrYT2 .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvyrYT2 .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvyrYT2 .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dx6Gucp .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvyrYT2 .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvyrYT2 .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dx6Gucp .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvyrYT2 .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pvyrYT2 .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dx6Gucp .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dx6Gucp .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dx6Gucp .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pvyrYT2">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(10.0 10.0 ) ">
//       <g transform="">
//       </g>
//       <g transform="translate(0.0 380.0 ) ">
//       </g>
//       <g transform="">
//       </g>
//       <g transform="">
//       </g>
//       <g transform="" clip-path="url(#cAX9Ohd)" clip-bounds-jfx="[rect (0.0, 0.0), (519.2608124881035, 380.0)]">
//         <defs>
//           <clipPath id="cAX9Ohd">
//             <rect x="0.0" y="0.0" width="519.2608124881035" height="380.0">
//             </rect>
//           </clipPath>
//         </defs>
//         <g>
//           <path d="M213.08671881184154 171.73294878168025 L166.54303137963134 153.46589756336047 A100.0 100.0 0.0 0 1 259.63040624405176 90.0 L259.63040624405176 140.0 A50.0 50.0 0.0 0 0 213.08671881184154 171.73294878168025 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M259.63040624405176 140.0 L259.63040624405176 90.0 A100.0 100.0 0.0 0 1 303.0187801558076 280.0968867902419 L281.32459319992967 235.04844339512096 A50.0 50.0 0.0 0 0 259.63040624405176 140.0 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M281.32459319992967 235.04844339512096 L303.0187801558076 280.0968867902419 A100.0 100.0 0.0 0 1 274.5346328616692 288.88308262251286 L267.0825195528605 239.44154131125643 A50.0 50.0 0.0 0 0 281.32459319992967 235.04844339512096 " fill="rgb(77,175,74)" stroke-width="1.0" fill-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M267.0825195528605 239.44154131125643 L274.5346328616692 288.88308262251286 A100.0 100.0 0.0 0 1 162.1376150258694 212.25209339563145 L210.8840106349606 201.12604669781572 A50.0 50.0 0.0 0 0 267.0825195528605 239.44154131125643 " fill="rgb(152,78,163)" stroke-width="1.0" fill-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M210.8840106349606 201.12604669781572 L162.1376150258694 212.25209339563145 A100.0 100.0 0.0 0 1 166.54303137963132 153.46589756336056 L213.08671881184154 171.73294878168028 A50.0 50.0 0.0 0 0 210.8840106349606 201.12604669781572 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M166.54303137963134 153.46589756336047 A100.0 100.0 0.0 0 1 259.63040624405176 90.0 M259.63040624405176 140.0 A50.0 50.0 0.0 0 0 213.08671881184154 171.73294878168025 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M259.63040624405176 90.0 A100.0 100.0 0.0 0 1 303.0187801558076 280.0968867902419 M281.32459319992967 235.04844339512096 A50.0 50.0 0.0 0 0 259.63040624405176 140.0 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>

// %% [markdown]
// ## Explode

// %%
val length = dataFrameOf(
    "name" to listOf(
        "20-50 km",
        "50-75 km",
        "10-20 km",
        "75-100 km",
        "3-5 km",
        "7-10 km",
        "5-7 km",
        ">100 km",
        "2-3 km"
    ),
    "count" to listOf(1109, 696, 353, 192, 168, 86, 74, 65, 53),
    "explode" to listOf(.0, .0, .0, .1, .1, .2, .3, .4, .6)
)

// %%
length.plot {
    pie {
        fillColor(name) {
            scale = continuous(Color.named("dark_blue"), Color.LIGHT_GREEN)
        }
        slice(count)
        explode(explode)
        stroke = 1.0
        strokeColor = Color.BLACK
        size = 20.0
    }
    layout.style(Style.Void)
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;czCyyy&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;explode&quot;:[0.0,0.0,0.0,0.1,0.1,0.2,0.3,0.4,0.6],
// &quot;name&quot;:[&quot;20-50 km&quot;,&quot;50-75 km&quot;,&quot;10-20 km&quot;,&quot;75-100 km&quot;,&quot;3-5 km&quot;,&quot;7-10 km&quot;,&quot;5-7 km&quot;,&quot;>100 km&quot;,&quot;2-3 km&quot;],
// &quot;count&quot;:[1109.0,696.0,353.0,192.0,168.0,86.0,74.0,65.0,53.0]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_gradient&quot;,
// &quot;high&quot;:&quot;#91cc75&quot;,
// &quot;low&quot;:&quot;dark_blue&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;fill&quot;:&quot;name&quot;,
// &quot;slice&quot;:&quot;count&quot;,
// &quot;explode&quot;:&quot;explode&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:20.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;stroke_color&quot;:&quot;#000000&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;stroke&quot;:1.0,
// &quot;data&quot;:{
// }
// }],
// &quot;theme&quot;:{
// &quot;name&quot;:&quot;classic&quot;,
// &quot;axis&quot;:{
// &quot;blank&quot;:true
// },
// &quot;line&quot;:{
// &quot;blank&quot;:true
// },
// &quot;axis_ontop&quot;:false,
// &quot;axis_ontop_y&quot;:false,
// &quot;axis_ontop_x&quot;:false
// }
// };
//        var plotContainer = document.getElementById(&quot;czCyyy&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" id=17244cd7-9cbe-4059-a327-0653163e31e8 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #peAwrh2 .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #peAwrh2 .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #peAwrh2 .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #peAwrh2 .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #peAwrh2 .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #peAwrh2 .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #peAwrh2 .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dOYxjS0 .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #peAwrh2 .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #peAwrh2 .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dOYxjS0 .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #peAwrh2 .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #peAwrh2 .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dOYxjS0 .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dOYxjS0 .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dOYxjS0 .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="peAwrh2">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(10.0 10.0 ) ">
//       <g transform="">
//       </g>
//       <g transform="translate(0.0 380.0 ) ">
//       </g>
//       <g transform="">
//       </g>
//       <g transform="">
//       </g>
//       <g transform="" clip-path="url(#cWllzfJ)" clip-bounds-jfx="[rect (0.0, 0.0), (460.70648929740446, 380.0)]">
//         <defs>
//           <clipPath id="cWllzfJ">
//             <rect x="0.0" y="0.0" width="460.70648929740446" height="380.0">
//             </rect>
//           </clipPath>
//         </defs>
//         <g>
//           <path d="M230.35324464870223 190.0 L169.87901441115528 269.6421212498522 A100.0 100.0 0.0 0 1 230.35324464870223 90.0 L230.35324464870223 190.0 A0.0 0.0 0.0 0 0 230.35324464870223 190.0 " fill="rgb(0,0,128)" stroke-width="1.0" fill-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M230.35324464870223 190.0 L230.35324464870223 90.0 A100.0 100.0 0.0 0 1 330.35097218857663 189.32584359304573 L230.35324464870223 190.0 A0.0 0.0 0.0 0 0 230.35324464870223 190.0 " fill="rgb(50,31,129)" stroke-width="1.0" fill-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M230.35324464870223 190.0 L330.35097218857663 189.32584359304573 A100.0 100.0 0.0 0 1 300.9844274522588 260.7900841627595 L230.35324464870223 190.0 A0.0 0.0 0.0 0 0 230.35324464870223 190.0 " fill="rgb(73,55,129)" stroke-width="1.0" fill-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M235.737291874738 198.426863916536 L306.36847467829455 269.21694807929555 A100.0 100.0 0.0 0 1 270.2910124987032 292.2673689825306 L235.737291874738 198.426863916536 A0.0 0.0 0.0 0 0 235.737291874738 198.426863916536 " fill="rgb(91,79,129)" stroke-width="1.0" fill-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M231.98635646893922 199.8657460834243 L266.5400770929044 293.7062511494189 A100.0 100.0 0.0 0 1 229.51468265276733 299.835195559484 L231.98635646893922 199.8657460834243 A0.0 0.0 0.0 0 0 231.98635646893922 199.8657460834243 " fill="rgb(105,103,128)" stroke-width="1.0" fill-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M227.93221527410768 209.85292464014685 L225.4605414579358 309.82237411620656 A100.0 100.0 0.0 0 1 206.30653707064857 307.48657684183615 L227.93221527410768 209.85292464014685 A0.0 0.0 0.0 0 0 227.93221527410768 209.85292464014685 " fill="rgb(117,128,127)" stroke-width="1.0" fill-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M221.45538781924685 218.6500984

// %%
val calories = dataFrameOf(
    "slice" to listOf(35, 25, 25, 15),
    "label" to listOf("Apples", "Bananas", "Cherries", "Dates"),
    "explode" to listOf(.1, .0, .0, .0)
)

// %%
plotGrid(
    listOf(
        calories.plot {
            pie {
                slice(slice)
                explode(explode)
                fillColor(label) {
                    scale = categoricalColorBrewer(BrewerPalette.Qualitative.Set1)
                }
                size = 15.0
            }
            layout {
                style(Style.Void)
            }
        },
        calories.plot {
            pie {
                slice(slice)
                explode(explode)
                fillColor(label) {
                    scale = categoricalColorBrewer(BrewerPalette.Qualitative.Set1)
                }
                size = 15.0
                hole = 0.8
            }
            layout {
                style(Style.Void)
            }
        }
    )
)
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;GEOdPh&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;layout&quot;:{
// &quot;name&quot;:&quot;grid&quot;,
// &quot;ncol&quot;:2,
// &quot;nrow&quot;:1,
// &quot;fit&quot;:true,
// &quot;align&quot;:false
// },
// &quot;figures&quot;:[{
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;slice&quot;:[35.0,25.0,25.0,15.0],
// &quot;explode&quot;:[0.1,0.0,0.0,0.0],
// &quot;label&quot;:[&quot;Apples&quot;,&quot;Bananas&quot;,&quot;Cherries&quot;,&quot;Dates&quot;]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_brewer&quot;,
// &quot;palette&quot;:&quot;Set1&quot;
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;slice&quot;:&quot;slice&quot;,
// &quot;explode&quot;:&quot;explode&quot;,
// &quot;fill&quot;:&quot;label&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:15.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;theme&quot;:{
// &quot;name&quot;:&quot;classic&quot;,
// &quot;axis&quot;:{
// &quot;blank&quot;:true
// },
// &quot;line&quot;:{
// &quot;blank&quot;:true
// },
// &quot;axis_ontop&quot;:false,
// &quot;axis_ontop_y&quot;:false,
// &quot;axis_ontop_x&quot;:false
// }
// },{
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;slice&quot;:[35.0,25.0,25.0,15.0],
// &quot;explode&quot;:[0.1,0.0,0.0,0.0],
// &quot;label&quot;:[&quot;Apples&quot;,&quot;Bananas&quot;,&quot;Cherries&quot;,&quot;Dates&quot;]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_brewer&quot;,
// &quot;palette&quot;:&quot;Set1&quot;
// }],
// &quot;layers&quot;:[{
// &quot;hole&quot;:0.8,
// &quot;mapping&quot;:{
// &quot;slice&quot;:&quot;slice&quot;,
// &quot;explode&quot;:&quot;explode&quot;,
// &quot;fill&quot;:&quot;label&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:15.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;theme&quot;:{
// &quot;name&quot;:&quot;classic&quot;,
// &quot;axis&quot;:{
// &quot;blank&quot;:true
// },
// &quot;line&quot;:{
// &quot;blank&quot;:true
// },
// &quot;axis_ontop&quot;:false,
// &quot;axis_ontop_y&quot;:false,
// &quot;axis_ontop_x&quot;:false
// }
// }],
// &quot;kind&quot;:&quot;subplots&quot;
// };
//        var plotContainer = document.getElementById(&quot;GEOdPh&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" id=762ac759-6ea5-4c05-8ebd-521e29817fe5 width="100%" height="100%" style="max-width: 900.0px; max-height: 400.0px;" viewBox="0 0 900.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <g id="pY0Rbhv">
//     <rect x="0.0" y="0.0" height="400.0" width="900.0" fill="rgb(255,255,255)" fill-opacity="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0">
//     </rect>
//   </g>
//   <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="448.0" height="400.0" x="0.0" y="0.0">
//     <style type="text/css">
//     .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pWmLQ2y .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pWmLQ2y .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pWmLQ2y .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pWmLQ2y .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pWmLQ2y .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pWmLQ2y .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pWmLQ2y .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dfjhzmN .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pWmLQ2y .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pWmLQ2y .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dfjhzmN .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pWmLQ2y .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pWmLQ2y .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dfjhzmN .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dfjhzmN .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dfjhzmN .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//     </style>
//     <g id="pWmLQ2y">
//       <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L448.0 400.0 L448.0 0.0 Z">
//       </path>
//       <g transform="translate(10.0 10.0 ) ">
//         <g transform="">
//         </g>
//         <g transform="translate(0.0 380.0 ) ">
//         </g>
//         <g transform="">
//         </g>
//         <g transform="">
//         </g>
//         <g transform="" clip-path="url(#cftA9Bt)" clip-bounds-jfx="[rect (0.0, 0.0), (323.2785026964189, 380.0)]">
//           <defs>
//             <clipPath id="cftA9Bt">
//               <rect x="0.0" y="0.0" width="323.2785026964189" height="380.0">
//               </rect>
//             </clipPath>
//           </defs>
//           <g>
//             <path d="M154.9567024167967 186.59507125195339 L94.28042783867564 230.67896517388886 A75.0 75.0 0.0 0 1 154.9567024167967 111.59507125195339 L154.9567024167967 186.59507125195339 A0.0 0.0 0.0 0 0 154.9567024167967 186.59507125195339 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//             </path>
//           </g>
//           <g>
//             <path d="M161.63925134820946 190.0 L161.63925134820946 115.0 A75.0 75.0 0.0 0 1 236.63925134820946 190.0 L161.63925134820946 190.0 A0.0 0.0 0.0 0 0 161.63925134820946 190.0 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//             </path>
//           </g>
//           <g>
