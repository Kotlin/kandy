// %% [markdown]
// # Plot Bunch
//
// *plotBunch()* allows showing a collection of plots on one figure.
// Each plot in the collection can have an arbitrary location and size.
// There is no automatic layout inside the bunch.

// %%
%use kandy

import org.apache.commons.math3.distribution.MultivariateNormalDistribution

// %%
val cov: Array<DoubleArray> = arrayOf(
    doubleArrayOf(1.0, 0.0),
    doubleArrayOf(0.0, 1.0)
)
val means: DoubleArray = doubleArrayOf(0.0, 0.0)
val xy = MultivariateNormalDistribution(means, cov).sample(400)

val xs = xy.map { it[0] }
val ys = xy.map { it[1] }

// %% [markdown]
// ### View this data as a scatter plot and as a histogram

// %%
val myScatter = plot {
    points {
        x(xs)
        y(ys)
        color = Color.GREY
        alpha = .4
    }
    layout {
        size = 600 to 200
        xAxisLabel = "x"
        yAxisLabel = "y"
    }
}
myScatter
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='200' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.0.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;Dt3Mz2&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:600.0,
// &quot;height&quot;:200.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;x&quot;
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;y&quot;
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;x&quot;,
// &quot;y&quot;:&quot;y&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;data&quot;:{
// &quot;x&quot;:[-2.596683181597675,1.2235689421700797,1.0655823698323443,-1.2100280046781853,-0.4861665986079104,0.6555269347981068,1.7867457913590736,-0.3615962544368323,-0.7496205273834033,0.45998595350779503,-0.20991840496952893,1.4373062965771985,0.9541790860974501,-1.140347176788375,0.7207304109683177,-1.4681491575945609,0.9254658807354401,-1.202738700888761,0.008406745248411512,-1.7588749466601228,0.0834518696769183,-2.397302838432838,-0.258795104061235,0.6770921812749664,0.4734838134121772,0.25020670238115167,-2.3007500396577103,-0.9387951830668788,1.4120742041070886,-0.12531566360626042,-0.5212021895875595,-0.12280397547786098,-0.7048007592503317,1.584288815793348,0.4619673282516753,0.2585617117704172,-0.8134977410597983,-0.8841685014135452,0.5839480715130473,0.17573215571795112,-1.5705508840309674,0.8430372202335447,1.5786279573981605,0.5949084883495901,-0.34884427226904674,1.0017642319490916,1.327146204872386,0.896636250150685,1.2248179457619934,-0.30569750950742414,-0.024915194040839823,-0.4164872482313392,1.825226681150007,0.9881874388639083,-0.05455689861091316,-1.702945870558986,0.9724696857353803,-1.533402125217122,1.1743470751236658,-1.8284985890943957,0.13887522221010093,1.311027252928661,0.1144071916501993,0.4311093280678462,-0.5233091208051266,1.2543991980231024,-1.326795485208699,1.0095896321379974,-0.8502135099994774,-1.024371899665668,-1.2883073161777692,-2.3180334183890747,0.581485565621426,1.7435659250404572,-0.394807146559095,-0.9789906273719785,0.6524798811883479,0.2121292346351029,-0.7145855195297063,-0.13785081050404427,0.06156671562505652,-0.0760390537083878,-0.2435229610057898,-1.7492053363198818,-0.6780997641246875,1.1753627780727431,0.8359427482051488,-1.6448272469166427,0.7233485869088526,0.5186700494398208,0.6610062969981869,0.7811379345606776,0.08179841553744166,-1.6546778588043574,-1.542879635070727,0.041633741594201565,1.8335278616423503,-0.02821569517626268,-0.9030107559342346,1.0546160650581942,1.2177328666000635,-1.3793950940762032,0.45602870744079654,0.014437545667605947,0.6779841320339485,-0.5881861996915438,-2.9252595118540294,-0.5377266251922831,0.4171093167123853,1.266218176096962,2.420172885761573,1.2194697303778428,0.7312110007610253,-0.854217327518857,-0.6891219217090915,-1.3077957684792623,0.3655647366587534,1.0526921182038007,-0.13421884816602242,-0.6939408404161331
0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="103.11484050908675" y1="-0.0" x2="103.11484050908675" y2="-144.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="181.59237119184968" y1="-0.0" x2="181.59237119184968" y2="-144.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="260.0699018746126" y1="-0.0" x2="260.0699018746126" y2="-144.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="338.5474325573755" y1="-0.0" x2="338.5474325573755" y2="-144.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="417.0249632401384" y1="-0.0" x2="417.0249632401384" y2="-144.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="495.50249392290135" y1="-0.0" x2="495.50249392290135" y2="-144.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(24.637309826323815 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             -3
//             </text>
//           </g>
//         </g>
//         <g transform="translate(103.11484050908675 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             -2
//             </text>
//           </g>
//         </g>
//         <g transform="translate(181.59237119184968 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             -1
//             </text>
//           </g>
//         </g>
//         <g transform="translate(260.0699018746126 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             0
//             </text>

// %% [markdown]
// ### Combine both plots in one figure

// %%
val scaleX = Scale.continuousPos(-3.5..3.5)
plotBunch {
    add(plot {
        histogram(xs) {
            x { scale = scaleX }
            fillColor = Color.named("dark_magenta")
        }
        layout {
            size = 600 to 200
            xAxisLabel = "x"
        }
    }, 0, 0)
    add(plot {
        points {
            x(xs) { scale = scaleX }
            y(ys)
            color = Color.GREY
            alpha = .4
        }
        layout {
            size = 600 to 200
            xAxisLabel = "x"
            yAxisLabel = "y"
        }
    }, 0, 200)
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.0.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;2EFBJj&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;kind&quot;:&quot;ggbunch&quot;,
// &quot;items&quot;:[{
// &quot;x&quot;:0,
// &quot;width&quot;:null,
// &quot;y&quot;:0,
// &quot;feature_spec&quot;:{
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:600.0,
// &quot;height&quot;:200.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;x&quot;,
// &quot;limits&quot;:[-3.5,3.5]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;x&quot;
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;x&quot;,
// &quot;y&quot;:&quot;count&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;data&quot;:{
// &quot;count&quot;:[2.0,4.0,4.0,10.0,18.0,26.0,28.0,42.0,37.0,44.0,44.0,42.0,36.0,32.0,16.0,7.0,4.0,3.0,0.0,1.0],
// &quot;x&quot;:[-2.85547807262705,-2.5382027312240445,-2.220927389821039,-1.9036520484180333,-1.5863767070150279,-1.2691013656120222,-0.9518260242090166,-0.634550682806011,-0.3172753414030056,0.0,0.3172753414030056,0.634550682806011,0.9518260242090166,1.2691013656120225,1.5863767070150279,1.9036520484180333,2.220927389821039,2.5382027312240445,2.85547807262705,3.1727534140300557]
// },
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;bar&quot;,
// &quot;fill&quot;:&quot;dark_magenta&quot;
// }]
// },
// &quot;height&quot;:null
// },{
// &quot;x&quot;:0,
// &quot;width&quot;:null,
// &quot;y&quot;:200,
// &quot;feature_spec&quot;:{
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:600.0,
// &quot;height&quot;:200.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;limits&quot;:[-3.5,3.5]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;x&quot;
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;y&quot;
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;x&quot;,
// &quot;y&quot;:&quot;y&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;data&quot;:{
// &quot;x&quot;:[-2.596683181597675,1.2235689421700797,1.0655823698323443,-1.2100280046781853,-0.4861665986079104,0.6555269347981068,1.7867457913590736,-0.3615962544368323,-0.7496205273834033,0.45998595350779503,-0.20991840496952893,1.4373062965771985,0.9541790860974501,-1.140347176788375,0.7207304109683177,-1.4681491575945609,0.9254658807354401,-1.202738700888761,0.008406745248411512,-1.7588749466601228,0.0834518696769183,-2.397302838432838,-0.258795104061235,0.6770921812749664,0.4734838134121772,0.25020670238115167,-2.3007500396577103,-0.9387951830668788,1.4120742041070886,-0.12531566360626042,-0.
// %% [markdown]
// ### Adjust visuals of the bunch figure

// %%
val upperTheme = theme {
    blankAxes()
    axis.text { }
    yAxis.title { }
    panel.grid.majorYLine {
        blank = true
    }
}
val lowerTheme = theme {
    blankAxes()
    yAxis.text { }
    axis.title { }
}

// %%
plotBunch {
    add(plot {
        histogram(xs) {
            x { scale = scaleX }
            fillColor = Color.named("dark_magenta")
        }
        layout {
            size = 600 to 200
            xAxisLabel = "x"
            theme(upperTheme)
        }
    }, 0, 0)
    add(plot {
        points {
            x(xs) { scale = scaleX }
            y(ys)
            color = Color.GREY
            alpha = .4
        }
        layout {
            size = 600 to 200
            xAxisLabel = "x"
            yAxisLabel = "y"
            theme(lowerTheme)
        }
    }, 0, 200)
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.0.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;lQdpwl&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;kind&quot;:&quot;ggbunch&quot;,
// &quot;items&quot;:[{
// &quot;x&quot;:0,
// &quot;width&quot;:null,
// &quot;y&quot;:0,
// &quot;feature_spec&quot;:{
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:600.0,
// &quot;height&quot;:200.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;x&quot;,
// &quot;limits&quot;:[-3.5,3.5]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;x&quot;
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;x&quot;,
// &quot;y&quot;:&quot;count&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;data&quot;:{
// &quot;x&quot;:[-2.85547807262705,-2.5382027312240445,-2.220927389821039,-1.9036520484180333,-1.5863767070150279,-1.2691013656120222,-0.9518260242090166,-0.634550682806011,-0.3172753414030056,0.0,0.3172753414030056,0.634550682806011,0.9518260242090166,1.2691013656120225,1.5863767070150279,1.9036520484180333,2.220927389821039,2.5382027312240445,2.85547807262705,3.1727534140300557],
// &quot;count&quot;:[2.0,4.0,4.0,10.0,18.0,26.0,28.0,42.0,37.0,44.0,44.0,42.0,36.0,32.0,16.0,7.0,4.0,3.0,0.0,1.0]
// },
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;bar&quot;,
// &quot;fill&quot;:&quot;dark_magenta&quot;
// }],
// &quot;theme&quot;:{
// &quot;axis_title_y&quot;:{
// &quot;blank&quot;:false
// },
// &quot;axis_ontop&quot;:false,
// &quot;panel_grid_major_y&quot;:{
// &quot;blank&quot;:true
// },
// &quot;axis&quot;:&quot;blank&quot;,
// &quot;axis_text&quot;:{
// &quot;blank&quot;:false
// },
// &quot;axis_ontop_y&quot;:false,
// &quot;axis_ontop_x&quot;:false
// }
// },
// &quot;height&quot;:null
// },{
// &quot;x&quot;:0,
// &quot;width&quot;:null,
// &quot;y&quot;:200,
// &quot;feature_spec&quot;:{
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:600.0,
// &quot;height&quot;:200.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;limits&quot;:[-3.5,3.5]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;x&quot;
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;y&quot;
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;x&quot;,
// &quot;y&quot;:&quot;y&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;data&quot;:{
// &quot;x&quot;:[-2.596683181597675,1.2235689421700797,1.0655823698323443,-1.2100280046781853,-0.4861665986079104,0.6555269347981068,1.7867457913590736,-0.3615962544368323,-0.7496205273834033,0.45998595350779503,-0.20991840496952893,1.4373062965771985,0.9541790860974501,-1.140347176788375,0.7207304109683177,-1.4681491575945609,0.9254658807354401,-1.202738700888761,0.008406745248411512,-1.7588749466601228,0.0834518696769183,-2.397302838432838,-0.258795104061235,0.6770921812749664,0.4734838134121772,0.25020670238115167,-2.3007500396577103,-0.9387951830668788,1.4120742041070886,-0.12531566360626042,-0.5212021895875595
// %% [markdown]
// ### Adjust plot sizes
//
// `add` method has two more (optional) parameters: `width` and `height`.
//
// These values will override the plot size earlier defined via *size* property.

// %%
plotBunch {
    add(plot {
        histogram(xs) {
            x { scale = scaleX }
            fillColor = Color.named("dark_magenta")
        }
        layout {
            size = 600 to 200
            xAxisLabel = "x"
            theme(upperTheme)
        }
    }, 0, 0, 600, 100)
    add(plot {
        points {
            x(xs) { scale = scaleX }
            y(ys)
            color = Color.GREY
            alpha = .4
        }
        layout {
            size = 600 to 200
            xAxisLabel = "x"
            yAxisLabel = "y"
            theme(lowerTheme)
        }
    }, 0, 100, 600, 300)
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.0.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;puDU70&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;kind&quot;:&quot;ggbunch&quot;,
// &quot;items&quot;:[{
// &quot;x&quot;:0,
// &quot;width&quot;:600,
// &quot;y&quot;:0,
// &quot;feature_spec&quot;:{
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:600.0,
// &quot;height&quot;:200.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;x&quot;,
// &quot;limits&quot;:[-3.5,3.5]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;x&quot;
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;x&quot;,
// &quot;y&quot;:&quot;count&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;data&quot;:{
// &quot;count&quot;:[2.0,4.0,4.0,10.0,18.0,26.0,28.0,42.0,37.0,44.0,44.0,42.0,36.0,32.0,16.0,7.0,4.0,3.0,0.0,1.0],
// &quot;x&quot;:[-2.85547807262705,-2.5382027312240445,-2.220927389821039,-1.9036520484180333,-1.5863767070150279,-1.2691013656120222,-0.9518260242090166,-0.634550682806011,-0.3172753414030056,0.0,0.3172753414030056,0.634550682806011,0.9518260242090166,1.2691013656120225,1.5863767070150279,1.9036520484180333,2.220927389821039,2.5382027312240445,2.85547807262705,3.1727534140300557]
// },
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;bar&quot;,
// &quot;fill&quot;:&quot;dark_magenta&quot;
// }],
// &quot;theme&quot;:{
// &quot;axis_title_y&quot;:{
// &quot;blank&quot;:false
// },
// &quot;axis_ontop&quot;:false,
// &quot;panel_grid_major_y&quot;:{
// &quot;blank&quot;:true
// },
// &quot;axis&quot;:&quot;blank&quot;,
// &quot;axis_text&quot;:{
// &quot;blank&quot;:false
// },
// &quot;axis_ontop_y&quot;:false,
// &quot;axis_ontop_x&quot;:false
// }
// },
// &quot;height&quot;:100
// },{
// &quot;x&quot;:0,
// &quot;width&quot;:600,
// &quot;y&quot;:100,
// &quot;feature_spec&quot;:{
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:600.0,
// &quot;height&quot;:200.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;limits&quot;:[-3.5,3.5]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;x&quot;
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;y&quot;
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;x&quot;,
// &quot;y&quot;:&quot;y&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;data&quot;:{
// &quot;x&quot;:[-2.596683181597675,1.2235689421700797,1.0655823698323443,-1.2100280046781853,-0.4861665986079104,0.6555269347981068,1.7867457913590736,-0.3615962544368323,-0.7496205273834033,0.45998595350779503,-0.20991840496952893,1.4373062965771985,0.9541790860974501,-1.140347176788375,0.7207304109683177,-1.4681491575945609,0.9254658807354401,-1.202738700888761,0.008406745248411512,-1.7588749466601228,0.0834518696769183,-2.397302838432838,-0.258795104061235,0.6770921812749664,0.4734838134121772,0.25020670238115167,-2.3007500396577103,-0.9387951830668788,1.4120742041070886,-0.12531566360626042,-0.5212021895875595,-0.12280397547786098,-0.7048007592503317,1.584288815793348,0.4619673282516753,0.2585617117704172,-0.8134977410597983