// %% [markdown]
// # Label Format

// %%
%use kandy(0.6.0-dev-40)
%use dataframe
%use datetime

import java.util.Locale

// %%
// The US Unemployment Rates 2000-2016
val economics = DataFrame.readCSV(
    "https://vincentarelbundock.github.io/Rdatasets/csv/ggplot2/economics.csv",
    parserOptions = ParserOptions(Locale.ENGLISH)
).filter { "date"<LocalDate>() >= LocalDate(2001, 1, 1) }

economics.head()
// Out:
//             <iframe onload="o_resize_iframe_out_1()" style="width:100%;" class="result_container" id="iframe_out_1" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody &gt; tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody &gt; tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody &gt; tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover &gt; td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// &sol;* formatting *&sol;
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
// :root {
//     --scroll-bg: #f5f5f5;
//     --scroll-fg: #b3b3b3;
// }
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;]{
//     --scroll-bg: #3c3c3c;
//     --scroll-fg: #97e1fb;
// }
// body {
//     scrollbar-color: var(--scroll-fg) var(--scroll-bg);
// }
// body::-webkit-scrollbar {
//     width: 10px; &sol;* Mostly for vertical scrollbars *&sol;
//     height: 10px; &sol;* Mostly for horizontal scrollbars *&sol;
// }
// body::-webkit-scrollbar-thumb {
//     background-color: var(--scroll-fg);
// }
// body::-webkit-scrollbar-track {
//     background-color: var(--scroll-bg);
// }
//             &lt;&sol;style&gt;
//         &lt;&sol;head&gt;
//         &lt;body&gt;
//
// &lt;table class=&quot;dataframe&quot; id=&quot;df_-1946157056&quot;&gt;&lt;&sol;table&gt;
//
// &lt;p class=&quot;dataframe_description&quot;&gt;DataFrame: rowsCount = 5, columnsCount = 7&lt;&sol;p&gt;
//
//         &lt;&sol;body&gt;
//         &lt;script&gt;
//             (function () {
//     window.DataFrame = window.DataFrame || new (function () {
//         this.addTable = function (df) {
//             let cols = df.cols;
//             for (let i = 0; i &lt; cols.length; i++) {
//                 for (let c of cols[i].children) {
//                     cols[c].parent = i;
//                 }
//             }
//             df.nrow = 0
//             for (let i = 0; i &lt; df.cols.length; i++) {
//                 if (df.cols[i].values.length &gt; df.nrow) df.nrow = df.cols[i].values.length
//             }
//             if (df.id === df.rootId) {
//                 df.expandedFrames = new Set()
//                 df.childFrames = {}
//                 const table = this.getTableElement(df.id)
//                 table.df = df
//                 for (let i = 0; i &lt; df.cols.length; i++) {
//                     let col = df.cols[i]
//                     if (col.parent === undefined &amp;&amp; col.children.length &gt; 0) col.expanded = true
//                 }
//             } else {
//                 const rootDf = this.getTableData(df.rootId)
//                 rootDf.childFrames[df.id] = df
//             }
//         }
//
//         this.computeRenderData = function (df) {
//             let result = []
//             let pos = 0
//             for (let col = 0; col &lt; df.cols.length; col++) {
//                 if (df.cols[col].parent === undefined)
//                     pos += this.computeRenderDataRec(df.cols, col, pos, 0, result, false, false)
//             }
//             for (let i = 0; i &lt; result.length; i++) {
//                 let row = result[i]
//                 for (let j = 0; j &lt; row.length; j++) {
//                     let cell = row[j]
//                     if (j === 0)
//                         cell.leftBd = false
//                     if (j &lt; row.length - 1) {
//                         let nextData = row[j + 1]
//                         if (nextData.leftBd) cell.rightBd = true
//                         else if (cell.rightBd) nextData.leftBd = true
//                     } else cell.rightBd = false
//                 }
//             }
//             return result
//         }
//
//         this.computeRenderDataRec = function (cols, colId, pos, depth, result, leftBorder, rightBorder) {
//             if (result.length === depth) {
//                 const array = [];
//                 if (pos &gt; 0) {
//                     let j = 0
//                     for (let i = 0; j &lt; pos; i++) {
//                         let c = result[depth - 1][i]
//                         j += c.span
//                         let copy = Object.assign({empty: true}, c)
//                         array.push(copy)
//                     }
//                 }
//                 result.push(array)
//             }
//             const col = cols[colId];
//             let size = 0;
//             if (col.expanded) {
//                 let childPos = pos
//                 for (let i = 0; i &lt; col.children.length; i++) {
//                     let child = col.children[i]
//                     let childLeft = i === 0 &amp;&amp; (col.children.length &gt; 1 || leftBorder)
//                     let childRight = i === col.children.length - 1 &amp;&amp; (col.children.length &gt; 1 || rightBorder)
//                     let childSize = this.computeRenderDataRec(cols, child, childPos, depth + 1, result, childLeft, childRight)
//                     childPos += childSize
//                     size += childSize
//                 }
//             } else {
//                 for (let i = depth + 1; i &lt; result.length; i++)
//                     result[i].push({id: colId, span: 1, leftBd: leftBorder, rightBd: rightBorder, empty: true})
//                 size = 1
//             }
//             let left = leftBorder
//             let right = rightBorder
//             if (size &gt; 1) {

// %% [markdown]
// ### Default plot (no formatting)

// %%
economics.plot { 
    line { 
        x(date)
        y(uempmed) { axis.name = "unemployment rate" }
    }
    layout.size = 900 to 400
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='900' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;unfPVz&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;date&quot;:[9.782928E11,9.809712E11,9.833904E11,9.860652E11,9.886572E11,9.913356E11,9.939276E11,9.96606E11,9.992844E11,1.0018764E12,1.0045584E12,1.0071504E12,1.0098288E12,1.0125072E12,1.0149264E12,1.0176012E12,1.0201932E12,1.0228716E12,1.0254636E12,1.028142E12,1.0308204E12,1.0334124E12,1.0360944E12,1.0386864E12,1.0413648E12,1.0440432E12,1.0464624E12,1.0491372E12,1.0517292E12,1.0544076E12,1.0569996E12,1.059678E12,1.0623564E12,1.0649484E12,1.0676304E12,1.0702224E12,1.0729008E12,1.0755792E12,1.0780848E12,1.0807596E12,1.0833516E12,1.08603E12,1.088622E12,1.0913004E12,1.0939788E12,1.0965708E12,1.0992528E12,1.1018448E12,1.1045232E12,1.1072016E12,1.1096208E12,1.1122956E12,1.1148876E12,1.117566E12,1.120158E12,1.1228364E12,1.1255148E12,1.1281068E12,1.1307888E12,1.1333808E12,1.1360592E12,1.1387376E12,1.1411568E12,1.1438316E12,1.1464236E12,1.149102E12,1.151694E12,1.1543724E12,1.1570508E12,1.1596428E12,1.1623248E12,1.1649168E12,1.1675952E12,1.1702736E12,1.1726928E12,1.1753676E12,1.1779596E12,1.180638E12,1.18323E12,1.1859084E12,1.1885868E12,1.1911788E12,1.1938608E12,1.1964528E12,1.1991312E12,1.2018096E12,1.2043152E12,1.20699E12,1.209582E12,1.2122604E12,1.2148524E12,1.2175308E12,1.2202092E12,1.2228012E12,1.2254832E12,1.2280752E12,1.2307536E12,1.233432E12,1.2358512E12,1.238526E12,1.241118E12,1.2437964E12,1.2463884E12,1.2490668E12,1.2517452E12,1.2543372E12,1.2570192E12,1.2596112E12,1.2622896E12,1.264968E12,1.2673872E12,1.270062E12,1.272654E12,1.2753324E12,1.2779244E12,1.2806028E12,1.2832812E12,1.2858732E12,1.2885552E12,1.2911472E12,1.2938256E12,1.296504E12,1.2989232E12,1.301598E12,1.30419E12,1.3068684E12,1.3094604E12,1.3121388E12,1.3148172E12,1.3174092E12,1.3200912E12,1.3226832E12,1.3253616E12,1.32804E12,1.3305456E12,1.333224E12,1.335816E12,1.3384944E12,1.3410864E12,1.3437648E12,1.3464432E12,1.3490352E12,1.3517136E12,1.3543056E12,1.356984E12,1.3596624E12,1.3620816E12,1.36476E12,1.367352E12,1.3700304E12,1.3726224E12,1.3753008E12,1.3779792E12,1.3805712E12,1.3832496E12,1.3858416E12,1.38852E12,1.3911984E12,1.3936176E12,1.396296E12,1.398888E12,1.4015664E12,1.4041584E12,1.4068368E12,1.4095152E12,1.4121072E12,1.4147856E12,1.4173776E12,1.420056E12,1.4227344E12,1.4251536E12,1.427832E12],
// &quot;uempmed&quot;:[5.8,6.1,6.6,5.9,6.3,6.0,6.8,6.9,7.2,7.3,7.7,8.2,8.4,8.3,8.4,8.9,9.5,11.0,8.9,9.0,9.5,9.6,9.3,9.6,9.6,9.5,9.7,10.2,9.9,11.5,10.3,10.1,10.2,10.4,10.3,10.4,10.6,10.2,10.2,9.5,9.9,11.0,8.9,9.2,9.6,9.5,9.7,9.5,9.4,9.2,9.3,9.0,9.1,9.0,8.8,9.2,8.4,8.6,8.5,8.7,8.6,9.1,8.7,8.4,8.5,7.3,8.0,8.4,8.0,7.9,8.3,7.5,8.3,8.5,9.1,8.6,8.2,7.7,8.7,8.8,8.7,8.4,8.6,8.4,9.0,8.7,8.7,9.4,7.9,9.0,9.7,9.7,10.2,10.4,9.8,10.5,10.7,11.7,12.3,13.1,14.2,17.2,16.0,16.3,17.8,18.9,19.8,20.1,20.0,19.9,20.4,22.1,22.3,25.2,22.3,21.0,20.3,21.2,21.0,21.9,21.5,21.1,21.5,20.9,21.6,22.4,22.0,22.4,22.0,20.6,20.8,20.5,20.8,19.7,19.2,19.1,19.9,20.4,17.5,18.4,18.8,19.9,18.6,17.7,15.8,17.2,17.6,17.1,17.1,17.0,16.2,16.5,16.5,16.3,17.1,17.3,15.4,15.9,15.8,15.7,14.6,13.8,13.1,12.9,13.4,13.6,13.0,12.9,13.2,12.9,12.0,11.5]
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:900.0,
// &quot;height&quot;:400.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;datetime&quot;:true,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;unemployment rate&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;date&quot;,
// &quot;y&quot;:&quot;uempmed&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;line&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;column&quot;:&quot;date&quot;,
// &quot;type&quot;:&quot;datetime&quot;
// }]
// }
// };
//        var plotContainer = document.getElementById(&quot;unfPVz&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" id=ea9d97fa-34dc-48a8-9425-49e2529b248f width="100%" height="100%" style="max-width: 900.0px; max-height: 400.0px;" viewBox="0 0 900.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pxh3z9t .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pxh3z9t .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pxh3z9t .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pxh3z9t .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pxh3z9t .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pxh3z9t .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pxh3z9t .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dKCc2lX .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pxh3z9t .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pxh3z9t .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dKCc2lX .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pxh3z9t .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pxh3z9t .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dKCc2lX .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dKCc2lX .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dKCc2lX .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pxh3z9t">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L900.0 400.0 L900.0 0.0 Z">
//     </path>
//     <g trans

// %% [markdown]
// ### Apply formatting to X and Y axis labels
//
// Use the `format` parameter in `breaks()` for axis.
//
//
// > Text in tooltips is now also formatted.

// %%
economics.plot { 
    line { 
        x(date) {
            axis {
                breaks(format = "%b %Y")
            }
        }
        y(uempmed) {
            axis {
                name = "unemployment rate"
                breaks(format = "{} %")
            }
        }
    }
    layout.size = 900 to 400
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='900' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;SzkAAj&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;date&quot;:[9.782928E11,9.809712E11,9.833904E11,9.860652E11,9.886572E11,9.913356E11,9.939276E11,9.96606E11,9.992844E11,1.0018764E12,1.0045584E12,1.0071504E12,1.0098288E12,1.0125072E12,1.0149264E12,1.0176012E12,1.0201932E12,1.0228716E12,1.0254636E12,1.028142E12,1.0308204E12,1.0334124E12,1.0360944E12,1.0386864E12,1.0413648E12,1.0440432E12,1.0464624E12,1.0491372E12,1.0517292E12,1.0544076E12,1.0569996E12,1.059678E12,1.0623564E12,1.0649484E12,1.0676304E12,1.0702224E12,1.0729008E12,1.0755792E12,1.0780848E12,1.0807596E12,1.0833516E12,1.08603E12,1.088622E12,1.0913004E12,1.0939788E12,1.0965708E12,1.0992528E12,1.1018448E12,1.1045232E12,1.1072016E12,1.1096208E12,1.1122956E12,1.1148876E12,1.117566E12,1.120158E12,1.1228364E12,1.1255148E12,1.1281068E12,1.1307888E12,1.1333808E12,1.1360592E12,1.1387376E12,1.1411568E12,1.1438316E12,1.1464236E12,1.149102E12,1.151694E12,1.1543724E12,1.1570508E12,1.1596428E12,1.1623248E12,1.1649168E12,1.1675952E12,1.1702736E12,1.1726928E12,1.1753676E12,1.1779596E12,1.180638E12,1.18323E12,1.1859084E12,1.1885868E12,1.1911788E12,1.1938608E12,1.1964528E12,1.1991312E12,1.2018096E12,1.2043152E12,1.20699E12,1.209582E12,1.2122604E12,1.2148524E12,1.2175308E12,1.2202092E12,1.2228012E12,1.2254832E12,1.2280752E12,1.2307536E12,1.233432E12,1.2358512E12,1.238526E12,1.241118E12,1.2437964E12,1.2463884E12,1.2490668E12,1.2517452E12,1.2543372E12,1.2570192E12,1.2596112E12,1.2622896E12,1.264968E12,1.2673872E12,1.270062E12,1.272654E12,1.2753324E12,1.2779244E12,1.2806028E12,1.2832812E12,1.2858732E12,1.2885552E12,1.2911472E12,1.2938256E12,1.296504E12,1.2989232E12,1.301598E12,1.30419E12,1.3068684E12,1.3094604E12,1.3121388E12,1.3148172E12,1.3174092E12,1.3200912E12,1.3226832E12,1.3253616E12,1.32804E12,1.3305456E12,1.333224E12,1.335816E12,1.3384944E12,1.3410864E12,1.3437648E12,1.3464432E12,1.3490352E12,1.3517136E12,1.3543056E12,1.356984E12,1.3596624E12,1.3620816E12,1.36476E12,1.367352E12,1.3700304E12,1.3726224E12,1.3753008E12,1.3779792E12,1.3805712E12,1.3832496E12,1.3858416E12,1.38852E12,1.3911984E12,1.3936176E12,1.396296E12,1.398888E12,1.4015664E12,1.4041584E12,1.4068368E12,1.4095152E12,1.4121072E12,1.4147856E12,1.4173776E12,1.420056E12,1.4227344E12,1.4251536E12,1.427832E12],
// &quot;uempmed&quot;:[5.8,6.1,6.6,5.9,6.3,6.0,6.8,6.9,7.2,7.3,7.7,8.2,8.4,8.3,8.4,8.9,9.5,11.0,8.9,9.0,9.5,9.6,9.3,9.6,9.6,9.5,9.7,10.2,9.9,11.5,10.3,10.1,10.2,10.4,10.3,10.4,10.6,10.2,10.2,9.5,9.9,11.0,8.9,9.2,9.6,9.5,9.7,9.5,9.4,9.2,9.3,9.0,9.1,9.0,8.8,9.2,8.4,8.6,8.5,8.7,8.6,9.1,8.7,8.4,8.5,7.3,8.0,8.4,8.0,7.9,8.3,7.5,8.3,8.5,9.1,8.6,8.2,7.7,8.7,8.8,8.7,8.4,8.6,8.4,9.0,8.7,8.7,9.4,7.9,9.0,9.7,9.7,10.2,10.4,9.8,10.5,10.7,11.7,12.3,13.1,14.2,17.2,16.0,16.3,17.8,18.9,19.8,20.1,20.0,19.9,20.4,22.1,22.3,25.2,22.3,21.0,20.3,21.2,21.0,21.9,21.5,21.1,21.5,20.9,21.6,22.4,22.0,22.4,22.0,20.6,20.8,20.5,20.8,19.7,19.2,19.1,19.9,20.4,17.5,18.4,18.8,19.9,18.6,17.7,15.8,17.2,17.6,17.1,17.1,17.0,16.2,16.5,16.5,16.3,17.1,17.3,15.4,15.9,15.8,15.7,14.6,13.8,13.1,12.9,13.4,13.6,13.0,12.9,13.2,12.9,12.0,11.5]
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:900.0,
// &quot;height&quot;:400.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;datetime&quot;:true,
// &quot;format&quot;:&quot;%b %Y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;unemployment rate&quot;,
// &quot;format&quot;:&quot;{} %&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;date&quot;,
// &quot;y&quot;:&quot;uempmed&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;line&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;column&quot;:&quot;date&quot;,
// &quot;type&quot;:&quot;datetime&quot;
// }]
// }
// };
//        var plotContainer = document.getElementById(&quot;SzkAAj&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" id=5c2a92f3-fb71-4867-8895-e87506f4e194 width="100%" height="100%" style="max-width: 900.0px; max-height: 400.0px;" viewBox="0 0 900.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pw9qer0 .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pw9qer0 .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pw9qer0 .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pw9qer0 .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pw9qer0 .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pw9qer0 .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pw9qer0 .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dtNyfN1 .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pw9qer0 .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pw9qer0 .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dtNyfN1 .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pw9qer0 .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pw9qer0 .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dtNyfN1 .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dtNyfN1 .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dtNyfN1 .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pw9qer0">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0"

// %% [markdown]
// ### Format axis labels for breaks specified manually

// %%
economics.plot { 
    line { 
        x(date) {
            axis {
                breaks(format = "%b %Y")
            }
        }
        y(uempmed) {
            axis {
                name = "unemployment rate"
                breaks(listOf(5.0, 15.0, 25.0), format = "{} %")
            }
        }
    }
    layout.size = 900 to 400
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='900' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;NplDs9&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;date&quot;:[9.782928E11,9.809712E11,9.833904E11,9.860652E11,9.886572E11,9.913356E11,9.939276E11,9.96606E11,9.992844E11,1.0018764E12,1.0045584E12,1.0071504E12,1.0098288E12,1.0125072E12,1.0149264E12,1.0176012E12,1.0201932E12,1.0228716E12,1.0254636E12,1.028142E12,1.0308204E12,1.0334124E12,1.0360944E12,1.0386864E12,1.0413648E12,1.0440432E12,1.0464624E12,1.0491372E12,1.0517292E12,1.0544076E12,1.0569996E12,1.059678E12,1.0623564E12,1.0649484E12,1.0676304E12,1.0702224E12,1.0729008E12,1.0755792E12,1.0780848E12,1.0807596E12,1.0833516E12,1.08603E12,1.088622E12,1.0913004E12,1.0939788E12,1.0965708E12,1.0992528E12,1.1018448E12,1.1045232E12,1.1072016E12,1.1096208E12,1.1122956E12,1.1148876E12,1.117566E12,1.120158E12,1.1228364E12,1.1255148E12,1.1281068E12,1.1307888E12,1.1333808E12,1.1360592E12,1.1387376E12,1.1411568E12,1.1438316E12,1.1464236E12,1.149102E12,1.151694E12,1.1543724E12,1.1570508E12,1.1596428E12,1.1623248E12,1.1649168E12,1.1675952E12,1.1702736E12,1.1726928E12,1.1753676E12,1.1779596E12,1.180638E12,1.18323E12,1.1859084E12,1.1885868E12,1.1911788E12,1.1938608E12,1.1964528E12,1.1991312E12,1.2018096E12,1.2043152E12,1.20699E12,1.209582E12,1.2122604E12,1.2148524E12,1.2175308E12,1.2202092E12,1.2228012E12,1.2254832E12,1.2280752E12,1.2307536E12,1.233432E12,1.2358512E12,1.238526E12,1.241118E12,1.2437964E12,1.2463884E12,1.2490668E12,1.2517452E12,1.2543372E12,1.2570192E12,1.2596112E12,1.2622896E12,1.264968E12,1.2673872E12,1.270062E12,1.272654E12,1.2753324E12,1.2779244E12,1.2806028E12,1.2832812E12,1.2858732E12,1.2885552E12,1.2911472E12,1.2938256E12,1.296504E12,1.2989232E12,1.301598E12,1.30419E12,1.3068684E12,1.3094604E12,1.3121388E12,1.3148172E12,1.3174092E12,1.3200912E12,1.3226832E12,1.3253616E12,1.32804E12,1.3305456E12,1.333224E12,1.335816E12,1.3384944E12,1.3410864E12,1.3437648E12,1.3464432E12,1.3490352E12,1.3517136E12,1.3543056E12,1.356984E12,1.3596624E12,1.3620816E12,1.36476E12,1.367352E12,1.3700304E12,1.3726224E12,1.3753008E12,1.3779792E12,1.3805712E12,1.3832496E12,1.3858416E12,1.38852E12,1.3911984E12,1.3936176E12,1.396296E12,1.398888E12,1.4015664E12,1.4041584E12,1.4068368E12,1.4095152E12,1.4121072E12,1.4147856E12,1.4173776E12,1.420056E12,1.4227344E12,1.4251536E12,1.427832E12],
// &quot;uempmed&quot;:[5.8,6.1,6.6,5.9,6.3,6.0,6.8,6.9,7.2,7.3,7.7,8.2,8.4,8.3,8.4,8.9,9.5,11.0,8.9,9.0,9.5,9.6,9.3,9.6,9.6,9.5,9.7,10.2,9.9,11.5,10.3,10.1,10.2,10.4,10.3,10.4,10.6,10.2,10.2,9.5,9.9,11.0,8.9,9.2,9.6,9.5,9.7,9.5,9.4,9.2,9.3,9.0,9.1,9.0,8.8,9.2,8.4,8.6,8.5,8.7,8.6,9.1,8.7,8.4,8.5,7.3,8.0,8.4,8.0,7.9,8.3,7.5,8.3,8.5,9.1,8.6,8.2,7.7,8.7,8.8,8.7,8.4,8.6,8.4,9.0,8.7,8.7,9.4,7.9,9.0,9.7,9.7,10.2,10.4,9.8,10.5,10.7,11.7,12.3,13.1,14.2,17.2,16.0,16.3,17.8,18.9,19.8,20.1,20.0,19.9,20.4,22.1,22.3,25.2,22.3,21.0,20.3,21.2,21.0,21.9,21.5,21.1,21.5,20.9,21.6,22.4,22.0,22.4,22.0,20.6,20.8,20.5,20.8,19.7,19.2,19.1,19.9,20.4,17.5,18.4,18.8,19.9,18.6,17.7,15.8,17.2,17.6,17.1,17.1,17.0,16.2,16.5,16.5,16.3,17.1,17.3,15.4,15.9,15.8,15.7,14.6,13.8,13.1,12.9,13.4,13.6,13.0,12.9,13.2,12.9,12.0,11.5]
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:900.0,
// &quot;height&quot;:400.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;datetime&quot;:true,
// &quot;format&quot;:&quot;%b %Y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;breaks&quot;:[5.0,15.0,25.0],
// &quot;name&quot;:&quot;unemployment rate&quot;,
// &quot;format&quot;:&quot;{} %&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;date&quot;,
// &quot;y&quot;:&quot;uempmed&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;line&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;column&quot;:&quot;date&quot;,
// &quot;type&quot;:&quot;datetime&quot;
// }]
// }
// };
//        var plotContainer = document.getElementById(&quot;NplDs9&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" id=1cafd20b-b8f6-4d43-b2ff-dc263c85ebe3 width="100%" height="100%" style="max-width: 900.0px; max-height: 400.0px;" viewBox="0 0 900.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pDasYuH .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDasYuH .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDasYuH .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDasYuH .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDasYuH .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDasYuH .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDasYuH .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dDdFN5q .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDasYuH .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDasYuH .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dDdFN5q .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDasYuH .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDasYuH .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dDdFN5q .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dDdFN5q .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dDdFN5q .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pDasYuH">
//     <path fill-rule="evenodd" fill="r

// %% [markdown]
// ### Configure tooltip's text and location

// %%
economics.plot { 
    line { 
        x(date) {
            axis {
                breaks(format = "%b %Y")
            }
        }
        y(uempmed) {
            axis {
                name = "unemployment rate"
                breaks(format = "{} %")
            }
        }
        tooltips(anchor = Anchor.TOP_CENTER, minWidth = 170.0) {
            line("Unemployment rate:|^y")
        }
    }
    layout.size = 900 to 400
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='900' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;4Nyz3b&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;date&quot;:[9.782928E11,9.809712E11,9.833904E11,9.860652E11,9.886572E11,9.913356E11,9.939276E11,9.96606E11,9.992844E11,1.0018764E12,1.0045584E12,1.0071504E12,1.0098288E12,1.0125072E12,1.0149264E12,1.0176012E12,1.0201932E12,1.0228716E12,1.0254636E12,1.028142E12,1.0308204E12,1.0334124E12,1.0360944E12,1.0386864E12,1.0413648E12,1.0440432E12,1.0464624E12,1.0491372E12,1.0517292E12,1.0544076E12,1.0569996E12,1.059678E12,1.0623564E12,1.0649484E12,1.0676304E12,1.0702224E12,1.0729008E12,1.0755792E12,1.0780848E12,1.0807596E12,1.0833516E12,1.08603E12,1.088622E12,1.0913004E12,1.0939788E12,1.0965708E12,1.0992528E12,1.1018448E12,1.1045232E12,1.1072016E12,1.1096208E12,1.1122956E12,1.1148876E12,1.117566E12,1.120158E12,1.1228364E12,1.1255148E12,1.1281068E12,1.1307888E12,1.1333808E12,1.1360592E12,1.1387376E12,1.1411568E12,1.1438316E12,1.1464236E12,1.149102E12,1.151694E12,1.1543724E12,1.1570508E12,1.1596428E12,1.1623248E12,1.1649168E12,1.1675952E12,1.1702736E12,1.1726928E12,1.1753676E12,1.1779596E12,1.180638E12,1.18323E12,1.1859084E12,1.1885868E12,1.1911788E12,1.1938608E12,1.1964528E12,1.1991312E12,1.2018096E12,1.2043152E12,1.20699E12,1.209582E12,1.2122604E12,1.2148524E12,1.2175308E12,1.2202092E12,1.2228012E12,1.2254832E12,1.2280752E12,1.2307536E12,1.233432E12,1.2358512E12,1.238526E12,1.241118E12,1.2437964E12,1.2463884E12,1.2490668E12,1.2517452E12,1.2543372E12,1.2570192E12,1.2596112E12,1.2622896E12,1.264968E12,1.2673872E12,1.270062E12,1.272654E12,1.2753324E12,1.2779244E12,1.2806028E12,1.2832812E12,1.2858732E12,1.2885552E12,1.2911472E12,1.2938256E12,1.296504E12,1.2989232E12,1.301598E12,1.30419E12,1.3068684E12,1.3094604E12,1.3121388E12,1.3148172E12,1.3174092E12,1.3200912E12,1.3226832E12,1.3253616E12,1.32804E12,1.3305456E12,1.333224E12,1.335816E12,1.3384944E12,1.3410864E12,1.3437648E12,1.3464432E12,1.3490352E12,1.3517136E12,1.3543056E12,1.356984E12,1.3596624E12,1.3620816E12,1.36476E12,1.367352E12,1.3700304E12,1.3726224E12,1.3753008E12,1.3779792E12,1.3805712E12,1.3832496E12,1.3858416E12,1.38852E12,1.3911984E12,1.3936176E12,1.396296E12,1.398888E12,1.4015664E12,1.4041584E12,1.4068368E12,1.4095152E12,1.4121072E12,1.4147856E12,1.4173776E12,1.420056E12,1.4227344E12,1.4251536E12,1.427832E12],
// &quot;uempmed&quot;:[5.8,6.1,6.6,5.9,6.3,6.0,6.8,6.9,7.2,7.3,7.7,8.2,8.4,8.3,8.4,8.9,9.5,11.0,8.9,9.0,9.5,9.6,9.3,9.6,9.6,9.5,9.7,10.2,9.9,11.5,10.3,10.1,10.2,10.4,10.3,10.4,10.6,10.2,10.2,9.5,9.9,11.0,8.9,9.2,9.6,9.5,9.7,9.5,9.4,9.2,9.3,9.0,9.1,9.0,8.8,9.2,8.4,8.6,8.5,8.7,8.6,9.1,8.7,8.4,8.5,7.3,8.0,8.4,8.0,7.9,8.3,7.5,8.3,8.5,9.1,8.6,8.2,7.7,8.7,8.8,8.7,8.4,8.6,8.4,9.0,8.7,8.7,9.4,7.9,9.0,9.7,9.7,10.2,10.4,9.8,10.5,10.7,11.7,12.3,13.1,14.2,17.2,16.0,16.3,17.8,18.9,19.8,20.1,20.0,19.9,20.4,22.1,22.3,25.2,22.3,21.0,20.3,21.2,21.0,21.9,21.5,21.1,21.5,20.9,21.6,22.4,22.0,22.4,22.0,20.6,20.8,20.5,20.8,19.7,19.2,19.1,19.9,20.4,17.5,18.4,18.8,19.9,18.6,17.7,15.8,17.2,17.6,17.1,17.1,17.0,16.2,16.5,16.5,16.3,17.1,17.3,15.4,15.9,15.8,15.7,14.6,13.8,13.1,12.9,13.4,13.6,13.0,12.9,13.2,12.9,12.0,11.5]
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:900.0,
// &quot;height&quot;:400.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;datetime&quot;:true,
// &quot;format&quot;:&quot;%b %Y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;unemployment rate&quot;,
// &quot;format&quot;:&quot;{} %&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;date&quot;,
// &quot;y&quot;:&quot;uempmed&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;line&quot;,
// &quot;tooltips&quot;:{
// &quot;tooltip_min_width&quot;:170.0,
// &quot;tooltip_anchor&quot;:&quot;top_center&quot;,
// &quot;lines&quot;:[&quot;Unemployment rate:|^y&quot;],
// &quot;disable_splitting&quot;:true
// },
// &quot;data&quot;:{
// }
// }],
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;column&quot;:&quot;date&quot;,
// &quot;type&quot;:&quot;datetime&quot;
// }]
// }
// };
//        var plotContainer = document.getElementById(&quot;4Nyz3b&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" id=873ce661-104b-4857-8600-1b9290ce0609 width="100%" height="100%" style="max-width: 900.0px; max-height: 400.0px;" viewBox="0 0 900.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pMh1mR4 .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pMh1mR4 .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pMh1mR4 .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pMh1mR4 .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pMh1mR4 .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pMh1mR4 .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pMh1mR4 .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dGfcVjo .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pMh1mR4 .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pMh1mR4 .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dGfcVjo .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pMh1mR4 .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pMh1mR4 .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dGfcVjo .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dGfcVjo .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dGfcVjo .tooltip-label {
//    fill: #474747;
//    font-family:

// %% [markdown]
// ### Format value shown in tooltip

// %%
economics.plot { 
    line { 
        x(date)
        y(uempmed) {
            axis {
                name = "unemployment rate"
            }
        }
        tooltips(formats = mapOf(date to "%B %Y"), anchor = Anchor.TOP_CENTER, minWidth = 170.0) {
            line("@uempmed % in @date")
        }
    }
    layout.size = 900 to 400
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='900' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;bGyrva&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;date&quot;:[9.782928E11,9.809712E11,9.833904E11,9.860652E11,9.886572E11,9.913356E11,9.939276E11,9.96606E11,9.992844E11,1.0018764E12,1.0045584E12,1.0071504E12,1.0098288E12,1.0125072E12,1.0149264E12,1.0176012E12,1.0201932E12,1.0228716E12,1.0254636E12,1.028142E12,1.0308204E12,1.0334124E12,1.0360944E12,1.0386864E12,1.0413648E12,1.0440432E12,1.0464624E12,1.0491372E12,1.0517292E12,1.0544076E12,1.0569996E12,1.059678E12,1.0623564E12,1.0649484E12,1.0676304E12,1.0702224E12,1.0729008E12,1.0755792E12,1.0780848E12,1.0807596E12,1.0833516E12,1.08603E12,1.088622E12,1.0913004E12,1.0939788E12,1.0965708E12,1.0992528E12,1.1018448E12,1.1045232E12,1.1072016E12,1.1096208E12,1.1122956E12,1.1148876E12,1.117566E12,1.120158E12,1.1228364E12,1.1255148E12,1.1281068E12,1.1307888E12,1.1333808E12,1.1360592E12,1.1387376E12,1.1411568E12,1.1438316E12,1.1464236E12,1.149102E12,1.151694E12,1.1543724E12,1.1570508E12,1.1596428E12,1.1623248E12,1.1649168E12,1.1675952E12,1.1702736E12,1.1726928E12,1.1753676E12,1.1779596E12,1.180638E12,1.18323E12,1.1859084E12,1.1885868E12,1.1911788E12,1.1938608E12,1.1964528E12,1.1991312E12,1.2018096E12,1.2043152E12,1.20699E12,1.209582E12,1.2122604E12,1.2148524E12,1.2175308E12,1.2202092E12,1.2228012E12,1.2254832E12,1.2280752E12,1.2307536E12,1.233432E12,1.2358512E12,1.238526E12,1.241118E12,1.2437964E12,1.2463884E12,1.2490668E12,1.2517452E12,1.2543372E12,1.2570192E12,1.2596112E12,1.2622896E12,1.264968E12,1.2673872E12,1.270062E12,1.272654E12,1.2753324E12,1.2779244E12,1.2806028E12,1.2832812E12,1.2858732E12,1.2885552E12,1.2911472E12,1.2938256E12,1.296504E12,1.2989232E12,1.301598E12,1.30419E12,1.3068684E12,1.3094604E12,1.3121388E12,1.3148172E12,1.3174092E12,1.3200912E12,1.3226832E12,1.3253616E12,1.32804E12,1.3305456E12,1.333224E12,1.335816E12,1.3384944E12,1.3410864E12,1.3437648E12,1.3464432E12,1.3490352E12,1.3517136E12,1.3543056E12,1.356984E12,1.3596624E12,1.3620816E12,1.36476E12,1.367352E12,1.3700304E12,1.3726224E12,1.3753008E12,1.3779792E12,1.3805712E12,1.3832496E12,1.3858416E12,1.38852E12,1.3911984E12,1.3936176E12,1.396296E12,1.398888E12,1.4015664E12,1.4041584E12,1.4068368E12,1.4095152E12,1.4121072E12,1.4147856E12,1.4173776E12,1.420056E12,1.4227344E12,1.4251536E12,1.427832E12],
// &quot;uempmed&quot;:[5.8,6.1,6.6,5.9,6.3,6.0,6.8,6.9,7.2,7.3,7.7,8.2,8.4,8.3,8.4,8.9,9.5,11.0,8.9,9.0,9.5,9.6,9.3,9.6,9.6,9.5,9.7,10.2,9.9,11.5,10.3,10.1,10.2,10.4,10.3,10.4,10.6,10.2,10.2,9.5,9.9,11.0,8.9,9.2,9.6,9.5,9.7,9.5,9.4,9.2,9.3,9.0,9.1,9.0,8.8,9.2,8.4,8.6,8.5,8.7,8.6,9.1,8.7,8.4,8.5,7.3,8.0,8.4,8.0,7.9,8.3,7.5,8.3,8.5,9.1,8.6,8.2,7.7,8.7,8.8,8.7,8.4,8.6,8.4,9.0,8.7,8.7,9.4,7.9,9.0,9.7,9.7,10.2,10.4,9.8,10.5,10.7,11.7,12.3,13.1,14.2,17.2,16.0,16.3,17.8,18.9,19.8,20.1,20.0,19.9,20.4,22.1,22.3,25.2,22.3,21.0,20.3,21.2,21.0,21.9,21.5,21.1,21.5,20.9,21.6,22.4,22.0,22.4,22.0,20.6,20.8,20.5,20.8,19.7,19.2,19.1,19.9,20.4,17.5,18.4,18.8,19.9,18.6,17.7,15.8,17.2,17.6,17.1,17.1,17.0,16.2,16.5,16.5,16.3,17.1,17.3,15.4,15.9,15.8,15.7,14.6,13.8,13.1,12.9,13.4,13.6,13.0,12.9,13.2,12.9,12.0,11.5]
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:900.0,
// &quot;height&quot;:400.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;datetime&quot;:true,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;unemployment rate&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;date&quot;,
// &quot;y&quot;:&quot;uempmed&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;line&quot;,
// &quot;tooltips&quot;:{
// &quot;tooltip_min_width&quot;:170.0,
// &quot;tooltip_anchor&quot;:&quot;top_center&quot;,
// &quot;formats&quot;:[{
// &quot;field&quot;:&quot;date&quot;,
// &quot;format&quot;:&quot;%B %Y&quot;
// }],
// &quot;lines&quot;:[&quot;@uempmed % in @date&quot;],
// &quot;disable_splitting&quot;:true
// },
// &quot;data&quot;:{
// }
// }],
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;column&quot;:&quot;date&quot;,
// &quot;type&quot;:&quot;datetime&quot;
// }]
// }
// };
//        var plotContainer = document.getElementById(&quot;bGyrva&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" id=fa79c34a-7aaa-46e7-9b70-9124472f6a7d width="100%" height="100%" style="max-width: 900.0px; max-height: 400.0px;" viewBox="0 0 900.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pDOaGAZ .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDOaGAZ .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDOaGAZ .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDOaGAZ .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDOaGAZ .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDOaGAZ .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDOaGAZ .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d0haZjk .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDOaGAZ .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDOaGAZ .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d0haZjk .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDOaGAZ .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pDOaGAZ .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d0haZjk .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d0haZjk .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #d0haZjk .tooltip-label {
//    fill: #

// %% [markdown]
// ### Adding to the unemployment rate mean

// %%
val unemploymentMean = economics.uempmed.mean()


economics.plot {
    x(date)
    y(uempmed)
    line {
        tooltips(formats = mapOf(date to "%B %Y"), anchor = Anchor.TOP_CENTER, minWidth = 170.0) {
            line("Unemployment rate:|^y %")
        }
    }
    hLine { 
        yIntercept.constant(unemploymentMean)
        color = Color.RED
        type = LineType.DASHED
        tooltips(enable = false)
    }
    text { 
        label = "${String.format("%.2f", unemploymentMean)} %"
        x.constant(LocalDate(2001, 1, 1).atStartOfDayIn(TimeZone.UTC).toEpochMilliseconds())
        y.constant(unemploymentMean + 0.5)
    }
    layout {
        title = "The US Unemployment Rates 2000-2016."
        yAxisLabel = "unemployment rate"
        size = 900 to 400
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='900' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;RxSZxc&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;The US Unemployment Rates 2000-2016.&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;date&quot;:[9.782928E11,9.809712E11,9.833904E11,9.860652E11,9.886572E11,9.913356E11,9.939276E11,9.96606E11,9.992844E11,1.0018764E12,1.0045584E12,1.0071504E12,1.0098288E12,1.0125072E12,1.0149264E12,1.0176012E12,1.0201932E12,1.0228716E12,1.0254636E12,1.028142E12,1.0308204E12,1.0334124E12,1.0360944E12,1.0386864E12,1.0413648E12,1.0440432E12,1.0464624E12,1.0491372E12,1.0517292E12,1.0544076E12,1.0569996E12,1.059678E12,1.0623564E12,1.0649484E12,1.0676304E12,1.0702224E12,1.0729008E12,1.0755792E12,1.0780848E12,1.0807596E12,1.0833516E12,1.08603E12,1.088622E12,1.0913004E12,1.0939788E12,1.0965708E12,1.0992528E12,1.1018448E12,1.1045232E12,1.1072016E12,1.1096208E12,1.1122956E12,1.1148876E12,1.117566E12,1.120158E12,1.1228364E12,1.1255148E12,1.1281068E12,1.1307888E12,1.1333808E12,1.1360592E12,1.1387376E12,1.1411568E12,1.1438316E12,1.1464236E12,1.149102E12,1.151694E12,1.1543724E12,1.1570508E12,1.1596428E12,1.1623248E12,1.1649168E12,1.1675952E12,1.1702736E12,1.1726928E12,1.1753676E12,1.1779596E12,1.180638E12,1.18323E12,1.1859084E12,1.1885868E12,1.1911788E12,1.1938608E12,1.1964528E12,1.1991312E12,1.2018096E12,1.2043152E12,1.20699E12,1.209582E12,1.2122604E12,1.2148524E12,1.2175308E12,1.2202092E12,1.2228012E12,1.2254832E12,1.2280752E12,1.2307536E12,1.233432E12,1.2358512E12,1.238526E12,1.241118E12,1.2437964E12,1.2463884E12,1.2490668E12,1.2517452E12,1.2543372E12,1.2570192E12,1.2596112E12,1.2622896E12,1.264968E12,1.2673872E12,1.270062E12,1.272654E12,1.2753324E12,1.2779244E12,1.2806028E12,1.2832812E12,1.2858732E12,1.2885552E12,1.2911472E12,1.2938256E12,1.296504E12,1.2989232E12,1.301598E12,1.30419E12,1.3068684E12,1.3094604E12,1.3121388E12,1.3148172E12,1.3174092E12,1.3200912E12,1.3226832E12,1.3253616E12,1.32804E12,1.3305456E12,1.333224E12,1.335816E12,1.3384944E12,1.3410864E12,1.3437648E12,1.3464432E12,1.3490352E12,1.3517136E12,1.3543056E12,1.356984E12,1.3596624E12,1.3620816E12,1.36476E12,1.367352E12,1.3700304E12,1.3726224E12,1.3753008E12,1.3779792E12,1.3805712E12,1.3832496E12,1.3858416E12,1.38852E12,1.3911984E12,1.3936176E12,1.396296E12,1.398888E12,1.4015664E12,1.4041584E12,1.4068368E12,1.4095152E12,1.4121072E12,1.4147856E12,1.4173776E12,1.420056E12,1.4227344E12,1.4251536E12,1.427832E12],
// &quot;uempmed&quot;:[5.8,6.1,6.6,5.9,6.3,6.0,6.8,6.9,7.2,7.3,7.7,8.2,8.4,8.3,8.4,8.9,9.5,11.0,8.9,9.0,9.5,9.6,9.3,9.6,9.6,9.5,9.7,10.2,9.9,11.5,10.3,10.1,10.2,10.4,10.3,10.4,10.6,10.2,10.2,9.5,9.9,11.0,8.9,9.2,9.6,9.5,9.7,9.5,9.4,9.2,9.3,9.0,9.1,9.0,8.8,9.2,8.4,8.6,8.5,8.7,8.6,9.1,8.7,8.4,8.5,7.3,8.0,8.4,8.0,7.9,8.3,7.5,8.3,8.5,9.1,8.6,8.2,7.7,8.7,8.8,8.7,8.4,8.6,8.4,9.0,8.7,8.7,9.4,7.9,9.0,9.7,9.7,10.2,10.4,9.8,10.5,10.7,11.7,12.3,13.1,14.2,17.2,16.0,16.3,17.8,18.9,19.8,20.1,20.0,19.9,20.4,22.1,22.3,25.2,22.3,21.0,20.3,21.2,21.0,21.9,21.5,21.1,21.5,20.9,21.6,22.4,22.0,22.4,22.0,20.6,20.8,20.5,20.8,19.7,19.2,19.1,19.9,20.4,17.5,18.4,18.8,19.9,18.6,17.7,15.8,17.2,17.6,17.1,17.1,17.0,16.2,16.5,16.5,16.3,17.1,17.3,15.4,15.9,15.8,15.7,14.6,13.8,13.1,12.9,13.4,13.6,13.0,12.9,13.2,12.9,12.0,11.5]
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:900.0,
// &quot;height&quot;:400.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;datetime&quot;:true,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;datetime&quot;:true,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;datetime&quot;:true,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;unemployment rate&quot;
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;date&quot;,
// &quot;y&quot;:&quot;uempmed&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;line&quot;,
// &quot;tooltips&quot;:{
// &quot;tooltip_min_width&quot;:170.0,
// &quot;tooltip_anchor&quot;:&quot;top_center&quot;,
// &quot;formats&quot;:[{
// &quot;field&quot;:&quot;date&quot;,
// &quot;format&quot;:&quot;%B %Y&quot;
// }],
// &quot;lines&quot;:[&quot;Unemployment rate:|^y %&quot;],
// &quot;disable_splitting&quot;:true
// },
// &quot;data&quot;:{
// }
// },{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;date&quot;,
// &quot;y&quot;:&quot;uempmed&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;yintercept&quot;:12.827906976744186,
// &quot;color&quot;:&quot;#ee6666&quot;,
// &quot;linetype&quot;:&quot;dashed&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;hline&quot;,
// &quot;tooltips&quot;:&quot;none&quot;,
// &quot;data&quot;:{
// }
// },{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;date&quot;,
// &quot;y&quot;:&quot;uempmed&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;x&quot;:9.782928E11,
// &quot;y&quot;:13.327906976744186,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;label&quot;:&quot;12,83 %&quot;,
// &quot;geom&quot;:&quot;text&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;column&quot;:&quot;date&quot;,
// &quot;type&quot;:&quot;datetime&quot;
// }]
// }
// };
//        var plotContainer = document.getElementById(&quot;RxSZxc&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" id=0c9dae4b-244b-41be-9b97-398ca67bce6c width="100%" height="100%" style="max-width: 900.0px; max-height: 400.0px;" viewBox="0 0 900.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pjnGszT .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjnGszT .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjnGszT .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjnGszT .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjnGszT .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjnGszT .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjnGszT .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande
