// %%
%useLatestDescriptors
%use ggdsl
// Out:
//    <div id="0VNC9z"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.5.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
// ...

// %%
var mpg_df = DataFrame.readCSV("https://raw.githubusercontent.com/JetBrains/lets-plot-kotlin/master/docs/examples/data/mpg.csv")
mpg_df.head()
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
// ...

// %%
mpg_df.create { plot {
   points {
       x(displ)
       y(hwy)
       color(drv)
   } 
} }
// Out:
//    <div id="VZaefK"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "data":{
// ...

// %%
mpg_df.create { plot {
   points {
       x(displ)
       y(hwy)
       color(drv)
   } 
   layout.title = "The plot title using 'ggtitle()'"
} }
// Out:
//    <div id="mJ3Ql4"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"The plot title using 'ggtitle()'"
// },
// "mapping":{
// },
// "data":{
// ...

// %%
mpg_df.create { plot {
   points {
       x(displ)
       y(hwy)
       color(drv)
   } 
   layout {
       title = "The plot title using 'labs()'"
   }
} }
// Out:
//    <div id="y6q8lF"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"The plot title using 'labs()'"
// },
// "mapping":{
// },
// "data":{
// ...

// %%
mpg_df.create { plot {
   points {
       x(displ)
       y(hwy)
       color(drv)
   } 
   layout {
       title = "The plot title"
       subtitle = "The plot subtitle"
   }
} }
// Out:
//    <div id="lPRC3D"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"The plot title",
// "subtitle":"The plot subtitle"
// },
// "mapping":{
// },
// "data":{
// ...

// %%
mpg_df.create { plot {
   points {
       x(displ)
       y(hwy)
       color(drv)
   } 
   layout {
       title = "The plot title"
       subtitle = "The plot subtitle"
   }
} }
// Out:
//    <div id="1OGyJo"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"The plot title",
// "subtitle":"The plot subtitle"
// },
// "mapping":{
// },
// "data":{
// ...

// %%
mpg_df.create { plot {
   points {
       x(displ)
       y(hwy)
       color(drv)
   } 
   layout {
       title = "The plot title"
       subtitle = "The plot subtitle"
       caption = "The plot caption"
   }
} }
// Out:
//    <div id="hsdb1Z"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"The plot title",
// "subtitle":"The plot subtitle"
// },
// "mapping":{
// },
// "data":{
// ...

// %%
mpg_df.create { plot {
   points {
       x(displ)
       y(hwy)
       color(drv)
   } 
   layout {
       title = "The plot title"
       subtitle = "The plot subtitle"
       caption = "The plot caption"
       theme {
           global.title {
               color = Color.BLUE
           }
       }
   }
} }
// Out:
//    <div id="Hv7J84"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"The plot title",
// "subtitle":"The plot subtitle"
// },
// "mapping":{
// },
// "data":{
// ...

// %%
mpg_df.create { plot {
   points {
       x(displ)
       y(hwy)
       color(drv)
   } 
   layout {
       title = "The plot title"
       subtitle = "The plot subtitle"
       caption = "The plot caption"
       theme {
           global {
               text {
                   font = FontFace.ITALIC
               }
               title {
                   font = FontFace.ITALIC
               }
           }
           plotCanvas {
               title {
                   color = Color.BLUE
               }
               subtitle {
                   font = FontFace.ITALIC
               }
               caption {
                   font = FontFace.ITALIC
               }
           }
       }
   }
} }
// Out:
//    <div id="5Lcit8"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"The plot title",
// "subtitle":"The plot subtitle"
// },
// "mapping":{
// },
// "data":{
// ...

// %%
mpg_df.create { plot {
   points {
       x(displ)
       y(hwy)
       color(drv)
   } 
   layout {
       title = "The plot title"
       subtitle = "The plot subtitle"
       caption = "The plot caption"
       theme {
           plotCanvas {
               title {
                   color = Color.BLUE
               }
               subtitle {
                   color = Color.RED
               }
               caption {
                   color = Color.named("dark_green")
               }
           }
       }
   }
} }
// Out:
//    <div id="PRKipy"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"The plot title",
// "subtitle":"The plot subtitle"
// },
// "mapping":{
// },
// "data":{
// ...

// %%
mpg_df.create { plot {
   points {
       x(displ)
       y(hwy)
       color(drv)
   } 
   layout {
       title = "The plot title:\nFuel efficiency for most popular models of car"
       subtitle = "The plot subtitle:\nPoints are colored by the type of drive train"
       caption = "The plot caption:\nmpg dataset"
       theme {
           plotCanvas {
               subtitle {
                   color = Color.named("gray")
               }
               caption {
                   color = Color.named("light_gray")
               }
           }
       }
   }
} }
// Out:
//    <div id="0cEkri"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"The plot title:\nFuel efficiency for most popular models of car",
// "subtitle":"The plot subtitle:\nPoints are colored by the type of drive train"
// },
// "mapping":{
// },
// "data":{
// ...

// %%
mpg_df.create { plot {
    points {
        x(displ)
        y(hwy)
        color(cty).with { legend.name = "City mileage" }
        symbol(drv).with { legend.name = "Drive type" }
        size(4.0)  
    }
} }
// Out:
//    <div id="sgAqGT"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "data":{
// ...

// %%
mpg_df.create { plot {
    points {
        x(displ)
        y(hwy)
        color(cty).with { legend.name = "City mileage" }
        symbol(drv).with { legend.name = "Drive type" }
        size(4.0)  
    }
    layout.theme { 
        legend.position = LegendPosition.Bottom
    }
} }
// Out:
//    <div id="tZHeKN"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "data":{
// ...

// %%
mpg_df.create { plot {
    points {
        x(displ)
        y(hwy)
        color(cty).with { legend.name = "City mileage\n(mpg)" }
        symbol(drv).with { legend.name = "Drive type\n(front/4/rear wheel)" }
        size(4.0)  
    }
} }
// Out:
//    <div id="mt26qP"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "data":{
// ...

// %%
mpg_df.create { plot {
    points {
        x(displ)
        y(hwy)
        color(cty).with { legend.name = "City mileage\n(mpg)" }
        symbol(drv).with { legend.name = "Drive type\n(front/4/rear wheel)" }
        size(4.0)  
    }
    layout.theme { 
        legend.position = LegendPosition.Bottom
    }
} }
// Out:
//    <div id="9g7OBc"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "data":{
// ...

// %%
mpg_df.create { plot {
    points {
        x(displ)
        y(hwy)
        color(cty).with { legend.name = "City mileage\n(mpg)" }
        symbol(drv).with { legend {
            type = discreteLegend(nRow = 3)
            name = "Drive type\n(front/4/rear wheel)" 
        } }
        size(4.0)  
    }
    layout.theme { 
        legend.position = LegendPosition.Bottom
    }
} }
// Out:
//    <div id="ykyMhp"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "data":{
// ...
