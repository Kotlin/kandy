// %%
%useLatestDescriptors
%use dataframe, kandy

// %%
val country by columnOf(
    "Australia", "Canada", "China", "Cuba", "Finland", "France", "Germany",
    "Iceland", "India", "Japan", "North Korea", "South Korea", "New Zealand",
    "Norway", "Poland", "Russia", "Turkey", "United Kingdom", "United States"
)
val lifeExp1998 = columnOf(
    75.49, 76.03, 66.35, 58.75, 79.64, 82.92, 80.68,
    70.71, 60.30, 82.78, 69.57, 74.61, 71.18,
    71.43, 75.22, 72.65, 74.56, 75.19, 81.12
) named "lifeExp"
val pop1998 = columnOf(
    19000, 30000, 1250000, 11000, 5000,
    59000, 82000, 280, 950000, 126000,
    24000, 47000, 3800, 4400, 38600,
    147000, 63000, 59000, 273000
) named "population"
val gdpPerCapita1998 = columnOf(
    29000, 32000, 750, 5000, 28000,
    27000, 32000, 34000, 450, 33000,
    600, 12000, 22000, 40000, 9000,
    4000, 3000, 28000, 35000
) named "gdp"
val data1998 = dataFrameOf(country, lifeExp1998, pop1998, gdpPerCapita1998).add("year") { 1998 }

val lifeExp2023 = columnOf(
    79.44, 73.60, 70.46, 63.34, 72.10, 78.15, 80.70,
    79.88, 63.13, 81.53, 59.33, 71.59, 76.56,
    71.97, 78.21, 78.38, 79.76, 84.77, 82.39
) named "lifeExp"
val pop2023 = columnOf(
    25000, 38000, 1400000, 11300, 5500,
    67000, 83000, 340, 1350000, 126000,
    25000, 51000, 5000, 5300, 38000,
    146000, 82000, 67000, 331000
) named "population"
val gdpPerCapita2023 = columnOf(
    55000, 52000, 10000, 7000, 48000,
    44000, 50000, 60000, 2000, 45000,
    1200, 30000, 34000, 70000, 15000,
    9000, 10000, 40000, 60000
) named "gdp"
val data2023 = dataFrameOf(country, lifeExp2023, pop2023, gdpPerCapita2023).add("year") { 2023 }

val dataset = data1998.fullJoin(data2023)

// %%
dataset.groupBy { year }.plot {
    layout.title = "Life Expectancy and GDP by Country"
    points {
        x(gdp) { axis.name = "GDP per capita (in dollars)" }
        y(lifeExp) { axis.name = "Life expectancy (years)" }
        size(population) {
            legend.type = LegendType.None
            scale = continuous(5.0..20.0)
        }
        color(year) {
            legend {
                name = ""
                breaks(format = "d")
            }
        }
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;nqVD7N&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Life Expectancy and GDP by Country&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;gdp&quot;:[29000.0,32000.0,750.0,5000.0,28000.0,27000.0,32000.0,34000.0,450.0,33000.0,600.0,12000.0,22000.0,40000.0,9000.0,4000.0,3000.0,28000.0,35000.0,55000.0,52000.0,10000.0,7000.0,48000.0,44000.0,50000.0,60000.0,2000.0,45000.0,1200.0,30000.0,34000.0,70000.0,15000.0,9000.0,10000.0,40000.0,60000.0],
// &quot;&amp;merged_groups&quot;:[&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;1998&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;],
// &quot;year&quot;:[1998.0,1998.0,1998.0,1998.0,1998.0,1998.0,1998.0,1998.0,1998.0,1998.0,1998.0,1998.0,1998.0,1998.0,1998.0,1998.0,1998.0,1998.0,1998.0,2023.0,2023.0,2023.0,2023.0,2023.0,2023.0,2023.0,2023.0,2023.0,2023.0,2023.0,2023.0,2023.0,2023.0,2023.0,2023.0,2023.0,2023.0,2023.0],
// &quot;lifeExp&quot;:[75.49,76.03,66.35,58.75,79.64,82.92,80.68,70.71,60.3,82.78,69.57,74.61,71.18,71.43,75.22,72.65,74.56,75.19,81.12,79.44,73.6,70.46,63.34,72.1,78.15,80.7,79.88,63.13,81.53,59.33,71.59,76.56,71.97,78.21,78.38,79.76,84.77,82.39],
// &quot;population&quot;:[19000.0,30000.0,1250000.0,11000.0,5000.0,59000.0,82000.0,280.0,950000.0,126000.0,24000.0,47000.0,3800.0,4400.0,38600.0,147000.0,63000.0,59000.0,273000.0,25000.0,38000.0,1400000.0,11300.0,5500.0,67000.0,83000.0,340.0,1350000.0,126000.0,25000.0,51000.0,5000.0,5300.0,38000.0,146000.0,82000.0,67000.0,331000.0]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;GDP per capita (in dollars)&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;Life expectancy (years)&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;size&quot;,
// &quot;range&quot;:[5.0,20.0],
// &quot;limits&quot;:[null,null],
// &quot;guide&quot;:&quot;none&quot;
// },{
// &quot;aesthetic&quot;:&quot;color&quot;,
// &quot;discrete&quot;:true,
// &quot;name&quot;:&quot;&quot;,
// &quot;format&quot;:&quot;d&quot;
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;gdp&quot;,
// &quot;y&quot;:&quot;lifeExp&quot;,
// &quot;size&quot;:&quot;population&quot;,
// &quot;color&quot;:&quot;year&quot;,
// &quot;group&quot;:&quot;&amp;merged_groups&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;point&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;int&quot;,
// &quot;column&quot;:&quot;year&quot;
// },{
// &quot;type&quot;:&quot;int&quot;,
// &quot;column&quot;:&quot;gdp&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;lifeExp&quot;
// },{
// &quot;type&quot;:&quot;int&quot;,
// &quot;column&quot;:&quot;population&quot;
// },{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;&amp;merged_groups&quot;
// }]
// },
// &quot;spec_id&quot;:&quot;2&quot;
// };
//        var containerDiv = document.getElementById(&quot;nqVD7N&quot;);
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//        var options = {
//            sizing: {
//                width_mode: &quot;fixed&quot;,
//                height_mode: &quot;fixed&quot;,
//                width: 600.0,
//                height: 400.0
//            }
//        };
//        var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//        if (toolbar) {
//          toolbar.bind(fig);
//        }
//
//    // ----------
//    })();
//
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=63c44e93-df22-4c18-9f7a-ded269a1ba5a width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #psoVspZ .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #psoVspZ .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #psoVspZ .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #psoVspZ .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #psoVspZ .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #psoVspZ .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #psoVspZ .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #psoVspZ .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d3tvBkb .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #psoVspZ .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #psoVspZ .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d3tvBkb .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #psoVspZ .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #psoVspZ .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d3tvBkb .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d3tvBkb .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d3tvBkb .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="psoVspZ">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.

// %%
dataset.filter { year == 1998 }.plot {
    layout.title = "Life Expectancy and GDP by Country (1998)"
    points {
        x(gdp) { axis.name = "GDP per capita (in dollars)" }
        y(lifeExp) { axis.name = "Life expectancy (years)" }
        size(population) {
            legend.type = LegendType.None
            scale = continuous(2.0..15.0)
        }
        color(country) {
            scale = categoricalColorHue()
        }
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;fxXboi&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Life Expectancy and GDP by Country (1998)&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;country&quot;:[&quot;Australia&quot;,&quot;Canada&quot;,&quot;China&quot;,&quot;Cuba&quot;,&quot;Finland&quot;,&quot;France&quot;,&quot;Germany&quot;,&quot;Iceland&quot;,&quot;India&quot;,&quot;Japan&quot;,&quot;North Korea&quot;,&quot;South Korea&quot;,&quot;New Zealand&quot;,&quot;Norway&quot;,&quot;Poland&quot;,&quot;Russia&quot;,&quot;Turkey&quot;,&quot;United Kingdom&quot;,&quot;United States&quot;],
// &quot;gdp&quot;:[29000.0,32000.0,750.0,5000.0,28000.0,27000.0,32000.0,34000.0,450.0,33000.0,600.0,12000.0,22000.0,40000.0,9000.0,4000.0,3000.0,28000.0,35000.0],
// &quot;lifeExp&quot;:[75.49,76.03,66.35,58.75,79.64,82.92,80.68,70.71,60.3,82.78,69.57,74.61,71.18,71.43,75.22,72.65,74.56,75.19,81.12],
// &quot;population&quot;:[19000.0,30000.0,1250000.0,11000.0,5000.0,59000.0,82000.0,280.0,950000.0,126000.0,24000.0,47000.0,3800.0,4400.0,38600.0,147000.0,63000.0,59000.0,273000.0]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;GDP per capita (in dollars)&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;Life expectancy (years)&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;size&quot;,
// &quot;range&quot;:[2.0,15.0],
// &quot;limits&quot;:[null,null],
// &quot;guide&quot;:&quot;none&quot;
// },{
// &quot;aesthetic&quot;:&quot;color&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_hue&quot;
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;gdp&quot;,
// &quot;y&quot;:&quot;lifeExp&quot;,
// &quot;size&quot;:&quot;population&quot;,
// &quot;color&quot;:&quot;country&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;point&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;int&quot;,
// &quot;column&quot;:&quot;gdp&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;lifeExp&quot;
// },{
// &quot;type&quot;:&quot;int&quot;,
// &quot;column&quot;:&quot;population&quot;
// },{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;country&quot;
// }]
// },
// &quot;spec_id&quot;:&quot;5&quot;
// };
//        var containerDiv = document.getElementById(&quot;fxXboi&quot;);
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//        var options = {
//            sizing: {
//                width_mode: &quot;fixed&quot;,
//                height_mode: &quot;fixed&quot;,
//                width: 600.0,
//                height: 400.0
//            }
//        };
//        var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//        if (toolbar) {
//          toolbar.bind(fig);
//        }
//
//    // ----------
//    })();
//
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=56846423-ee16-4495-bb92-f320d41a0451 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pgOi4Aw .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pgOi4Aw .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pgOi4Aw .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pgOi4Aw .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pgOi4Aw .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pgOi4Aw .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pgOi4Aw .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pgOi4Aw .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dxYWSlk .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pgOi4Aw .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pgOi4Aw .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dxYWSlk .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pgOi4Aw .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pgOi4Aw .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dxYWSlk .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dxYWSlk .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dxYWSlk .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pgOi4Aw">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 26.5 ) ">
//       <g>
//         <g transform="translate(21.961210910936405 0.0 ) ">
//           <g>
//             <line x1="13.512400117895606" y1="0.0" x2="13.512400117895606" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="101.97328468677028" y1="0.0" x2="101.97328468677028" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="190.43416925564495" y1="0.0" x2="190.43416925564495" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="278.8950538245196" y1="0.0" x2="278.8950538245196" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="367.3559383933943" y1="0.0" x2="367.3559383933943" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transf

// %%
dataset.filter { year == 2023 }.plot {
    layout.title = "Life Expectancy and GDP by Country (2023)"
    points {
        x(gdp) { axis.name = "GDP per capita (in dollars)" }
        y(lifeExp) { axis.name = "Life expectancy (years)" }
        size(population) {
            legend.type = LegendType.None
            scale = continuous(2.0..15.0)
        }
        color(country) {
            scale = categoricalColorHue()
        }
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;Yuls50&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Life Expectancy and GDP by Country (2023)&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;country&quot;:[&quot;Australia&quot;,&quot;Canada&quot;,&quot;China&quot;,&quot;Cuba&quot;,&quot;Finland&quot;,&quot;France&quot;,&quot;Germany&quot;,&quot;Iceland&quot;,&quot;India&quot;,&quot;Japan&quot;,&quot;North Korea&quot;,&quot;South Korea&quot;,&quot;New Zealand&quot;,&quot;Norway&quot;,&quot;Poland&quot;,&quot;Russia&quot;,&quot;Turkey&quot;,&quot;United Kingdom&quot;,&quot;United States&quot;],
// &quot;gdp&quot;:[55000.0,52000.0,10000.0,7000.0,48000.0,44000.0,50000.0,60000.0,2000.0,45000.0,1200.0,30000.0,34000.0,70000.0,15000.0,9000.0,10000.0,40000.0,60000.0],
// &quot;lifeExp&quot;:[79.44,73.6,70.46,63.34,72.1,78.15,80.7,79.88,63.13,81.53,59.33,71.59,76.56,71.97,78.21,78.38,79.76,84.77,82.39],
// &quot;population&quot;:[25000.0,38000.0,1400000.0,11300.0,5500.0,67000.0,83000.0,340.0,1350000.0,126000.0,25000.0,51000.0,5000.0,5300.0,38000.0,146000.0,82000.0,67000.0,331000.0]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;GDP per capita (in dollars)&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;Life expectancy (years)&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;size&quot;,
// &quot;range&quot;:[2.0,15.0],
// &quot;limits&quot;:[null,null],
// &quot;guide&quot;:&quot;none&quot;
// },{
// &quot;aesthetic&quot;:&quot;color&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_hue&quot;
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;gdp&quot;,
// &quot;y&quot;:&quot;lifeExp&quot;,
// &quot;size&quot;:&quot;population&quot;,
// &quot;color&quot;:&quot;country&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;point&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;int&quot;,
// &quot;column&quot;:&quot;gdp&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;lifeExp&quot;
// },{
// &quot;type&quot;:&quot;int&quot;,
// &quot;column&quot;:&quot;population&quot;
// },{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;country&quot;
// }]
// },
// &quot;spec_id&quot;:&quot;8&quot;
// };
//        var containerDiv = document.getElementById(&quot;Yuls50&quot;);
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//        var options = {
//            sizing: {
//                width_mode: &quot;fixed&quot;,
//                height_mode: &quot;fixed&quot;,
//                width: 600.0,
//                height: 400.0
//            }
//        };
//        var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//        if (toolbar) {
//          toolbar.bind(fig);
//        }
//
//    // ----------
//    })();
//
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=0fefe850-14dd-430c-97cd-c6472e6d6feb width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pj1Z4qv .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pj1Z4qv .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pj1Z4qv .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pj1Z4qv .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pj1Z4qv .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pj1Z4qv .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pj1Z4qv .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pj1Z4qv .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dhUCWfB .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pj1Z4qv .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pj1Z4qv .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dhUCWfB .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pj1Z4qv .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pj1Z4qv .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dhUCWfB .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dhUCWfB .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dhUCWfB .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pj1Z4qv">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 26.5 ) ">
//       <g>
//         <g transform="translate(21.961210910936405 0.0 ) ">
//           <g>
//             <line x1="11.390881810647885" y1="0.0" x2="11.390881810647885" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="113.09518369143257" y1="0.0" x2="113.09518369143257" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="214.79948557221726" y1="0.0" x2="214.79948557221726" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="316.50378745300196" y1="0.0" x2="316.50378745300196" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(21.961210910936405 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="298.723627787307" x2="384.8490783168893" y2="298.723627787307" stroke="rgb(233,233,233)"
