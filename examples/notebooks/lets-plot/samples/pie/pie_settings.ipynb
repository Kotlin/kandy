// %% [markdown]
// # Pie Settings

// %%
%useLatestDescriptors
%use dataframe, kandy

// %%
val language by columnOf("Kotlin", "Java", "C++", "JavaScript", "C#", "Other")
val users by columnOf(563, 481, 202, 406, 150, 312)
val usersLanguages = dataFrameOf(language, users)

// %%
usersLanguages.plot { 
    pie { 
        slice(users)
        fillColor(language) {
            scale = categorical(
                "Kotlin" to Color.hex("#1E88E5"),
                "Java" to Color.hex("#D32F2F"),
                "C++" to Color.hex("#7B1FA2"),
                "JavaScript" to Color.hex("#FBC02D"),
                "C#" to Color.hex("#388E3C"),
                "Other" to Color.hex("#757575")
            )
        }
        size = 33.0
        hole = 0.8
        alpha = 0.8
    }
    layout.style(Style.Void)
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;dvgFsm&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;language&quot;:[&quot;Kotlin&quot;,&quot;Java&quot;,&quot;C++&quot;,&quot;JavaScript&quot;,&quot;C#&quot;,&quot;Other&quot;],
// &quot;users&quot;:[563.0,481.0,202.0,406.0,150.0,312.0]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;values&quot;:[&quot;#1E88E5&quot;,&quot;#D32F2F&quot;,&quot;#7B1FA2&quot;,&quot;#FBC02D&quot;,&quot;#388E3C&quot;,&quot;#757575&quot;],
// &quot;limits&quot;:[&quot;Kotlin&quot;,&quot;Java&quot;,&quot;C++&quot;,&quot;JavaScript&quot;,&quot;C#&quot;,&quot;Other&quot;]
// }],
// &quot;layers&quot;:[{
// &quot;hole&quot;:0.8,
// &quot;mapping&quot;:{
// &quot;slice&quot;:&quot;users&quot;,
// &quot;fill&quot;:&quot;language&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:33.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;alpha&quot;:0.8,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;theme&quot;:{
// &quot;name&quot;:&quot;classic&quot;,
// &quot;axis&quot;:{
// &quot;blank&quot;:true
// },
// &quot;line&quot;:{
// &quot;blank&quot;:true
// },
// &quot;axis_ontop&quot;:false,
// &quot;axis_ontop_y&quot;:false,
// &quot;axis_ontop_x&quot;:false
// },
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;int&quot;,
// &quot;column&quot;:&quot;users&quot;
// },{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;language&quot;
// }]
// },
// &quot;spec_id&quot;:&quot;2&quot;
// };
//        var containerDiv = document.getElementById(&quot;dvgFsm&quot;);
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//        var options = {
//            sizing: {
//                width_mode: &quot;fixed&quot;,
//                height_mode: &quot;fixed&quot;,
//                width: 600.0,
//                height: 400.0
//            }
//        };
//        var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
