// %%
%useLatestDescriptors
%use kandy

// %%
val days = listOf(
    "Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun", "Sun",
    "Sat", "Thu", "Fri", "Tue", "Wed", "Sun", "Mon", "Thu",
    "Sun", "Sat", "Tue", "Mon", "Thu", "Wed", "Fri", "Sat",
    "Tue", "Sun", "Fri", "Sat", "Thu", "Mon", "Wed", "Tue",
    "Thu", "Mon", "Sun", "Fri", "Wed", "Sat", "Tue", "Thu",
    "Sat", "Tue", "Sun", "Mon", "Wed", "Fri", "Thu", "Sat",
    "Thu", "Fri", "Sun", "Tue", "Sat", "Wed", "Mon", "Thu",
    "Wed", "Tue", "Sat", "Fri", "Sun", "Thu", "Mon", "Tue",
    "Fri", "Thu", "Wed", "Sun", "Sat", "Mon", "Tue", "Thu",
    "Tue", "Wed", "Sun", "Mon", "Thu", "Sat", "Fri", "Tue",
    "Thu", "Sun", "Fri", "Sat", "Mon", "Wed", "Tue", "Thu",
    "Sat", "Mon", "Tue", "Thu", "Fri", "Sun", "Wed", "Sat",
    "Sun", "Fri", "Tue", "Thu", "Sat", "Mon", "Wed", "Sun",
    "Mon", "Wed", "Sat", "Fri", "Thu", "Tue", "Sun", "Sat",
)
val drinks = listOf(
    "soda", "tea", "coffee", "tea", "soda", "tea", "coffee", "soda",
    "coffee", "soda", "tea", "coffee", "soda", "tea", "coffee", "tea",
    "coffee", "soda", "tea", "soda", "coffee", "tea", "soda", "coffee",
    "soda", "tea", "coffee", "tea", "soda", "coffee", "tea", "soda",
    "tea", "soda", "coffee", "tea", "soda", "coffee", "soda", "tea",
    "coffee", "soda", "tea", "soda", "coffee", "tea", "soda", "coffee",
    "soda", "coffee", "tea", "soda", "coffee", "soda", "tea", "coffee",
    "soda", "coffee", "tea", "soda", "tea", "soda", "coffee", "tea",
    "tea", "coffee", "soda", "tea", "coffee", "soda", "tea", "soda",
    "tea", "soda", "coffee", "soda", "tea", "coffee", "soda", "coffee",
    "tea", "coffee", "soda", "tea", "soda", "coffee", "soda", "tea",
    "coffee", "soda", "tea", "coffee", "tea", "soda", "coffee", "soda",
    "soda", "tea", "coffee", "soda", "tea", "coffee", "soda", "tea",
    "coffee", "tea", "soda", "coffee", "tea", "soda", "coffee", "soda"
)

plot {
    heatmap(days, drinks)
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;5ZNodV&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;x&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_gradient&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;x&quot;,
// &quot;y&quot;:&quot;y&quot;,
// &quot;fill&quot;:&quot;count&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;data&quot;:{
// &quot;x&quot;:[&quot;Mon&quot;,&quot;Tue&quot;,&quot;Wed&quot;,&quot;Thu&quot;,&quot;Fri&quot;,&quot;Sat&quot;,&quot;Sun&quot;,&quot;Sun&quot;,&quot;Sat&quot;,&quot;Thu&quot;,&quot;Fri&quot;,&quot;Tue&quot;,&quot;Wed&quot;,&quot;Sun&quot;,&quot;Mon&quot;,&quot;Sat&quot;,&quot;Thu&quot;,&quot;Wed&quot;,&quot;Tue&quot;,&quot;Fri&quot;,&quot;Mon&quot;],
// &quot;count&quot;:[8.0,6.0,4.0,8.0,5.0,5.0,6.0,3.0,9.0,7.0,6.0,4.0,7.0,7.0,5.0,4.0,4.0,3.0,7.0,3.0,1.0],
// &quot;y&quot;:[&quot;soda&quot;,&quot;tea&quot;,&quot;coffee&quot;,&quot;tea&quot;,&quot;soda&quot;,&quot;tea&quot;,&quot;coffee&quot;,&quot;soda&quot;,&quot;coffee&quot;,&quot;soda&quot;,&quot;tea&quot;,&quot;coffee&quot;,&quot;soda&quot;,&quot;tea&quot;,&quot;coffee&quot;,&quot;soda&quot;,&quot;coffee&quot;,&quot;tea&quot;,&quot;soda&quot;,&quot;coffee&quot;,&quot;tea&quot;]
// },
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;tile&quot;,
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;x&quot;
// },{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;y&quot;
// },{
// &quot;type&quot;:&quot;int&quot;,
// &quot;column&quot;:&quot;count&quot;
// }]
// }
// }],
// &quot;spec_id&quot;:&quot;2&quot;
// };
//        var containerDiv = document.getElementById(&quot;5ZNodV&quot;);
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//        var options = {
//            sizing: {
//                width_mode: &quot;fixed&quot;,
//                height_mode: &quot;fixed&quot;,
//                width: 600.0,
//                height: 400.0
//            }
//        };
//        var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//        if (toolbar) {
//          toolbar.bind(fig);
//        }
//
//    // ----------
//    })();
//
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=fb9a3925-5ca0-48a5-ad92-a56a53a8f4b8 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #p9k12JQ .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #p9k12JQ .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p9k12JQ .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p9k12JQ .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #p9k12JQ .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p9k12JQ .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p9k12JQ .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p9k12JQ .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dWrif9z .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p9k12JQ .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p9k12JQ .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dWrif9z .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p9k12JQ .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p9k12JQ .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dWrif9z .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dWrif9z .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dWrif9z .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="p9k12JQ">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 65.22795793432942 L0.0 334.7720420656706 L600.0 334.7720420656706 L600.0 65.22795793432942 Z">
//     </path>
//     <g transform="translate(29.5 71.72795793432942 ) ">
//       <g>
//         <g transform="translate(48.06940244056283 0.0 ) ">
//           <g>
//             <line x1="43.34731143880552" y1="0.0" x2="43.34731143880552" y2="210.54408413134115" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="105.27204206567055" y1="0.0" x2="105.27204206567055" y2="210.54408413134115" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="167.1967726925356" y1="0.0" x2="167.1967726925356" y2="210.54408413134115" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="229.12150331940063" y1="0.0" x2="229.12150331940063" y2="210.54408413134115" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="291.04623394626566" y1="0.0" x2="291.04623394626566" y2="210.54408413134115" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="352.9709645731307" y1="0.0" x2="352.9709645731307" y2="210.54408413134115" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="414.895695
