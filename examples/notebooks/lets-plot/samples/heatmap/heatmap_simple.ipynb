// %%
%useLatestDescriptors
%use kandy

// %%
val days = listOf(
    "Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun", "Sun",
    "Sat", "Thu", "Fri", "Tue", "Wed", "Sun", "Mon", "Thu",
    "Sun", "Sat", "Tue", "Mon", "Thu", "Wed", "Fri", "Sat",
    "Tue", "Sun", "Fri", "Sat", "Thu", "Mon", "Wed", "Tue",
    "Thu", "Mon", "Sun", "Fri", "Wed", "Sat", "Tue", "Thu",
    "Sat", "Tue", "Sun", "Mon", "Wed", "Fri", "Thu", "Sat",
    "Thu", "Fri", "Sun", "Tue", "Sat", "Wed", "Mon", "Thu",
    "Wed", "Tue", "Sat", "Fri", "Sun", "Thu", "Mon", "Tue",
    "Fri", "Thu", "Wed", "Sun", "Sat", "Mon", "Tue", "Thu",
    "Tue", "Wed", "Sun", "Mon", "Thu", "Sat", "Fri", "Tue",
    "Thu", "Sun", "Fri", "Sat", "Mon", "Wed", "Tue", "Thu",
    "Sat", "Mon", "Tue", "Thu", "Fri", "Sun", "Wed", "Sat",
    "Sun", "Fri", "Tue", "Thu", "Sat", "Mon", "Wed", "Sun",
    "Mon", "Wed", "Sat", "Fri", "Thu", "Tue", "Sun", "Sat",
)
val drinks = listOf(
    "soda", "tea", "coffee", "tea", "soda", "tea", "coffee", "soda",
    "coffee", "soda", "tea", "coffee", "soda", "tea", "coffee", "tea",
    "coffee", "soda", "tea", "soda", "coffee", "tea", "soda", "coffee",
    "soda", "tea", "coffee", "tea", "soda", "coffee", "tea", "soda",
    "tea", "soda", "coffee", "tea", "soda", "coffee", "soda", "tea",
    "coffee", "soda", "tea", "soda", "coffee", "tea", "soda", "coffee",
    "soda", "coffee", "tea", "soda", "coffee", "soda", "tea", "coffee",
    "soda", "coffee", "tea", "soda", "tea", "soda", "coffee", "tea",
    "tea", "coffee", "soda", "tea", "coffee", "soda", "tea", "soda",
    "tea", "soda", "coffee", "soda", "tea", "coffee", "soda", "coffee",
    "tea", "coffee", "soda", "tea", "soda", "coffee", "soda", "tea",
    "coffee", "soda", "tea", "coffee", "tea", "soda", "coffee", "soda",
    "soda", "tea", "coffee", "soda", "tea", "coffee", "soda", "tea",
    "coffee", "tea", "soda", "coffee", "tea", "soda", "coffee", "soda"
)

plot {
    heatmap(days, drinks)
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;diIS9H&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;x&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;scale_mapper_kind&quot;:&quot;color_gradient&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;x&quot;,
// &quot;y&quot;:&quot;y&quot;,
// &quot;fill&quot;:&quot;count&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;data&quot;:{
// &quot;x&quot;:[&quot;Mon&quot;,&quot;Tue&quot;,&quot;Wed&quot;,&quot;Thu&quot;,&quot;Fri&quot;,&quot;Sat&quot;,&quot;Sun&quot;,&quot;Sun&quot;,&quot;Sat&quot;,&quot;Thu&quot;,&quot;Fri&quot;,&quot;Tue&quot;,&quot;Wed&quot;,&quot;Sun&quot;,&quot;Mon&quot;,&quot;Sat&quot;,&quot;Thu&quot;,&quot;Wed&quot;,&quot;Tue&quot;,&quot;Fri&quot;,&quot;Mon&quot;],
// &quot;count&quot;:[8.0,6.0,4.0,8.0,5.0,5.0,6.0,3.0,9.0,7.0,6.0,4.0,7.0,7.0,5.0,4.0,4.0,3.0,7.0,3.0,1.0],
// &quot;y&quot;:[&quot;soda&quot;,&quot;tea&quot;,&quot;coffee&quot;,&quot;tea&quot;,&quot;soda&quot;,&quot;tea&quot;,&quot;coffee&quot;,&quot;soda&quot;,&quot;coffee&quot;,&quot;soda&quot;,&quot;tea&quot;,&quot;coffee&quot;,&quot;soda&quot;,&quot;tea&quot;,&quot;coffee&quot;,&quot;soda&quot;,&quot;coffee&quot;,&quot;tea&quot;,&quot;soda&quot;,&quot;coffee&quot;,&quot;tea&quot;]
// },
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;tile&quot;
// }]
// };
//        var plotContainer = document.getElementById(&quot;diIS9H&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" id=a501b901-e1f7-4b91-8096-4820af1cb256 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pRS9FdA .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pRS9FdA .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pRS9FdA .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pRS9FdA .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pRS9FdA .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pRS9FdA .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pRS9FdA .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dH03yv3 .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pRS9FdA .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pRS9FdA .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dH03yv3 .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pRS9FdA .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pRS9FdA .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dH03yv3 .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dH03yv3 .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dH03yv3 .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pRS9FdA">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(23.0 77.1874173937889 ) ">
//       <g transform="translate(48.06940244056283 0.0 ) ">
//         <line x1="43.15812224961633" y1="209.62516521242222" x2="43.15812224961633" y2="2.8421709430404007E-14" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//         </line>
//         <line x1="104.8125826062111" y1="209.62516521242222" x2="104.8125826062111" y2="2.8421709430404007E-14" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//         </line>
//         <line x1="166.46704296280586" y1="209.62516521242222" x2="166.46704296280586" y2="2.8421709430404007E-14" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//         </line>
//         <line x1="228.1215033194006" y1="209.62516521242222" x2="228.1215033194006" y2="2.8421709430404007E-14" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//         </line>
//         <line x1="289.7759636759954" y1="209.62516521242222" x2="289.7759636759954" y2="2.8421709430404007E-14" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//         </line>
//         <line x1="351.4304240325901" y1="209.62516521242222" x2="351.4304240325901" y2="2.8421709430404007E-14" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//         </line>
//         <line x1="413.0848843891849" y1="209.62516521242222" x2="413.0848843891849" y2="2.8421709430404007E-14" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//         </line>
//       </g>
//       <g transform="translate(48.06940244056283 209.62516521242222 ) ">
//         <g transform="translate(43.15812224961633 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//               <tspan>Mon</tspan>
//             </text>
//           </g>
//         </g>
//         <g transform="translate(104.8125826062111 0.0 ) ">
//           <line stroke-width="1.0"
