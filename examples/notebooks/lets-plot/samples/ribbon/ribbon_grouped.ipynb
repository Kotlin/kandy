// %%
%use dataframe, kandy

// %%
val times = listOf("00:00", "06:00", "12:00", "18:00", "24:00")
val btcMin = listOf(310, 225, 202, 278, 360)
val btcMax = listOf(334, 307, 243, 293, 388)
val ethMin = listOf(180, 205, 256, 300, 280)
val ethMax = listOf(210, 234, 299, 322, 331)

val dataset = dataFrameOf(
    "time" to times + times,
    "min" to btcMin + ethMin,
    "max" to btcMax + ethMax,
    "currency" to List(5) { "btc" } + List(5) { "eth" }
)

// %%
dataset.groupBy("currency").plot { 
    ribbon { 
        x("time")
        y {
            limits = 170..400
            axis.name = "price, tokens"
        }
        yMin("min")
        yMax("max")
        fillColor("currency") {
            legend.breaksLabeled("btc" to "Bubble Tea\nCoin", "eth" to "E-Traders\nHedgehogs")
        }
        alpha = 0.6
        borderLine.width = 0.0
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.0.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;MxbmgW&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;&amp;merged_groups&quot;:[&quot;btc&quot;,&quot;btc&quot;,&quot;btc&quot;,&quot;btc&quot;,&quot;btc&quot;,&quot;eth&quot;,&quot;eth&quot;,&quot;eth&quot;,&quot;eth&quot;,&quot;eth&quot;],
// &quot;min&quot;:[310.0,225.0,202.0,278.0,360.0,180.0,205.0,256.0,300.0,280.0],
// &quot;max&quot;:[334.0,307.0,243.0,293.0,388.0,210.0,234.0,299.0,322.0,331.0],
// &quot;currency&quot;:[&quot;btc&quot;,&quot;btc&quot;,&quot;btc&quot;,&quot;btc&quot;,&quot;btc&quot;,&quot;eth&quot;,&quot;eth&quot;,&quot;eth&quot;,&quot;eth&quot;,&quot;eth&quot;],
// &quot;time&quot;:[&quot;00:00&quot;,&quot;06:00&quot;,&quot;12:00&quot;,&quot;18:00&quot;,&quot;24:00&quot;,&quot;00:00&quot;,&quot;06:00&quot;,&quot;12:00&quot;,&quot;18:00&quot;,&quot;24:00&quot;]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;price, tokens&quot;,
// &quot;limits&quot;:[170.0,400.0]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;discrete&quot;:true,
// &quot;breaks&quot;:[&quot;btc&quot;,&quot;eth&quot;],
// &quot;labels&quot;:[&quot;Bubble Tea\nCoin&quot;,&quot;E-Traders\nHedgehogs&quot;]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;time&quot;,
// &quot;ymin&quot;:&quot;min&quot;,
// &quot;ymax&quot;:&quot;max&quot;,
// &quot;fill&quot;:&quot;currency&quot;,
// &quot;group&quot;:&quot;&amp;merged_groups&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:0.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;alpha&quot;:0.6,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;ribbon&quot;,
// &quot;data&quot;:{
// }
// }]
// };
//        var plotContainer = document.getElementById(&quot;MxbmgW&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>
//         <svg id=ccf827ce-83e8-499d-b006-961a948ae8c7 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="600.0" height="400.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #p9EQL53 .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9EQL53 .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9EQL53 .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9EQL53 .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9EQL53 .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9EQL53 .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9EQL53 .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dnDsXXP .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9EQL53 .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9EQL53 .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dnDsXXP .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9EQL53 .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p9EQL53 .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dnDsXXP .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dnDsXXP .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dnDsXXP .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="p9EQL53">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(23.0 10.0 ) ">
//       <g transform="translate(29.941816366404606 344.0 ) ">
//         <line x1="18.74282472128575" y1="-0.0" x2="18.74282472128575" y2="-344.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="112.45694832771449" y1="-0.0" x2="112.45694832771449" y2="-344.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="206.17107193414324" y1="-0.0" x2="206.17107193414324" y2="-344.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="299.88519554057194" y1="-0.0" x2="299.88519554057194" y2="-344.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="393.5993191470007" y1="-0.0" x2="393.5993191470007" y2="-344.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(18.74282472128575 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             00:00
//             </text>
//           </g>
//         </g>
//         <g transform="translate(112.45694832771449 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             06:00
//             </text>
//           </g>
//         </g>
//         <g transform="translate(206.17107193414324 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             12:00
//             </text>
//           </g>
//         </g>
//         <g transform="translate(299.88519554057194 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="
