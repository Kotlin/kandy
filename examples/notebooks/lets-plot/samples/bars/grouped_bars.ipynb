// %%
%useLatestDescriptors
%use kandy
%use dataframe

// %%
val dataset = dataFrameOf(
    "day" to listOf("Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"),
    "coffee" to listOf(0.81, 0.78, 0.72, 0.65, 0.73, 0.49, 0.38),
    "tea" to listOf(0.12, 0.16, 0.21, 0.26, 0.24, 0.22, 0.30),
    "soda" to listOf(0.07, 0.06, 0.07, 0.09, 0.03, 0.29, 0.32),
).gather("coffee", "tea", "soda").into("drink", "amount")

// %%
dataset.groupBy { drink }.plot {
    layout.title = "Weekly Beverage Consumption Trends"
    bars {
        x(day)
        y(amount)
        fillColor(drink) {
            scale = categorical(
                "coffee" to Color.hex("#6F4E37"),
                "tea" to Color.hex("#C2D4AB"),
                "soda" to Color.hex("#B5651D")
            )
        }
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;pW4fj1&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Weekly Beverage Consumption Trends&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;amount&quot;:[0.81,0.78,0.72,0.65,0.73,0.49,0.38,0.12,0.16,0.21,0.26,0.24,0.22,0.3,0.07,0.06,0.07,0.09,0.03,0.29,0.32],
// &quot;&amp;merged_groups&quot;:[&quot;coffee&quot;,&quot;coffee&quot;,&quot;coffee&quot;,&quot;coffee&quot;,&quot;coffee&quot;,&quot;coffee&quot;,&quot;coffee&quot;,&quot;tea&quot;,&quot;tea&quot;,&quot;tea&quot;,&quot;tea&quot;,&quot;tea&quot;,&quot;tea&quot;,&quot;tea&quot;,&quot;soda&quot;,&quot;soda&quot;,&quot;soda&quot;,&quot;soda&quot;,&quot;soda&quot;,&quot;soda&quot;,&quot;soda&quot;],
// &quot;day&quot;:[&quot;Mon&quot;,&quot;Tue&quot;,&quot;Wed&quot;,&quot;Thu&quot;,&quot;Fri&quot;,&quot;Sat&quot;,&quot;Sun&quot;,&quot;Mon&quot;,&quot;Tue&quot;,&quot;Wed&quot;,&quot;Thu&quot;,&quot;Fri&quot;,&quot;Sat&quot;,&quot;Sun&quot;,&quot;Mon&quot;,&quot;Tue&quot;,&quot;Wed&quot;,&quot;Thu&quot;,&quot;Fri&quot;,&quot;Sat&quot;,&quot;Sun&quot;],
// &quot;drink&quot;:[&quot;coffee&quot;,&quot;coffee&quot;,&quot;coffee&quot;,&quot;coffee&quot;,&quot;coffee&quot;,&quot;coffee&quot;,&quot;coffee&quot;,&quot;tea&quot;,&quot;tea&quot;,&quot;tea&quot;,&quot;tea&quot;,&quot;tea&quot;,&quot;tea&quot;,&quot;tea&quot;,&quot;soda&quot;,&quot;soda&quot;,&quot;soda&quot;,&quot;soda&quot;,&quot;soda&quot;,&quot;soda&quot;,&quot;soda&quot;]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;values&quot;:[&quot;#6F4E37&quot;,&quot;#C2D4AB&quot;,&quot;#B5651D&quot;],
// &quot;limits&quot;:[&quot;coffee&quot;,&quot;tea&quot;,&quot;soda&quot;]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;day&quot;,
// &quot;y&quot;:&quot;amount&quot;,
// &quot;fill&quot;:&quot;drink&quot;,
// &quot;group&quot;:&quot;&amp;merged_groups&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;dodge&quot;,
// &quot;geom&quot;:&quot;bar&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;drink&quot;
// },{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;day&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;amount&quot;
// },{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;&amp;merged_groups&quot;
// }]
// },
// &quot;spec_id&quot;:&quot;2&quot;
// };
//        var containerDiv = document.getElementById(&quot;pW4fj1&quot;);
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//        var options = {
//            sizing: {
//                width_mode: &quot;fixed&quot;,
//                height_mode: &quot;fixed&quot;,
//                width: 600.0,
//                height: 400.0
//            }
//        };
//        var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//        if (toolbar) {
//          toolbar.bind(fig);
//        }
//
//    // ----------
//    })();
//
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=f26ebf8e-a4a7-408e-b4b2-6e066c8ad119 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pQocpoV .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pQocpoV .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pQocpoV .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pQocpoV .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pQocpoV .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pQocpoV .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pQocpoV .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pQocpoV .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #drKZPID .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pQocpoV .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pQocpoV .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #drKZPID .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pQocpoV .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pQocpoV .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #drKZPID .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #drKZPID .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #drKZPID .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pQocpoV">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 26.5 ) ">
//       <g>
//         <g transform="translate(27.034701220281416 0.0 ) ">
//           <g>
//             <line x1="39.61660853443421" y1="0.0" x2="39.61660853443421" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="100.56523704894838" y1="0.0" x2="100.56523704894838" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="161.51386556346253" y1="0.0" x2="161.51386556346253" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="222.46249407797671" y1="0.0" x2="222.46249407797671" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <
