// %%
%useLatestDescriptors
%use kandy, dataframe, datetime

// %%
val df = dataFrameOf(
    "date" to List(10) { LocalDate(2022, 1, it + 1) },
    "open" to listOf(10.0, 15.0, 12.0, 18.0, 14.0, 16.0, 20.0, 22.0, 19.0, 25.0),
    "high" to listOf(18.0, 17.0, 20.0, 22.0, 18.0, 22.0, 25.0, 24.0, 27.0, 28.0),
    "low" to listOf(8.0, 10.0, 9.0, 11.0, 12.0, 15.0, 18.0, 17.0, 18.0, 22.0),
    "close" to listOf(15.0, 12.0, 18.0, 14.0, 16.0, 20.0, 22.0, 19.0, 25.0, 23.0),
)

df.plot {
    candlestick("date", "open", "high", "low", "close") {
        increase {
            fillColor = Color.hex("#00fefe")
            alpha = 0.9
        }
        decrease {
            fillColor = Color.hex("#ea2211")
            alpha = 0.5
        }
        borderLine.color = Color.BLACK
        width = 0.7
    }
    y.axis.name = "Price, €"
    x.axis.name = "Date"
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;yc24pU&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;date&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;datetime&quot;:true,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;values&quot;:[&quot;#00fefe&quot;,&quot;#ea2211&quot;],
// &quot;limits&quot;:[true,false],
// &quot;guide&quot;:&quot;none&quot;
// },{
// &quot;aesthetic&quot;:&quot;color&quot;,
// &quot;values&quot;:[&quot;#3ba272&quot;,&quot;#ee6666&quot;],
// &quot;limits&quot;:[true,false],
// &quot;guide&quot;:&quot;none&quot;
// },{
// &quot;aesthetic&quot;:&quot;linetype&quot;,
// &quot;values&quot;:[1.0,1.0],
// &quot;limits&quot;:[true,false],
// &quot;guide&quot;:&quot;none&quot;
// },{
// &quot;aesthetic&quot;:&quot;size&quot;,
// &quot;values&quot;:[0.6,0.6],
// &quot;limits&quot;:[true,false],
// &quot;guide&quot;:&quot;none&quot;
// },{
// &quot;aesthetic&quot;:&quot;alpha&quot;,
// &quot;values&quot;:[0.9,0.5],
// &quot;limits&quot;:[true,false],
// &quot;guide&quot;:&quot;none&quot;
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;Price, €&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;Date&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;x&quot;,
// &quot;ymin&quot;:&quot;min&quot;,
// &quot;lower&quot;:&quot;lower&quot;,
// &quot;middle&quot;:&quot;middle&quot;,
// &quot;upper&quot;:&quot;upper&quot;,
// &quot;ymax&quot;:&quot;max&quot;,
// &quot;fill&quot;:&quot;isIncreased&quot;,
// &quot;color&quot;:&quot;isIncreased&quot;,
// &quot;linetype&quot;:&quot;isIncreased&quot;,
// &quot;size&quot;:&quot;isIncreased&quot;,
// &quot;alpha&quot;:&quot;isIncreased&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;data&quot;:{
// &quot;min&quot;:[8.0,10.0,9.0,11.0,12.0,15.0,18.0,17.0,18.0,22.0],
// &quot;middle&quot;:[null,null,null,null,null,null,null,null,null,null],
// &quot;max&quot;:[18.0,17.0,20.0,22.0,18.0,22.0,25.0,24.0,27.0,28.0],
// &quot;isIncreased&quot;:[true,false,true,false,true,true,true,false,true,false],
// &quot;lower&quot;:[10.0,12.0,12.0,14.0,14.0,16.0,20.0,19.0,19.0,23.0],
// &quot;upper&quot;:[15.0,15.0,18.0,18.0,16.0,20.0,22.0,22.0,25.0,25.0],
// &quot;x&quot;:[1.6409952E12,1.6410816E12,1.641168E12,1.6412544E12,1.6413408E12,1.6414272E12,1.6415136E12,1.6416E12,1.6416864E12,1.6417728E12],
// &quot;close&quot;:[15.0,12.0,18.0,14.0,16.0,20.0,22.0,19.0,25.0,23.0],
// &quot;open&quot;:[10.0,15.0,12.0,18.0,14.0,16.0,20.0,22.0,19.0,25.0]
// },
// &quot;whisker_width&quot;:0.0,
// &quot;color&quot;:&quot;#000000&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;width&quot;:0.7,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;boxplot&quot;,
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;datetime&quot;,
// &quot;column&quot;:&quot;x&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;min&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;lower&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;upper&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;max&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;open&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;close&quot;
// },{
// &quot;type&quot;:&quot;bool&quot;,
// &quot;column&quot;:&quot;isIncreased&quot;
// }]
// },
// &quot;tooltips&quot;:{
// &quot;formats&quot;:[{
// &quot;field&quot;:&quot;x&quot;,
// &quot;format&quot;:&quot;%d/%m/%y&quot;
// },{
// &quot;field&quot;:&quot;open&quot;,
// &quot;format&quot;:&quot;.2f&quot;
// },{
// &quot;field&quot;:&quot;max&quot;,
// &quot;format&quot;:&quot;.2f&quot;
// },{
// &quot;field&quot;:&quot;min&quot;,
// &quot;format&quot;:&quot;.2f&quot;
// },{
// &quot;field&quot;:&quot;close&quot;,
// &quot;format&quot;:&quot;.2f&quot;
// }],
// &quot;title&quot;:&quot;@x&quot;,
// &quot;lines&quot;:[&quot;open|@open&quot;,&quot;high|@max&quot;,&quot;low|@min&quot;,&quot;close|@close&quot;],
// &quot;disable_splitting&quot;:true
// }
// }],
// &quot;spec_id&quot;:&quot;2&quot;
// };
//        var containerDiv = document.getElementById(&quot;yc24pU&quot;);
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//        var options = {
//            sizing: {
//                width_mode: &quot;fixed&quot;,
//                height_mode: &quot;fixed&quot;,
//                width: 600.0,
//                height: 400.0
//            }
//        };
//        var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//        if (toolbar) {
//          toolbar.bind(fig);
//        }
//
//    // ----------
//    })();
//
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=00899c2f-5636-41c2-9c6b-9bf33319b4ac width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pnhMykY .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pnhMykY .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pnhMykY .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pnhMykY .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pnhMykY .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pnhMykY .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pnhMykY .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pnhMykY .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dOowC6G .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pnhMykY .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pnhMykY .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dOowC6G .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pnhMykY .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pnhMykY .facet-
