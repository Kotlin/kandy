// %%
%useLatestDescriptors
%use kandy
%use dataframe

// %%
val dataset = dataFrameOf(
    "year" to listOf("2016", "2017", "2018", "2019", "2020", "2021"),
    "Apple" to listOf(700, 800, 750, 900, 850, 950),
    "Google" to listOf(1000, 950, 1200, 1150, 1250, 1300),
    "Microsoft" to listOf(600, 700, 650, 700, 750, 800),
    "Meta" to listOf(1100, 1200, 1150, 1300, 1250, 1350),
    "Amazon" to listOf(300, 400, 350, 450, 500, 600)
).gather("Apple", "Google", "Microsoft", "Meta", "Amazon").into("company", "users")

// %%
dataset.groupBy { company }.plot {
    layout.title = "User Growth Dynamics"
    area {
        x(year)
        y(users)
        fillColor(company) {
            scale = categorical(
                "Apple" to Color.hex("#FF45ED"),
                "Google" to Color.hex("#3DEA62"),
                "Microsoft" to Color.BLACK,
                "Meta" to Color.hex("#FDB60D"),
                "Amazon" to Color.hex("#087CFA")
            )
        }
        borderLine.color(company)
        alpha = 0.3
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;9YM3qc&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;User Growth Dynamics&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;&amp;merged_groups&quot;:[&quot;Apple&quot;,&quot;Apple&quot;,&quot;Apple&quot;,&quot;Apple&quot;,&quot;Apple&quot;,&quot;Apple&quot;,&quot;Google&quot;,&quot;Google&quot;,&quot;Google&quot;,&quot;Google&quot;,&quot;Google&quot;,&quot;Google&quot;,&quot;Microsoft&quot;,&quot;Microsoft&quot;,&quot;Microsoft&quot;,&quot;Microsoft&quot;,&quot;Microsoft&quot;,&quot;Microsoft&quot;,&quot;Meta&quot;,&quot;Meta&quot;,&quot;Meta&quot;,&quot;Meta&quot;,&quot;Meta&quot;,&quot;Meta&quot;,&quot;Amazon&quot;,&quot;Amazon&quot;,&quot;Amazon&quot;,&quot;Amazon&quot;,&quot;Amazon&quot;,&quot;Amazon&quot;],
// &quot;year&quot;:[&quot;2016&quot;,&quot;2017&quot;,&quot;2018&quot;,&quot;2019&quot;,&quot;2020&quot;,&quot;2021&quot;,&quot;2016&quot;,&quot;2017&quot;,&quot;2018&quot;,&quot;2019&quot;,&quot;2020&quot;,&quot;2021&quot;,&quot;2016&quot;,&quot;2017&quot;,&quot;2018&quot;,&quot;2019&quot;,&quot;2020&quot;,&quot;2021&quot;,&quot;2016&quot;,&quot;2017&quot;,&quot;2018&quot;,&quot;2019&quot;,&quot;2020&quot;,&quot;2021&quot;,&quot;2016&quot;,&quot;2017&quot;,&quot;2018&quot;,&quot;2019&quot;,&quot;2020&quot;,&quot;2021&quot;],
// &quot;company&quot;:[&quot;Apple&quot;,&quot;Apple&quot;,&quot;Apple&quot;,&quot;Apple&quot;,&quot;Apple&quot;,&quot;Apple&quot;,&quot;Google&quot;,&quot;Google&quot;,&quot;Google&quot;,&quot;Google&quot;,&quot;Google&quot;,&quot;Google&quot;,&quot;Microsoft&quot;,&quot;Microsoft&quot;,&quot;Microsoft&quot;,&quot;Microsoft&quot;,&quot;Microsoft&quot;,&quot;Microsoft&quot;,&quot;Meta&quot;,&quot;Meta&quot;,&quot;Meta&quot;,&quot;Meta&quot;,&quot;Meta&quot;,&quot;Meta&quot;,&quot;Amazon&quot;,&quot;Amazon&quot;,&quot;Amazon&quot;,&quot;Amazon&quot;,&quot;Amazon&quot;,&quot;Amazon&quot;],
// &quot;users&quot;:[700.0,800.0,750.0,900.0,850.0,950.0,1000.0,950.0,1200.0,1150.0,1250.0,1300.0,600.0,700.0,650.0,700.0,750.0,800.0,1100.0,1200.0,1150.0,1300.0,1250.0,1350.0,300.0,400.0,350.0,450.0,500.0,600.0]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;values&quot;:[&quot;#FF45ED&quot;,&quot;#3DEA62&quot;,&quot;#000000&quot;,&quot;#FDB60D&quot;,&quot;#087CFA&quot;],
// &quot;limits&quot;:[&quot;Apple&quot;,&quot;Google&quot;,&quot;Microsoft&quot;,&quot;Meta&quot;,&quot;Amazon&quot;]
// },{
// &quot;aesthetic&quot;:&quot;color&quot;,
// &quot;discrete&quot;:true
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;year&quot;,
// &quot;y&quot;:&quot;users&quot;,
// &quot;fill&quot;:&quot;company&quot;,
// &quot;color&quot;:&quot;company&quot;,
// &quot;group&quot;:&quot;&amp;merged_groups&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;alpha&quot;:0.3,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;area&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;company&quot;
// },{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;year&quot;
// },{
// &quot;type&quot;:&quot;int&quot;,
// &quot;column&quot;:&quot;users&quot;
// },{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;&amp;merged_groups&quot;
// }]
// },
// &quot;spec_id&quot;:&quot;2&quot;
// };
//        var containerDiv = document.getElementById(&quot;9YM3qc&quot;);
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//        var options = {
//            sizing: {
//                width_mode: &quot;fixed&quot;,
//                height_mode: &quot;fixed&quot;,
//                width: 600.0,
//                height: 400.0
//            }
//        };
//        var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//        if (toolbar) {
//          toolbar.bind(fig);
//        }
//
//    // ----------
//    })();
//
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=43233059-ffd4-4ea8-84a2-b41fc8227533 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pB7vVIm .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pB7vVIm .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pB7vVIm .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pB7vVIm .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pB7vVIm .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pB7vVIm .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pB7vVIm .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pB7vVIm .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d24yrtc .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pB7vVIm .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pB7vVIm .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d24yrtc .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pB7vVIm .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pB7vVIm .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d24yrtc .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d24yrtc .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d24yrtc .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pB7vVIm">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </p
