// %%
%useLatestDescriptors
%use ggdsl(0.2.4-dev-5)

// %%
val dat = mapOf("x" to listOf(0.0, 1.0), "y" to listOf(0.0, 1.0))

// %%
plot(dat) {
    tile {
        x("x"<Double>())
        y("y"<Double>())
        color(Color.named("light-gray"))
        
        tooltips(title = "Tooltip title") {
            line("label|value")
        }
    }
}
// Out:
//    <div id="BX2SiT"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "data":{
// "x":[0.0,1.0],
// "y":[0.0,1.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// }],
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"tile",
// "fill":"light-gray",
// "tooltips":{
// "tooltip_lines":["label|value"],
// "tooltip_title":"Tooltip title"
// },
// "data":{
// }
// }]
// };
//            var plotContainer = document.getElementById("BX2SiT");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [markdown]
// ### Tooltip properties in theme:
//
// - `tooltip` - tooltip rectangle;
// - `tooltipText` - text in general tooltip;
// - `tooltipTitleText` - tooltip title text;
// - `axisTooltipText[X|Y]` - axis tooltip text (inherits from 'tooltipText')

// %%
plot(dat) {
    tile {
        x("x"<Double>())
        y("y"<Double>())
        color(Color.named("light-gray"))
        
        tooltips(title = "Tooltip title") {
            line("label|value")
        }
        
    }
    
    layout.theme { 
        layerTooltips {
            background {
                borderLineColor = Color.hex("#225e32")
                fillColor = Color.hex("#238b45")
                borderLineWidth = 2.0
            }
            text {
                color = Color.hex("#bae4b3")
            }
            title {
                color = Color.hex("#edf8e9")
            }
        }
        xAxis.tooltip.text {
            color = Color.GREEN
        }
    }
}
// Out:
//    <div id="Qhz3qC"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "data":{
// "x":[0.0,1.0],
// "y":[0.0,1.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// }],
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"tile",
// "fill":"light-gray",
// "tooltips":{
// "tooltip_lines":["label|value"],
// "tooltip_title":"Tooltip title"
// },
// "data":{
// }
// }],
// "theme":{
// "tooltip_title_text":{
// "color":"#edf8e9",
// "face":false,
// "blank":false
// },
// "axis_ontop":false,
// "axis_tooltip_text_x":{
// "color":"#3ba272",
// "face":false,
// "blank":false
// },
// "tooltip":{
// "fill":"#238b45",
// "color":"#225e32",
// "size":2.0,
// "blank":false
// },
// "tooltip_text":{
// "color":"#bae4b3",
// "face":false,
// "blank":false
// },
// "axis_ontop_y":false,
// "axis_ontop_x":false
// }
// };
//            var plotContainer = document.getElementById("Qhz3qC");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
