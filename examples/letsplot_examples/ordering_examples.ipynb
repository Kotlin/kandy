// %% [markdown]
// ## Ordering Discrete Values

// %%
%useLatestDescriptors
%use lets-plot
%use dataframe
%use ggdsl(0.1.4-dev-42)
// Out:
//    <div id="plO4a6"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("plO4a6").appendChild(div);
//            };
//            var e = document.getElementById("plO4a6");
//            e.appendChild(script);
//        })();
//    </script>

// %%
LetsPlot.getInfo()  // This prevents Krangl from loading an obsolete version of Lets-Plot classes.
// Out:
// Lets-Plot Kotlin API v.4.0.0. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.2.4.0.

// %%
val mpg = DataFrame.readCSV("https://raw.githubusercontent.com/JetBrains/lets-plot-kotlin/master/docs/examples/data/mpg.csv")
mpg.head(3)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_-100663293"></table>
//
// <p>DataFrame: rowsCount = 3, columnsCount = 12</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"untitled: Int\">untitled</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>"] },
// { name: "<span title=\"manufacturer: String\">manufacturer</span>", children: [], rightAlign: false, values: ["audi","audi","audi"] },
// { name: "<span title=\"model: String\">model</span>", children: [], rightAlign: false, values: ["a4","a4","a4"] },
// { name: "<span title=\"displ: java.math.BigDecimal\">displ</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1,8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1,8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,0</span></span>"] },
// { name: "<span title=\"year: Int\">year</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1999</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1999</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2008</span></span>"] },
// { name: "<span title=\"cyl: Int\">cyl</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>"] },
// { name: "<span title=\"trans: String\">trans</span>", children: [], rightAlign: false, values: ["auto(l5)","manual(m5)","manual(m6)"] },
// { name: "<span title=\"drv: String\">drv</span>", children: [], rightAlign: false, values: ["f","f","f"] },
// { name: "<span title=\"cty: Int\">cty</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">18</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">21</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">20</span></span>"] },
// { name: "<span title=\"hwy: Int\">hwy</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">29</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">29</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">31</span></span>"] },
// { name: "<span title=\"fl: String\">fl</span>", children: [], rightAlign: false, values: ["p","p","p"] },
// { name: "<span title=\"class: String\">class</span>", children: [], rightAlign: false, values: ["compact","compact","compact"] },
// ], id: -100663293, rootId: -100663293, totalRows: 3 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-100663293) });
//
//
//         </script>
//         </html>

// %%
val p = letsPlot(mpg.toMap()) { y = "hwy" } + theme(axisTitleX="blank")

// %%
val p1 = p + ggtitle("default") + geomBoxplot{ x = "class" }
val p2 = p + ggtitle("alphabetically") + geomBoxplot{ x = asDiscrete("class", order = 1) }
val p3 = p + ggtitle("by 'middle' ↑") + geomBoxplot{ x = asDiscrete("class", orderBy = "..middle..", order = 1) }
val p4 = p + ggtitle("by 'middle' ↓") + geomBoxplot{ x = asDiscrete("class", orderBy = "..middle..", order = -1) }
val p5 = p + ggtitle("by 'ymax' ↑") + geomBoxplot{ x = asDiscrete("class", orderBy = "..ymax..", order = 1) }
val p6 = p + ggtitle("by 'ymax' ↓") + geomBoxplot{ x = asDiscrete("class", orderBy = "..ymax..", order = -1) }
     
val w = 470 
val h = 300

val bunch = GGBunch()
bunch.addPlot(p1, 0, 0, w, h)
bunch.addPlot(p2, w, 0, w, h)
bunch.addPlot(p3, 0, h, w, h)
bunch.addPlot(p4, w, h, w, h)
bunch.addPlot(p5, 0, h*2, w, h)
bunch.addPlot(p6, w, h*2, w, h)

bunch
// Out:
//    <div id="Ol9r4d"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "kind":"ggbunch",
// "items":[{
// "x":0,
// "width":470,
// "y":0,
// "feature_spec":{
// "ggtitle":{
// "text":"default"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"class"
// },
// "stat":"boxplot",
// "position":{
// "name":"dodge",
// "width":0.95,
// "kind":"pos"
// },
// "geom":"boxplot",
// "data":{
// "..middle..":[NaN,NaN,NaN,NaN,27.0,27.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,NaN,23.0,NaN,NaN,NaN,NaN,17.0,25.0,NaN,NaN,26.0],
// "..upper..":[NaN,NaN,NaN,NaN,29.0,29.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,NaN,24.0,NaN,NaN,NaN,NaN,18.0,26.0,NaN,NaN,30.5],
// "..ymax..":[NaN,NaN,NaN,NaN,33.0,32.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,NaN,24.0,NaN,NaN,NaN,NaN,20.0,26.0,NaN,NaN,36.0],
// "..lower..":[NaN,NaN,NaN,NaN,26.0,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,NaN,22.0,NaN,NaN,NaN,NaN,16.0,24.0,NaN,NaN,24.5],
// "..ymin..":[NaN,NaN,NaN,NaN,23.0,23.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,NaN,21.0,NaN,NaN,NaN,NaN,15.0,23.0,NaN,NaN,20.0],
// "hwy":[35.0,37.0,35.0,44.0,NaN,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,NaN,12.0,12.0,12.0,22.0,NaN,NaN,44.0,41.0,NaN],
// "class":["compact","compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","minivan","minivan","pickup","pickup","pickup","pickup","pickup","2seater","subcompact","subcompact","subcompact"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":0,
// "feature_spec":{
// "ggtitle":{
// "text":"alphabetically"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class"
// },
// "stat":"boxplot",
// "position":{
// "name":"dodge",
// "width":0.95,
// "kind":"pos"
// },
// "geom":"boxplot",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class",
// "order":1
// }
// }]
// },
// "data":{
// "..middle..":[NaN,NaN,NaN,NaN,27.0,27.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,NaN,23.0,NaN,NaN,NaN,NaN,17.0,25.0,NaN,NaN,26.0],
// "..upper..":[NaN,NaN,NaN,NaN,29.0,29.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,NaN,24.0,NaN,NaN,NaN,NaN,18.0,26.0,NaN,NaN,30.5],
// "..ymax..":[NaN,NaN,NaN,NaN,33.0,32.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,NaN,24.0,NaN,NaN,NaN,NaN,20.0,26.0,NaN,NaN,36.0],
// "..lower..":[NaN,NaN,NaN,NaN,26.0,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,NaN,22.0,NaN,NaN,NaN,NaN,16.0,24.0,NaN,NaN,24.5],
// "..ymin..":[NaN,NaN,NaN,NaN,23.0,23.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,NaN,21.0,NaN,NaN,NaN,NaN,15.0,23.0,NaN,NaN,20.0],
// "@as_discrete@class":["compact","compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","minivan","minivan","pickup","pickup","pickup","pickup","pickup","2seater","subcompact","subcompact","subcompact"],
// "hwy":[35.0,37.0,35.0,44.0,NaN,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,NaN,12.0,12.0,12.0,22.0,NaN,NaN,44.0,41.0,NaN]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":300,
// "feature_spec":{
// "ggtitle":{
// "text":"by 'middle' ↑"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class"
// },
// "stat":"boxplot",
// "position":{
// "name":"dodge",
// "width":0.95,
// "kind":"pos"
// },
// "geom":"boxplot",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class",
// "order_by":"..middle..",
// "order":1
// }
// }]
// },
// "data":{
// "..middle..":[NaN,NaN,NaN,NaN,27.0,27.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,NaN,23.0,NaN,NaN,NaN,NaN,17.0,25.0,NaN,NaN,26.0],
// "..upper..":[NaN,NaN,NaN,NaN,29.0,29.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,NaN,24.0,NaN,NaN,NaN,NaN,18.0,26.0,NaN,NaN,30.5],
// "..ymax..":[NaN,NaN,NaN,NaN,33.0,32.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,NaN,24.0,NaN,NaN,NaN,NaN,20.0,26.0,NaN,NaN,36.0],
// "..lower..":[NaN,NaN,NaN,NaN,26.0,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,NaN,22.0,NaN,NaN,NaN,NaN,16.0,24.0,NaN,NaN,24.5],
// "..ymin..":[NaN,NaN,NaN,NaN,23.0,23.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,NaN,21.0,NaN,NaN,NaN,NaN,15.0,23.0,NaN,NaN,20.0],
// "hwy":[35.0,37.0,35.0,44.0,NaN,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,NaN,12.0,12.0,12.0,22.0,NaN,NaN,44.0,41.0,NaN],
// "@as_discrete@class":["compact","compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","minivan","minivan","pickup","pickup","pickup","pickup","pickup","2seater","subcompact","subcompact","subcompact"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":300,
// "feature_spec":{
// "ggtitle":{
// "text":"by 'middle' ↓"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class"
// },
// "stat":"boxplot",
// "position":{
// "name":"dodge",
// "width":0.95,
// "kind":"pos"
// },
// "geom":"boxplot",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class",
// "order_by":"..middle..",
// "order":-1
// }
// }]
// },
// "data":{
// "..middle..":[NaN,NaN,NaN,NaN,27.0,27.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,NaN,23.0,NaN,NaN,NaN,NaN,17.0,25.0,NaN,NaN,26.0],
// "..upper..":[NaN,NaN,NaN,NaN,29.0,29.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,NaN,24.0,NaN,NaN,NaN,NaN,18.0,26.0,NaN,NaN,30.5],
// "..ymax..":[NaN,NaN,NaN,NaN,33.0,32.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,NaN,24.0,NaN,NaN,NaN,NaN,20.0,26.0,NaN,NaN,36.0],
// "..lower..":[NaN,NaN,NaN,NaN,26.0,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,NaN,22.0,NaN,NaN,NaN,NaN,16.0,24.0,NaN,NaN,24.5],
// "..ymin..":[NaN,NaN,NaN,NaN,23.0,23.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,NaN,21.0,NaN,NaN,NaN,NaN,15.0,23.0,NaN,NaN,20.0],
// "@as_discrete@class":["compact","compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","minivan","minivan","pickup","pickup","pickup","pickup","pickup","2seater","subcompact","subcompact","subcompact"],
// "hwy":[35.0,37.0,35.0,44.0,NaN,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,NaN,12.0,12.0,12.0,22.0,NaN,NaN,44.0,41.0,NaN]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":600,
// "feature_spec":{
// "ggtitle":{
// "text":"by 'ymax' ↑"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class"
// },
// "stat":"boxplot",
// "position":{
// "name":"dodge",
// "width":0.95,
// "kind":"pos"
// },
// "geom":"boxplot",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class",
// "order_by":"..ymax..",
// "order":1
// }
// }]
// },
// "data":{
// "..middle..":[NaN,NaN,NaN,NaN,27.0,27.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,NaN,23.0,NaN,NaN,NaN,NaN,17.0,25.0,NaN,NaN,26.0],
// "..upper..":[NaN,NaN,NaN,NaN,29.0,29.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,NaN,24.0,NaN,NaN,NaN,NaN,18.0,26.0,NaN,NaN,30.5],
// "..ymax..":[NaN,NaN,NaN,NaN,33.0,32.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,NaN,24.0,NaN,NaN,NaN,NaN,20.0,26.0,NaN,NaN,36.0],
// "..lower..":[NaN,NaN,NaN,NaN,26.0,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,NaN,22.0,NaN,NaN,NaN,NaN,16.0,24.0,NaN,NaN,24.5],
// "..ymin..":[NaN,NaN,NaN,NaN,23.0,23.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,NaN,21.0,NaN,NaN,NaN,NaN,15.0,23.0,NaN,NaN,20.0],
// "hwy":[35.0,37.0,35.0,44.0,NaN,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,NaN,12.0,12.0,12.0,22.0,NaN,NaN,44.0,41.0,NaN],
// "@as_discrete@class":["compact","compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","minivan","minivan","pickup","pickup","pickup","pickup","pickup","2seater","subcompact","subcompact","subcompact"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":600,
// "feature_spec":{
// "ggtitle":{
// "text":"by 'ymax' ↓"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class"
// },
// "stat":"boxplot",
// "position":{
// "name":"dodge",
// "width":0.95,
// "kind":"pos"
// },
// "geom":"boxplot",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "

// %%
val myP1 = mpg.create { plot {
    boxplot(`class`, hwy) {}
    layout.title = "default"
} }
val myP2 = mpg.create { plot { 
    boxplot(`class`, hwy) {
        x(categoricalPos<String>(`class`.toSet().sorted())) // TODO
    }
    layout.title = "alphabetically"
} }
val myP3 = mpg.create { plot {
    boxplot(`class`, hwy) {
        orderBy(Stat.MIDDLE)
    }
    layout.title = "by 'middle' ↑"
} }
val myP4 = mpg.create { plot {
    boxplot(`class`, hwy) {
        orderBy(Stat.MIDDLE, true)
    }
    layout.title = "by 'middle' ↓"
} }
val myP5 = mpg.create { plot {
    boxplot(`class`, hwy) {
        orderBy(Stat., true)
    }
    layout.title = "by 'ymax' ↑"
} }
val myP6 = mpg.create { plot {
    boxplot(`class`, hwy) {}
    layout.title = "default"
} }

plotBunch { 
    add(myP1, 0, 0, w, h)
    add(myP2, w, 0, w, h)
    add(myP3, 0, h, w, h)
    add(myP4, w, h, w, h)
    add(myP5, 0, h*2, w, h)
    add(myP6, w, h*2, w, h)
}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="mjDUtG"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "kind":"ggbunch",
// "items":[{
// "x":0,
// "width":470,
// "y":0,
// "feature_spec":{
// "ggtitle":{
// "text":"default"
// },
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// }],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class",
// "y":"hwy"
// },
// "stat":"boxplot",
// "data":{
// "..middle..":[NaN,NaN,NaN,NaN,27.0,27.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,NaN,23.0,NaN,NaN,NaN,NaN,17.0,25.0,NaN,NaN,26.0],
// "..upper..":[NaN,NaN,NaN,NaN,29.0,29.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,NaN,24.0,NaN,NaN,NaN,NaN,18.0,26.0,NaN,NaN,30.5],
// "..ymax..":[NaN,NaN,NaN,NaN,33.0,32.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,NaN,24.0,NaN,NaN,NaN,NaN,20.0,26.0,NaN,NaN,36.0],
// "..lower..":[NaN,NaN,NaN,NaN,26.0,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,NaN,22.0,NaN,NaN,NaN,NaN,16.0,24.0,NaN,NaN,24.5],
// "..ymin..":[NaN,NaN,NaN,NaN,23.0,23.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,NaN,21.0,NaN,NaN,NaN,NaN,15.0,23.0,NaN,NaN,20.0],
// "hwy":[35.0,37.0,35.0,44.0,NaN,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,NaN,12.0,12.0,12.0,22.0,NaN,NaN,44.0,41.0,NaN],
// "@as_discrete@class":["compact","compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","minivan","minivan","pickup","pickup","pickup","pickup","pickup","2seater","subcompact","subcompact","subcompact"]
// },
// "position":"identity",
// "geom":"boxplot",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class"
// }
// }]
// }
// }]
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":0,
// "feature_spec":{
// "ggtitle":{
// "text":"alphabetically"
// },
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":["2seater","compact","midsize","minivan","pickup","subcompact","suv"]
// },{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// }],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class",
// "y":"hwy"
// },
// "stat":"boxplot",
// "data":{
// "..middle..":[NaN,NaN,NaN,NaN,27.0,27.0,25.0,NaN,NaN,NaN,NaN,17.0,NaN,NaN,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,NaN,23.0],
// "..upper..":[NaN,NaN,NaN,NaN,29.0,29.0,26.0,NaN,NaN,NaN,NaN,18.0,NaN,NaN,30.5,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,NaN,24.0],
// "..ymax..":[NaN,NaN,NaN,NaN,33.0,32.0,26.0,NaN,NaN,NaN,NaN,20.0,NaN,NaN,36.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,NaN,24.0],
// "..lower..":[NaN,NaN,NaN,NaN,26.0,26.0,24.0,NaN,NaN,NaN,NaN,16.0,NaN,NaN,24.5,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,NaN,22.0],
// "..ymin..":[NaN,NaN,NaN,NaN,23.0,23.0,23.0,NaN,NaN,NaN,NaN,15.0,NaN,NaN,20.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,NaN,21.0],
// "hwy":[35.0,37.0,35.0,44.0,NaN,NaN,NaN,12.0,12.0,12.0,22.0,NaN,44.0,41.0,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,NaN],
// "@as_discrete@class":["compact","compact","compact","compact","compact","midsize","2seater","pickup","pickup","pickup","pickup","pickup","subcompact","subcompact","subcompact","suv","suv","suv","suv","suv","suv","suv","suv","suv","minivan","minivan"]
// },
// "position":"identity",
// "geom":"boxplot",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class"
// }
// }]
// }
// }]
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":300,
// "feature_spec":{
// "ggtitle":{
// "text":"default"
// },
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// }],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class",
// "y":"hwy"
// },
// "stat":"boxplot",
// "data":{
// "..middle..":[NaN,NaN,NaN,NaN,27.0,27.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,NaN,23.0,NaN,NaN,NaN,NaN,17.0,25.0,NaN,NaN,26.0],
// "..upper..":[NaN,NaN,NaN,NaN,29.0,29.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,NaN,24.0,NaN,NaN,NaN,NaN,18.0,26.0,NaN,NaN,30.5],
// "..ymax..":[NaN,NaN,NaN,NaN,33.0,32.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,NaN,24.0,NaN,NaN,NaN,NaN,20.0,26.0,NaN,NaN,36.0],
// "..lower..":[NaN,NaN,NaN,NaN,26.0,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,NaN,22.0,NaN,NaN,NaN,NaN,16.0,24.0,NaN,NaN,24.5],
// "..ymin..":[NaN,NaN,NaN,NaN,23.0,23.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,NaN,21.0,NaN,NaN,NaN,NaN,15.0,23.0,NaN,NaN,20.0],
// "hwy":[35.0,37.0,35.0,44.0,NaN,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,NaN,12.0,12.0,12.0,22.0,NaN,NaN,44.0,41.0,NaN],
// "@as_discrete@class":["compact","compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","minivan","minivan","pickup","pickup","pickup","pickup","pickup","2seater","subcompact","subcompact","subcompact"]
// },
// "position":"identity",
// "geom":"boxplot",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class"
// }
// }]
// }
// }]
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":300,
// "feature_spec":{
// "ggtitle":{
// "text":"default"
// },
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// }],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class",
// "y":"hwy"
// },
// "stat":"boxplot",
// "data":{
// "..middle..":[NaN,NaN,NaN,NaN,27.0,27.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,NaN,23.0,NaN,NaN,NaN,NaN,17.0,25.0,NaN,NaN,26.0],
// "..upper..":[NaN,NaN,NaN,NaN,29.0,29.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,NaN,24.0,NaN,NaN,NaN,NaN,18.0,26.0,NaN,NaN,30.5],
// "..ymax..":[NaN,NaN,NaN,NaN,33.0,32.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,NaN,24.0,NaN,NaN,NaN,NaN,20.0,26.0,NaN,NaN,36.0],
// "..lower..":[NaN,NaN,NaN,NaN,26.0,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,NaN,22.0,NaN,NaN,NaN,NaN,16.0,24.0,NaN,NaN,24.5],
// "..ymin..":[NaN,NaN,NaN,NaN,23.0,23.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,NaN,21.0,NaN,NaN,NaN,NaN,15.0,23.0,NaN,NaN,20.0],
// "hwy":[35.0,37.0,35.0,44.0,NaN,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,NaN,12.0,12.0,12.0,22.0,NaN,NaN,44.0,41.0,NaN],
// "@as_discrete@class":["compact","compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","minivan","minivan","pickup","pickup","pickup","pickup","pickup","2seater","subcompact","subcompact","subcompact"]
// },
// "position":"identity",
// "geom":"boxplot",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class"
// }
// }]
// }
// }]
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":600,
// "feature_spec":{
// "ggtitle":{
// "text":"default"
// },
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// }],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class",
// "y":"hwy"
// },
// "stat":"boxplot",
// "data":{
// "..middle..":[NaN,NaN,NaN,NaN,27.0,27.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,NaN,23.0,NaN,NaN,NaN,NaN,17.0,25.0,NaN,NaN,26.0],
// "..upper..":[NaN,NaN,NaN,NaN,29.0,29.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,NaN,24.0,NaN,NaN,NaN,NaN,18.0,26.0,NaN,NaN,30.5],
// "..ymax..":[NaN,NaN,NaN,NaN,33.0,32.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,NaN,24.0,NaN,NaN,NaN,NaN,20.0,26.0,NaN,NaN,36.0],
// "..lower..":[NaN,NaN,NaN,NaN,26.0,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,NaN,22.0,NaN,NaN,NaN,NaN,16.0,24.0,NaN,NaN,24.5],
// "..ymin..":[NaN,NaN,NaN,NaN,23.0,23.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,NaN,21.0,NaN,NaN,NaN,NaN,15.0,23.0,NaN,NaN,20.0],
// "@as_discrete@class":["compact","compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","minivan","minivan","pickup","pickup","pickup","pickup","pickup","2seater","subcompact","subcompact","subcompact"],
// "hwy":[35.0,37.0,35.0,44.0,NaN,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,NaN,12.0,12.0,12.0,22.0,NaN,NaN,44.0,41.0,NaN]
// },
// "position":"identity",
// "geom":"boxplot",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class"
// }
// }]
// }
// }]
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":600,
// "feature_spec":{
// "ggtitle":{
// "text":"default"
// },
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// }],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class",
// "y":"hwy"
// },
// "stat":"boxplot",
// "data":{
// "..mid

// %%
val classOrdered = asDiscrete("class", order=1)

val p10 = p + ggtitle("x='class', color='class'") +
              geomBoxplot{ x = "class"; color = "class" }
              
val p11 = p + ggtitle("x=asDiscrete('class', order=1), color='class'") +
              geomBoxplot{ x = classOrdered; color = "class" }              
              
val p12 = p + ggtitle("x=asDiscrete('class', order=1),\ncolor=asDiscrete('class')") +
              geomBoxplot{ x = classOrdered; color = asDiscrete("class") }
              
val p13 = p + ggtitle("x='class', color='drv'") +
              geomBoxplot{ x = "class"; color = "drv" }
              
val p14 = p + ggtitle("x=asDiscrete('class', order=1),\ncolor=asDiscrete('drv', order=1)") +
              geomBoxplot{ x = classOrdered; color = asDiscrete("drv", order=1) }
              
val p15 = p + ggtitle("x=asDiscrete('class', orderBy='..middle..')") +
              geomBoxplot{ x = asDiscrete("class", orderBy="..middle.."); color = "drv" }
  

val bunch1 = GGBunch()
bunch1.addPlot(p10, 0, 0, w, h)
bunch1.addPlot(p11, 0, h, w, h)
bunch1.addPlot(p12, w, h, w, h)
bunch1.addPlot(p13, 0, h*2, w, h)
bunch1.addPlot(p14, 0, h*3, w, h)
bunch1.addPlot(p15, w, h*3, w, h)

bunch1
// Out:
//    <div id="J1I0y1"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "kind":"ggbunch",
// "items":[{
// "x":0,
// "width":470,
// "y":0,
// "feature_spec":{
// "ggtitle":{
// "text":"x='class', color='class'"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"class",
// "color":"class"
// },
// "stat":"boxplot",
// "position":{
// "name":"dodge",
// "width":0.95,
// "kind":"pos"
// },
// "geom":"boxplot",
// "data":{
// "..middle..":[NaN,NaN,NaN,NaN,27.0,27.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,25.0,NaN,23.0,NaN,NaN,NaN,NaN,17.0,NaN,NaN,26.0],
// "..upper..":[NaN,NaN,NaN,NaN,29.0,29.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,26.0,NaN,24.0,NaN,NaN,NaN,NaN,18.0,NaN,NaN,30.5],
// "..ymax..":[NaN,NaN,NaN,NaN,33.0,32.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,26.0,NaN,24.0,NaN,NaN,NaN,NaN,20.0,NaN,NaN,36.0],
// "..lower..":[NaN,NaN,NaN,NaN,26.0,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,24.0,NaN,22.0,NaN,NaN,NaN,NaN,16.0,NaN,NaN,24.5],
// "..ymin..":[NaN,NaN,NaN,NaN,23.0,23.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,23.0,NaN,21.0,NaN,NaN,NaN,NaN,15.0,NaN,NaN,20.0],
// "hwy":[35.0,37.0,35.0,44.0,NaN,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,NaN,17.0,NaN,12.0,12.0,12.0,22.0,NaN,44.0,41.0,NaN],
// "class":["compact","compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","2seater","minivan","minivan","pickup","pickup","pickup","pickup","pickup","subcompact","subcompact","subcompact"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":300,
// "feature_spec":{
// "ggtitle":{
// "text":"x=asDiscrete('class', order=1), color='class'"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class",
// "color":"class"
// },
// "stat":"boxplot",
// "position":{
// "name":"dodge",
// "width":0.95,
// "kind":"pos"
// },
// "geom":"boxplot",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class",
// "order":1
// }
// }]
// },
// "data":{
// "..middle..":[25.0,NaN,NaN,NaN,NaN,27.0,27.0,NaN,23.0,NaN,NaN,NaN,NaN,17.0,NaN,NaN,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5],
// "..upper..":[26.0,NaN,NaN,NaN,NaN,29.0,29.0,NaN,24.0,NaN,NaN,NaN,NaN,18.0,NaN,NaN,30.5,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0],
// "..ymax..":[26.0,NaN,NaN,NaN,NaN,33.0,32.0,NaN,24.0,NaN,NaN,NaN,NaN,20.0,NaN,NaN,36.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0],
// "..lower..":[24.0,NaN,NaN,NaN,NaN,26.0,26.0,NaN,22.0,NaN,NaN,NaN,NaN,16.0,NaN,NaN,24.5,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0],
// "..ymin..":[23.0,NaN,NaN,NaN,NaN,23.0,23.0,NaN,21.0,NaN,NaN,NaN,NaN,15.0,NaN,NaN,20.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0],
// "@as_discrete@class":["2seater","compact","compact","compact","compact","compact","midsize","minivan","minivan","pickup","pickup","pickup","pickup","pickup","subcompact","subcompact","subcompact","suv","suv","suv","suv","suv","suv","suv","suv","suv"],
// "hwy":[NaN,35.0,37.0,35.0,44.0,NaN,NaN,17.0,NaN,12.0,12.0,12.0,22.0,NaN,44.0,41.0,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN],
// "class":["2seater","compact","compact","compact","compact","compact","midsize","minivan","minivan","pickup","pickup","pickup","pickup","pickup","subcompact","subcompact","subcompact","suv","suv","suv","suv","suv","suv","suv","suv","suv"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":300,
// "feature_spec":{
// "ggtitle":{
// "text":"x=asDiscrete('class', order=1),\ncolor=asDiscrete('class')"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class",
// "color":"@as_discrete@class"
// },
// "stat":"boxplot",
// "position":{
// "name":"dodge",
// "width":0.95,
// "kind":"pos"
// },
// "geom":"boxplot",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class",
// "order":1
// }
// },{
// "aes":"color",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class"
// }
// }]
// },
// "data":{
// "..middle..":[NaN,NaN,NaN,NaN,27.0,27.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,25.0,NaN,23.0,NaN,NaN,NaN,NaN,17.0,NaN,NaN,26.0],
// "..upper..":[NaN,NaN,NaN,NaN,29.0,29.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,26.0,NaN,24.0,NaN,NaN,NaN,NaN,18.0,NaN,NaN,30.5],
// "..ymax..":[NaN,NaN,NaN,NaN,33.0,32.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,26.0,NaN,24.0,NaN,NaN,NaN,NaN,20.0,NaN,NaN,36.0],
// "..lower..":[NaN,NaN,NaN,NaN,26.0,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,24.0,NaN,22.0,NaN,NaN,NaN,NaN,16.0,NaN,NaN,24.5],
// "..ymin..":[NaN,NaN,NaN,NaN,23.0,23.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,23.0,NaN,21.0,NaN,NaN,NaN,NaN,15.0,NaN,NaN,20.0],
// "@as_discrete@class":["compact","compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","2seater","minivan","minivan","pickup","pickup","pickup","pickup","pickup","subcompact","subcompact","subcompact"],
// "hwy":[35.0,37.0,35.0,44.0,NaN,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,NaN,17.0,NaN,12.0,12.0,12.0,22.0,NaN,44.0,41.0,NaN]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":600,
// "feature_spec":{
// "ggtitle":{
// "text":"x='class', color='drv'"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"class",
// "color":"drv"
// },
// "stat":"boxplot",
// "position":{
// "name":"dodge",
// "width":0.95,
// "kind":"pos"
// },
// "geom":"boxplot",
// "data":{
// "..middle..":[NaN,NaN,29.0,27.0,NaN,23.0,NaN,NaN,29.0,25.0,24.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,18.0,NaN,NaN,NaN,NaN,17.0,26.0,NaN,NaN,NaN,17.0,25.0,23.0],
// "..upper..":[NaN,NaN,30.0,29.0,NaN,24.0,NaN,NaN,32.5,27.0,24.5,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,NaN,NaN,NaN,NaN,18.0,26.0,NaN,NaN,NaN,18.0,26.0,25.0],
// "..ymax..":[NaN,NaN,35.0,32.0,NaN,24.0,NaN,NaN,36.0,28.0,25.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,NaN,NaN,NaN,NaN,20.0,26.0,NaN,NaN,NaN,18.0,26.0,26.0],
// "..lower..":[NaN,NaN,26.5,26.0,NaN,22.0,NaN,NaN,27.5,25.0,23.5,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,NaN,NaN,NaN,NaN,16.0,26.0,NaN,NaN,NaN,17.0,24.0,22.0],
// "drv":["f","f","f","f","f","f","f","f","f","4","4","4","4","4","4","4","4","4","4","4","4","4","4","4","4","4","r","r","r","r","r","r"],
// "..ymin..":[NaN,NaN,23.0,25.0,NaN,21.0,NaN,NaN,24.0,25.0,23.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,NaN,NaN,NaN,NaN,15.0,26.0,NaN,NaN,NaN,16.0,23.0,20.0],
// "hwy":[37.0,44.0,NaN,NaN,17.0,NaN,44.0,41.0,NaN,NaN,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,12.0,12.0,12.0,22.0,NaN,NaN,20.0,15.0,20.0,NaN,NaN,NaN],
// "class":["compact","compact","compact","midsize","minivan","minivan","subcompact","subcompact","subcompact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","pickup","pickup","pickup","pickup","pickup","subcompact","suv","suv","suv","suv","2seater","subcompact"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":900,
// "feature_spec":{
// "ggtitle":{
// "text":"x=asDiscrete('class', order=1),\ncolor=asDiscrete('drv', order=1)"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class",
// "color":"@as_discrete@drv"
// },
// "stat":"boxplot",
// "position":{
// "name":"dodge",
// "width":0.95,
// "kind":"pos"
// },
// "geom":"boxplot",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class",
// "order":1
// }
// },{
// "aes":"color",
// "annotation":"as_discrete",
// "parameters":{
// "label":"drv",
// "order":1
// }
// }]
// },
// "data":{
// "..middle..":[25.0,24.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,18.0,NaN,NaN,NaN,NaN,17.0,26.0,NaN,NaN,29.0,27.0,NaN,23.0,NaN,NaN,29.0,NaN,NaN,NaN,17.0,25.0,23.0],
// "..upper..":[27.0,24.5,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,NaN,NaN,NaN,NaN,18.0,26.0,NaN,NaN,30.0,29.0,NaN,24.0,NaN,NaN,32.5,NaN,NaN,NaN,18.0,26.0,25.0],
// "@as_discrete@drv":["4","4","4","4","4","4","4","4","4","4","4","4","4","4","4","4","4","f","f","f","f","f","f","f","f","f","r","r","r","r","r","r"],
// "..ymax..":[28.0,25.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,NaN,NaN,NaN,NaN,20.0,26.0,NaN,NaN,35.0,32.0,NaN,24.0,NaN,NaN,36.0,NaN,NaN,NaN,18.0,26.0,26.0],
// "..lower..":[25.0,23.5,NaN,NaN,NaN,NaN,NaN,NaN,N

// %%
val p21 = p +
        geomCrossbar(stat = org.jetbrains.letsPlot.Stat.boxplot()) { x = "class"; color = "class"} +
        scaleColorBrewer(palette = "Dark2") +
        ggtitle("default")
        
val p22 = p +
        geomCrossbar(stat = org.jetbrains.letsPlot.Stat.boxplot()) { 
            x = asDiscrete("class", orderBy = "..middle..", order = 1); 
            color = "class"} +
        scaleColorBrewer(palette = "Dark2") +
        ggtitle("order by 'middle' ↑, also applies to 'color'")        
val p23 = p +
        geomCrossbar(stat = org.jetbrains.letsPlot.Stat.boxplot()) { 
            x = asDiscrete("class", orderBy = "..middle.."); 
            color = asDiscrete("class", order = 1)} +
        scaleColorBrewer(palette = "Dark2") +
        ggtitle("'class' and 'orderBy' + 'class' and 'order':\noptions are combined")      
        
val bunch2 = GGBunch()
bunch2.addPlot(p21, 0, 0, w, h)
bunch2.addPlot(p22, w, 0, w, h)
bunch2.addPlot(p23, 0, h, w, h)
bunch2
// Out:
//    <div id="u0znsZ"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "kind":"ggbunch",
// "items":[{
// "x":0,
// "width":470,
// "y":0,
// "feature_spec":{
// "ggtitle":{
// "text":"default"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"color",
// "scale_mapper_kind":"color_brewer",
// "palette":"Dark2"
// }],
// "layers":[{
// "mapping":{
// "x":"class",
// "color":"class"
// },
// "stat":"boxplot",
// "position":{
// "name":"dodge",
// "width":0.95,
// "kind":"pos"
// },
// "geom":"crossbar",
// "data":{
// "..middle..":[NaN,NaN,NaN,NaN,27.0,27.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,25.0,NaN,23.0,NaN,NaN,NaN,NaN,17.0,NaN,NaN,26.0],
// "..upper..":[NaN,NaN,NaN,NaN,29.0,29.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,26.0,NaN,24.0,NaN,NaN,NaN,NaN,18.0,NaN,NaN,30.5],
// "..ymax..":[NaN,NaN,NaN,NaN,33.0,32.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,26.0,NaN,24.0,NaN,NaN,NaN,NaN,20.0,NaN,NaN,36.0],
// "..lower..":[NaN,NaN,NaN,NaN,26.0,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,24.0,NaN,22.0,NaN,NaN,NaN,NaN,16.0,NaN,NaN,24.5],
// "..ymin..":[NaN,NaN,NaN,NaN,23.0,23.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,23.0,NaN,21.0,NaN,NaN,NaN,NaN,15.0,NaN,NaN,20.0],
// "class":["compact","compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","2seater","minivan","minivan","pickup","pickup","pickup","pickup","pickup","subcompact","subcompact","subcompact"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":0,
// "feature_spec":{
// "ggtitle":{
// "text":"order by 'middle' ↑, also applies to 'color'"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"color",
// "scale_mapper_kind":"color_brewer",
// "palette":"Dark2"
// }],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class",
// "color":"class"
// },
// "stat":"boxplot",
// "position":{
// "name":"dodge",
// "width":0.95,
// "kind":"pos"
// },
// "geom":"crossbar",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class",
// "order_by":"..middle..",
// "order":1
// }
// }]
// },
// "data":{
// "..middle..":[NaN,NaN,NaN,NaN,17.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,NaN,23.0,25.0,NaN,NaN,26.0,NaN,NaN,NaN,NaN,27.0,27.0],
// "..upper..":[NaN,NaN,NaN,NaN,18.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,NaN,24.0,26.0,NaN,NaN,30.5,NaN,NaN,NaN,NaN,29.0,29.0],
// "..ymax..":[NaN,NaN,NaN,NaN,20.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,NaN,24.0,26.0,NaN,NaN,36.0,NaN,NaN,NaN,NaN,33.0,32.0],
// "..lower..":[NaN,NaN,NaN,NaN,16.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,NaN,22.0,24.0,NaN,NaN,24.5,NaN,NaN,NaN,NaN,26.0,26.0],
// "..ymin..":[NaN,NaN,NaN,NaN,15.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,NaN,21.0,23.0,NaN,NaN,20.0,NaN,NaN,NaN,NaN,23.0,23.0],
// "@as_discrete@class":["pickup","pickup","pickup","pickup","pickup","suv","suv","suv","suv","suv","suv","suv","suv","suv","minivan","minivan","2seater","subcompact","subcompact","subcompact","compact","compact","compact","compact","compact","midsize"],
// "class":["pickup","pickup","pickup","pickup","pickup","suv","suv","suv","suv","suv","suv","suv","suv","suv","minivan","minivan","2seater","subcompact","subcompact","subcompact","compact","compact","compact","compact","compact","midsize"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":300,
// "feature_spec":{
// "ggtitle":{
// "text":"'class' and 'orderBy' + 'class' and 'order':\noptions are combined"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"color",
// "scale_mapper_kind":"color_brewer",
// "palette":"Dark2"
// }],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class",
// "color":"@as_discrete@class"
// },
// "stat":"boxplot",
// "position":{
// "name":"dodge",
// "width":0.95,
// "kind":"pos"
// },
// "geom":"crossbar",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class",
// "order_by":"..middle.."
// }
// },{
// "aes":"color",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class",
// "order":1
// }
// }]
// },
// "data":{
// "..middle..":[NaN,NaN,NaN,NaN,27.0,27.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,25.0,NaN,23.0,NaN,NaN,NaN,NaN,17.0,NaN,NaN,26.0],
// "..upper..":[NaN,NaN,NaN,NaN,29.0,29.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,19.0,26.0,NaN,24.0,NaN,NaN,NaN,NaN,18.0,NaN,NaN,30.5],
// "..ymax..":[NaN,NaN,NaN,NaN,33.0,32.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,22.0,26.0,NaN,24.0,NaN,NaN,NaN,NaN,20.0,NaN,NaN,36.0],
// "..lower..":[NaN,NaN,NaN,NaN,26.0,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,24.0,NaN,22.0,NaN,NaN,NaN,NaN,16.0,NaN,NaN,24.5],
// "..ymin..":[NaN,NaN,NaN,NaN,23.0,23.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,14.0,23.0,NaN,21.0,NaN,NaN,NaN,NaN,15.0,NaN,NaN,20.0],
// "@as_discrete@class":["compact","compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","2seater","minivan","minivan","pickup","pickup","pickup","pickup","pickup","subcompact","subcompact","subcompact"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// }]
// };
//            var plotContainer = document.getElementById("u0znsZ");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
val p31 = p + ggtitle("default") + geomBar { x = "class" }
val p32 = p + ggtitle("alphabetically") + geomBar { x = asDiscrete("class", order = 1) }
val p33 = p + ggtitle("by 'hwy' ↓") + geomBar { x = asDiscrete("class", orderBy = "hwy") }
val p34 = p + ggtitle("by 'hwy' ↑") + geomBar { x = asDiscrete("class", orderBy = "hwy", order = 1) }

val bunch3 = GGBunch()
bunch3.addPlot(p31, 0, 0, w, h)
bunch3.addPlot(p32, w, 0, w, h)
bunch3.addPlot(p33, 0, h, w, h)
bunch3.addPlot(p34, w, h, w, h)
bunch3
// Out:
//    <div id="YzSE4f"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "kind":"ggbunch",
// "items":[{
// "x":0,
// "width":470,
// "y":0,
// "feature_spec":{
// "ggtitle":{
// "text":"default"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"class"
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "hwy":[47.0,41.0,62.0,5.0,11.0,33.0,35.0],
// "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":0,
// "feature_spec":{
// "ggtitle":{
// "text":"alphabetically"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class"
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class",
// "order":1
// }
// }]
// },
// "data":{
// "@as_discrete@class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"],
// "hwy":[47.0,41.0,62.0,5.0,11.0,33.0,35.0]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":300,
// "feature_spec":{
// "ggtitle":{
// "text":"by 'hwy' ↓"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class"
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class",
// "order_by":"hwy"
// }
// }]
// },
// "data":{
// "@as_discrete@class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"],
// "hwy":[47.0,41.0,62.0,5.0,11.0,33.0,35.0]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":300,
// "feature_spec":{
// "ggtitle":{
// "text":"by 'hwy' ↑"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@class"
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class",
// "order_by":"hwy",
// "order":1
// }
// }]
// },
// "data":{
// "hwy":[47.0,41.0,62.0,5.0,11.0,33.0,35.0],
// "@as_discrete@class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// }]
// };
//            var plotContainer = document.getElementById("YzSE4f");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
val p41 = p + ggtitle("default") + geomBar { x = "manufacturer"; fill = "class" }
val p42 = p + ggtitle("'x' alphabetically") + geomBar { x = asDiscrete("manufacturer", order = 1); fill = "class" }
val p43 = p + ggtitle("'x' alphabetically + samplingPick(4)") + 
              geomBar(sampling = samplingPick(4)) { 
                            x = asDiscrete("manufacturer", order = 1); 
                            fill = "class" 
                          }
val p44 = p + ggtitle("'fill' alphabetically") + geomBar { x = "manufacturer"; fill = asDiscrete("class", order=1) }
val p45 = p + ggtitle("'x' & 'fill' alphabetically") + 
              geomBar { x = asDiscrete("manufacturer", order=1); fill = asDiscrete("class", order=1) }
val p46 = p + ggtitle("'x' by count ('sum' aggregation)") + 
              geomBar { x = asDiscrete("manufacturer", orderBy="..count.."); fill = "class" }
val p47 = p + ggtitle("'x' by count + samplingPick(4)") + 
              geomBar(sampling = samplingPick(4)) { 
                            x = asDiscrete("manufacturer", orderBy="..count.."); 
                            fill = "class" 
                          }

val bunch4 = GGBunch()
bunch4.addPlot(p41, 0, 0, w, h)
bunch4.addPlot(p42, 0, h, w, h)
bunch4.addPlot(p43, w, h, w, h)
bunch4.addPlot(p44, 0, h*2, w, h)
bunch4.addPlot(p45, w, h*2, w, h)
bunch4.addPlot(p46, 0, h*3, w, h)
bunch4.addPlot(p47, w, h*3, w, h)
bunch4
// Out:
//    <div id="19CtRk"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "kind":"ggbunch",
// "items":[{
// "x":0,
// "width":470,
// "y":0,
// "feature_spec":{
// "ggtitle":{
// "text":"default"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"manufacturer",
// "fill":"class"
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "hwy":[15.0,2.0,4.0,12.0,14.0,3.0,5.0,7.0,7.0,5.0,7.0,7.0,9.0,7.0,9.0,8.0,4.0,3.0,4.0,4.0,6.0,8.0,5.0,11.0,19.0,7.0,7.0,9.0,9.0,7.0,4.0,6.0],
// "class":["compact","compact","compact","compact","compact","midsize","midsize","midsize","midsize","midsize","midsize","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","suv","2seater","minivan","pickup","pickup","pickup","subcompact","subcompact","subcompact","subcompact","subcompact"],
// "manufacturer":["audi","nissan","subaru","toyota","volkswagen","audi","chevrolet","hyundai","nissan","pontiac","toyota","volkswagen","chevrolet","dodge","ford","jeep","land rover","lincoln","mercury","nissan","subaru","toyota","chevrolet","dodge","dodge","ford","toyota","ford","honda","hyundai","subaru","volkswagen"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":300,
// "feature_spec":{
// "ggtitle":{
// "text":"'x' alphabetically"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@manufacturer",
// "fill":"class"
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"manufacturer",
// "order":1
// }
// }]
// },
// "data":{
// "hwy":[15.0,2.0,4.0,12.0,14.0,3.0,5.0,7.0,7.0,5.0,7.0,7.0,9.0,7.0,9.0,8.0,4.0,3.0,4.0,4.0,6.0,8.0,5.0,11.0,19.0,7.0,7.0,9.0,9.0,7.0,4.0,6.0],
// "class":["compact","compact","compact","compact","compact","midsize","midsize","midsize","midsize","midsize","midsize","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","suv","2seater","minivan","pickup","pickup","pickup","subcompact","subcompact","subcompact","subcompact","subcompact"],
// "@as_discrete@manufacturer":["audi","nissan","subaru","toyota","volkswagen","audi","chevrolet","hyundai","nissan","pontiac","toyota","volkswagen","chevrolet","dodge","ford","jeep","land rover","lincoln","mercury","nissan","subaru","toyota","chevrolet","dodge","dodge","ford","toyota","ford","honda","hyundai","subaru","volkswagen"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":300,
// "feature_spec":{
// "ggtitle":{
// "text":"'x' alphabetically + samplingPick(4)"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@manufacturer",
// "fill":"class"
// },
// "stat":"count",
// "sampling":{
// "n":4.0,
// "name":"pick"
// },
// "position":"stack",
// "geom":"bar",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"manufacturer",
// "order":1
// }
// }]
// },
// "data":{
// "hwy":[15.0,3.0,5.0,9.0,7.0,9.0,5.0,11.0,19.0,7.0,9.0],
// "class":["compact","midsize","midsize","suv","suv","suv","2seater","minivan","pickup","pickup","subcompact"],
// "@as_discrete@manufacturer":["audi","audi","chevrolet","chevrolet","dodge","ford","chevrolet","dodge","dodge","ford","ford"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// },
// "computation_messages":["sampling_pick(n=4) was applied to [bar/count stat] layer"]
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":600,
// "feature_spec":{
// "ggtitle":{
// "text":"'fill' alphabetically"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"manufacturer",
// "fill":"@as_discrete@class"
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"fill",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class",
// "order":1
// }
// }]
// },
// "data":{
// "@as_discrete@class":["2seater","compact","compact","compact","compact","compact","midsize","midsize","midsize","midsize","midsize","midsize","midsize","minivan","pickup","pickup","pickup","subcompact","subcompact","subcompact","subcompact","subcompact","suv","suv","suv","suv","suv","suv","suv","suv","suv","suv"],
// "hwy":[5.0,15.0,2.0,4.0,12.0,14.0,3.0,5.0,7.0,7.0,5.0,7.0,7.0,11.0,19.0,7.0,7.0,9.0,9.0,7.0,4.0,6.0,9.0,7.0,9.0,8.0,4.0,3.0,4.0,4.0,6.0,8.0],
// "manufacturer":["chevrolet","audi","nissan","subaru","toyota","volkswagen","audi","chevrolet","hyundai","nissan","pontiac","toyota","volkswagen","dodge","dodge","ford","toyota","ford","honda","hyundai","subaru","volkswagen","chevrolet","dodge","ford","jeep","land rover","lincoln","mercury","nissan","subaru","toyota"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":600,
// "feature_spec":{
// "ggtitle":{
// "text":"'x' & 'fill' alphabetically"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@manufacturer",
// "fill":"@as_discrete@class"
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"manufacturer",
// "order":1
// }
// },{
// "aes":"fill",
// "annotation":"as_discrete",
// "parameters":{
// "label":"class",
// "order":1
// }
// }]
// },
// "data":{
// "@as_discrete@class":["2seater","compact","compact","compact","compact","compact","midsize","midsize","midsize","midsize","midsize","midsize","midsize","minivan","pickup","pickup","pickup","subcompact","subcompact","subcompact","subcompact","subcompact","suv","suv","suv","suv","suv","suv","suv","suv","suv","suv"],
// "hwy":[5.0,15.0,2.0,4.0,12.0,14.0,3.0,5.0,7.0,7.0,5.0,7.0,7.0,11.0,19.0,7.0,7.0,9.0,9.0,7.0,4.0,6.0,9.0,7.0,9.0,8.0,4.0,3.0,4.0,4.0,6.0,8.0],
// "@as_discrete@manufacturer":["chevrolet","audi","nissan","subaru","toyota","volkswagen","audi","chevrolet","hyundai","nissan","pontiac","toyota","volkswagen","dodge","dodge","ford","toyota","ford","honda","hyundai","subaru","volkswagen","chevrolet","dodge","ford","jeep","land rover","lincoln","mercury","nissan","subaru","toyota"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":900,
// "feature_spec":{
// "ggtitle":{
// "text":"'x' by count ('sum' aggregation)"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@manufacturer",
// "fill":"class"
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"manufacturer",
// "order_by":"..count.."
// }
// }]
// },
// "data":{
// "..count..":[15.0,2.0,4.0,12.0,14.0,3.0,5.0,7.0,7.0,5.0,7.0,7.0,9.0,7.0,9.0,8.0,4.0,3.0,4.0,4.0,6.0,8.0,5.0,11.0,19.0,7.0,7.0,9.0,9.0,7.0,4.0,6.0],
// "hwy":[15.0,2.0,4.0,12.0,14.0,3.0,5.0,7.0,7.0,5.0,7.0,7.0,9.0,7.0,9.0,8.0,4.0,3.0,4.0,4.0,6.0,8.0,5.0,11.0,19.0,7.0,7.0,9.0,9.0,7.0,4.0,6.0],
// "class":["compact","compact","compact","compact","compact","midsize","midsize","midsize","midsize","midsize","midsize","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","suv","2seater","minivan","pickup","pickup","pickup","subcompact","subcompact","subcompact","subcompact","subcompact"],
// "@as_discrete@manufacturer":["audi","nissan","subaru","toyota","volkswagen","audi","chevrolet","hyundai","nissan","pontiac","toyota","volkswagen","chevrolet","dodge","ford","jeep","land rover","lincoln","mercury","nissan","subaru","toyota","chevrolet","dodge","dodge","ford","toyota","ford","honda","hyundai","subaru","volkswagen"]
// }
// }],
// "theme":{
// "axis_title_x":"blank"
// }
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":900,
// "feature_spec":{
// "ggtitle":{
// "text":"'x' by count + samplingPick(4)"
// },
// "mapping":{
// "y":"hwy"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@manufacturer",
// "fill":"class"
// },
// "stat":"count",
// "sampling":{
// "n":4.0,
// "name":"pick"
// },
// "position":"stack",
// "geom":"bar",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"manufacturer",
// "order_by":"..count.."
// }
// }]
// },
// "d

// %%
val pp = letsPlot(mpg.toMap()) { x = "fl"; fill = "drv" }
val p51 = pp + geomBar() + ggtitle("Default")
val p52 = pp + geomBar(position=positionDodge()) + ggtitle("With Dodge Position")

val pOrder1 = ggplot(mpg.toMap()) { x = asDiscrete("fl", order=1); fill = asDiscrete("drv", order=1) }
val title1 = ggtitle("'x' and 'fill' alphabetically")

val p53 = pOrder1 + geomBar() + title1
val p54 = pOrder1 + geomBar(position=positionDodge()) + title1

val pOrder2 = ggplot(mpg.toMap()) { x = asDiscrete("fl", orderBy="..count.."); fill = "drv" }
val title2 = ggtitle("'x' by 'count'")

val p55 = pOrder2 + geomBar() + title2
val p56 = pOrder2 + geomBar(position=positionDodge()) + title2


val bunch5 = GGBunch()
bunch5.addPlot(p51, 0, 0, w, h)
bunch5.addPlot(p52, w, 0, w, h)
bunch5.addPlot(p53, 0, h, w, h)
bunch5.addPlot(p54, w, h, w, h)
bunch5.addPlot(p55, 0, h*2, w, h)
bunch5.addPlot(p56, w, h*2, w, h)
bunch5
// Out:
//    <div id="P5WrDG"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "kind":"ggbunch",
// "items":[{
// "x":0,
// "width":470,
// "y":0,
// "feature_spec":{
// "ggtitle":{
// "text":"Default"
// },
// "mapping":{
// "x":"fl",
// "fill":"drv"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "fl":["p","r","e","c","d","p","r","e","d","r","e","p"],
// "..count..":[25.0,76.0,1.0,1.0,3.0,20.0,75.0,6.0,2.0,17.0,1.0,7.0],
// "drv":["f","f","f","f","f","4","4","4","4","r","r","r"]
// }
// }]
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":0,
// "feature_spec":{
// "ggtitle":{
// "text":"With Dodge Position"
// },
// "mapping":{
// "x":"fl",
// "fill":"drv"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"dodge",
// "geom":"bar",
// "data":{
// "fl":["p","r","e","c","d","p","r","e","d","r","e","p"],
// "..count..":[25.0,76.0,1.0,1.0,3.0,20.0,75.0,6.0,2.0,17.0,1.0,7.0],
// "drv":["f","f","f","f","f","4","4","4","4","r","r","r"]
// }
// }]
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":300,
// "feature_spec":{
// "ggtitle":{
// "text":"'x' and 'fill' alphabetically"
// },
// "mapping":{
// "x":"@as_discrete@fl",
// "fill":"@as_discrete@drv"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "@as_discrete@drv":["4","4","4","4","f","f","f","f","f","r","r","r"],
// "@as_discrete@fl":["p","r","e","d","p","r","e","c","d","r","e","p"],
// "..count..":[20.0,75.0,6.0,2.0,25.0,76.0,1.0,1.0,3.0,17.0,1.0,7.0]
// }
// }],
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"fl",
// "order":1
// }
// },{
// "aes":"fill",
// "annotation":"as_discrete",
// "parameters":{
// "label":"drv",
// "order":1
// }
// }]
// }
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":300,
// "feature_spec":{
// "ggtitle":{
// "text":"'x' and 'fill' alphabetically"
// },
// "mapping":{
// "x":"@as_discrete@fl",
// "fill":"@as_discrete@drv"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"dodge",
// "geom":"bar",
// "data":{
// "@as_discrete@drv":["4","4","4","4","f","f","f","f","f","r","r","r"],
// "@as_discrete@fl":["p","r","e","d","p","r","e","c","d","r","e","p"],
// "..count..":[20.0,75.0,6.0,2.0,25.0,76.0,1.0,1.0,3.0,17.0,1.0,7.0]
// }
// }],
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"fl",
// "order":1
// }
// },{
// "aes":"fill",
// "annotation":"as_discrete",
// "parameters":{
// "label":"drv",
// "order":1
// }
// }]
// }
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":600,
// "feature_spec":{
// "ggtitle":{
// "text":"'x' by 'count'"
// },
// "mapping":{
// "x":"@as_discrete@fl",
// "fill":"drv"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "@as_discrete@fl":["p","r","e","c","d","p","r","e","d","r","e","p"],
// "..count..":[25.0,76.0,1.0,1.0,3.0,20.0,75.0,6.0,2.0,17.0,1.0,7.0],
// "drv":["f","f","f","f","f","4","4","4","4","r","r","r"]
// }
// }],
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"fl",
// "order_by":"..count.."
// }
// }]
// }
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":600,
// "feature_spec":{
// "ggtitle":{
// "text":"'x' by 'count'"
// },
// "mapping":{
// "x":"@as_discrete@fl",
// "fill":"drv"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"dodge",
// "geom":"bar",
// "data":{
// "@as_discrete@fl":["p","r","e","c","d","p","r","e","d","r","e","p"],
// "..count..":[25.0,76.0,1.0,1.0,3.0,20.0,75.0,6.0,2.0,17.0,1.0,7.0],
// "drv":["f","f","f","f","f","4","4","4","4","r","r","r"]
// }
// }],
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"fl",
// "order_by":"..count.."
// }
// }]
// }
// },
// "height":300
// }]
// };
//            var plotContainer = document.getElementById("P5WrDG");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
// diamonds

val diamonds = DataFrame.readCSV("https://vincentarelbundock.github.io/Rdatasets/csv/ggplot2/diamonds.csv")
diamonds.head(3)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_-100663292"></table>
//
// <p>DataFrame: rowsCount = 3, columnsCount = 11</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"untitled: Int\">untitled</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>"] },
// { name: "<span title=\"carat: java.math.BigDecimal\">carat</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,23</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,21</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,23</span></span>"] },
// { name: "<span title=\"cut: String\">cut</span>", children: [], rightAlign: false, values: ["Ideal","Premium","Good"] },
// { name: "<span title=\"color: String\">color</span>", children: [], rightAlign: false, values: ["E","E","E"] },
// { name: "<span title=\"clarity: String\">clarity</span>", children: [], rightAlign: false, values: ["SI2","SI1","VS1"] },
// { name: "<span title=\"depth: java.math.BigDecimal\">depth</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">61,5</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">59,8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">56,9</span></span>"] },
// { name: "<span title=\"table: java.math.BigDecimal\">table</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">5,500000e+01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6,100000e+01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6,500000e+01</span></span>"] },
// { name: "<span title=\"price: Int\">price</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">326</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">326</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">327</span></span>"] },
// { name: "<span title=\"x: java.math.BigDecimal\">x</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,95</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,89</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4,05</span></span>"] },
// { name: "<span title=\"y: java.math.BigDecimal\">y</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,98</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,84</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4,07</span></span>"] },
// { name: "<span title=\"z: java.math.BigDecimal\">z</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,43</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,31</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,31</span></span>"] },
// ], id: -100663292, rootId: -100663292, totalRows: 3 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-100663292) });
//
//
//         </script>
//         </html>

// %%
val pd = letsPlot(diamonds.toMap())

val p61 = pd + geomBar { x = "cut"; fill = "clarity" } + ggtitle("Default")

val p62 = pd + geomBar(position=positionFill) { x = "cut"; fill = "clarity" } + ggtitle("position='fill'")
val p63 = pd + ggtitle("'x' and 'fill' alphabetically") +
          geomBar(position=positionFill) { x = asDiscrete("cut", order=1); 
                                       fill = asDiscrete("clarity", order=1) }
val p64 = pd + ggtitle("'x' order by 'count'") +
          geomBar(position=positionFill) { x = asDiscrete("cut", orderBy="..count.."); 
                                       fill = asDiscrete("clarity", order=1) }

val p65 = pd + geomBar(position=positionDodge()) { x = "cut"; fill = "clarity" } + ggtitle("position='dodge'")
val p66 = pd + ggtitle("'x' order by 'count' and 'fill' - alphabetically") +
          geomBar(position=positionDodge()) { x = asDiscrete("cut", orderBy="..count.."); 
                                        fill = asDiscrete("clarity", order=1) }


val bunch6 = GGBunch()
bunch6.addPlot(p61, 0, 0, w, h)
bunch6.addPlot(p62, w, 0, w, h)
bunch6.addPlot(p63, 0, h, w, h)
bunch6.addPlot(p64, w, h, w, h)
bunch6.addPlot(p65, 0, h*2, w, h)
bunch6.addPlot(p66, w, h*2, w, h)
bunch6
// Out:
//    <div id="dVib8l"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "kind":"ggbunch",
// "items":[{
// "x":0,
// "width":470,
// "y":0,
// "feature_spec":{
// "ggtitle":{
// "text":"Default"
// },
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"cut",
// "fill":"clarity"
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "cut":["Ideal","Good","Premium","Very Good","Fair","Premium","Very Good","Good","Ideal","Fair","Good","Very Good","Ideal","Premium","Fair","Premium","Fair","Very Good","Good","Ideal","Very Good","Ideal","Premium","Good","Fair","Very Good","Ideal","Premium","Good","Fair","Premium","Very Good","Fair","Ideal","Good","Ideal","Premium","Very Good","Fair","Good"],
// "clarity":["SI2","SI2","SI2","SI2","SI2","SI1","SI1","SI1","SI1","SI1","VS1","VS1","VS1","VS1","VS1","VS2","VS2","VS2","VS2","VS2","VVS2","VVS2","VVS2","VVS2","VVS2","VVS1","VVS1","VVS1","VVS1","VVS1","I1","I1","I1","I1","I1","IF","IF","IF","IF","IF"],
// "..count..":[2598.0,1081.0,2949.0,2100.0,466.0,3575.0,3240.0,1560.0,4282.0,408.0,648.0,1775.0,3589.0,1989.0,170.0,3357.0,261.0,2591.0,978.0,5071.0,1235.0,2606.0,870.0,286.0,69.0,789.0,2047.0,616.0,186.0,17.0,205.0,84.0,210.0,146.0,96.0,1212.0,230.0,268.0,9.0,71.0]
// }
// }]
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":0,
// "feature_spec":{
// "ggtitle":{
// "text":"position='fill'"
// },
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"cut",
// "fill":"clarity"
// },
// "stat":"count",
// "position":"fill",
// "geom":"bar",
// "data":{
// "cut":["Ideal","Good","Premium","Very Good","Fair","Premium","Very Good","Good","Ideal","Fair","Good","Very Good","Ideal","Premium","Fair","Premium","Fair","Very Good","Good","Ideal","Very Good","Ideal","Premium","Good","Fair","Very Good","Ideal","Premium","Good","Fair","Premium","Very Good","Fair","Ideal","Good","Ideal","Premium","Very Good","Fair","Good"],
// "clarity":["SI2","SI2","SI2","SI2","SI2","SI1","SI1","SI1","SI1","SI1","VS1","VS1","VS1","VS1","VS1","VS2","VS2","VS2","VS2","VS2","VVS2","VVS2","VVS2","VVS2","VVS2","VVS1","VVS1","VVS1","VVS1","VVS1","I1","I1","I1","I1","I1","IF","IF","IF","IF","IF"],
// "..count..":[2598.0,1081.0,2949.0,2100.0,466.0,3575.0,3240.0,1560.0,4282.0,408.0,648.0,1775.0,3589.0,1989.0,170.0,3357.0,261.0,2591.0,978.0,5071.0,1235.0,2606.0,870.0,286.0,69.0,789.0,2047.0,616.0,186.0,17.0,205.0,84.0,210.0,146.0,96.0,1212.0,230.0,268.0,9.0,71.0]
// }
// }]
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":300,
// "feature_spec":{
// "ggtitle":{
// "text":"'x' and 'fill' alphabetically"
// },
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@cut",
// "fill":"@as_discrete@clarity"
// },
// "stat":"count",
// "position":"fill",
// "geom":"bar",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"cut",
// "order":1
// }
// },{
// "aes":"fill",
// "annotation":"as_discrete",
// "parameters":{
// "label":"clarity",
// "order":1
// }
// }]
// },
// "data":{
// "@as_discrete@cut":["Premium","Very Good","Fair","Ideal","Good","Ideal","Premium","Very Good","Fair","Good","Premium","Very Good","Good","Ideal","Fair","Ideal","Good","Premium","Very Good","Fair","Good","Very Good","Ideal","Premium","Fair","Premium","Fair","Very Good","Good","Ideal","Very Good","Ideal","Premium","Good","Fair","Very Good","Ideal","Premium","Good","Fair"],
// "..count..":[205.0,84.0,210.0,146.0,96.0,1212.0,230.0,268.0,9.0,71.0,3575.0,3240.0,1560.0,4282.0,408.0,2598.0,1081.0,2949.0,2100.0,466.0,648.0,1775.0,3589.0,1989.0,170.0,3357.0,261.0,2591.0,978.0,5071.0,789.0,2047.0,616.0,186.0,17.0,1235.0,2606.0,870.0,286.0,69.0],
// "@as_discrete@clarity":["I1","I1","I1","I1","I1","IF","IF","IF","IF","IF","SI1","SI1","SI1","SI1","SI1","SI2","SI2","SI2","SI2","SI2","VS1","VS1","VS1","VS1","VS1","VS2","VS2","VS2","VS2","VS2","VVS1","VVS1","VVS1","VVS1","VVS1","VVS2","VVS2","VVS2","VVS2","VVS2"]
// }
// }]
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":300,
// "feature_spec":{
// "ggtitle":{
// "text":"'x' order by 'count'"
// },
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@cut",
// "fill":"@as_discrete@clarity"
// },
// "stat":"count",
// "position":"fill",
// "geom":"bar",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"cut",
// "order_by":"..count.."
// }
// },{
// "aes":"fill",
// "annotation":"as_discrete",
// "parameters":{
// "label":"clarity",
// "order":1
// }
// }]
// },
// "data":{
// "@as_discrete@cut":["Premium","Very Good","Fair","Ideal","Good","Ideal","Premium","Very Good","Fair","Good","Premium","Very Good","Good","Ideal","Fair","Ideal","Good","Premium","Very Good","Fair","Good","Very Good","Ideal","Premium","Fair","Premium","Fair","Very Good","Good","Ideal","Very Good","Ideal","Premium","Good","Fair","Very Good","Ideal","Premium","Good","Fair"],
// "..count..":[205.0,84.0,210.0,146.0,96.0,1212.0,230.0,268.0,9.0,71.0,3575.0,3240.0,1560.0,4282.0,408.0,2598.0,1081.0,2949.0,2100.0,466.0,648.0,1775.0,3589.0,1989.0,170.0,3357.0,261.0,2591.0,978.0,5071.0,789.0,2047.0,616.0,186.0,17.0,1235.0,2606.0,870.0,286.0,69.0],
// "@as_discrete@clarity":["I1","I1","I1","I1","I1","IF","IF","IF","IF","IF","SI1","SI1","SI1","SI1","SI1","SI2","SI2","SI2","SI2","SI2","VS1","VS1","VS1","VS1","VS1","VS2","VS2","VS2","VS2","VS2","VVS1","VVS1","VVS1","VVS1","VVS1","VVS2","VVS2","VVS2","VVS2","VVS2"]
// }
// }]
// },
// "height":300
// },{
// "x":0,
// "width":470,
// "y":600,
// "feature_spec":{
// "ggtitle":{
// "text":"position='dodge'"
// },
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"cut",
// "fill":"clarity"
// },
// "stat":"count",
// "position":"dodge",
// "geom":"bar",
// "data":{
// "cut":["Ideal","Good","Premium","Very Good","Fair","Premium","Very Good","Good","Ideal","Fair","Good","Very Good","Ideal","Premium","Fair","Premium","Fair","Very Good","Good","Ideal","Very Good","Ideal","Premium","Good","Fair","Very Good","Ideal","Premium","Good","Fair","Premium","Very Good","Fair","Ideal","Good","Ideal","Premium","Very Good","Fair","Good"],
// "clarity":["SI2","SI2","SI2","SI2","SI2","SI1","SI1","SI1","SI1","SI1","VS1","VS1","VS1","VS1","VS1","VS2","VS2","VS2","VS2","VS2","VVS2","VVS2","VVS2","VVS2","VVS2","VVS1","VVS1","VVS1","VVS1","VVS1","I1","I1","I1","I1","I1","IF","IF","IF","IF","IF"],
// "..count..":[2598.0,1081.0,2949.0,2100.0,466.0,3575.0,3240.0,1560.0,4282.0,408.0,648.0,1775.0,3589.0,1989.0,170.0,3357.0,261.0,2591.0,978.0,5071.0,1235.0,2606.0,870.0,286.0,69.0,789.0,2047.0,616.0,186.0,17.0,205.0,84.0,210.0,146.0,96.0,1212.0,230.0,268.0,9.0,71.0]
// }
// }]
// },
// "height":300
// },{
// "x":470,
// "width":470,
// "y":600,
// "feature_spec":{
// "ggtitle":{
// "text":"'x' order by 'count' and 'fill' - alphabetically"
// },
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"@as_discrete@cut",
// "fill":"@as_discrete@clarity"
// },
// "stat":"count",
// "position":"dodge",
// "geom":"bar",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"x",
// "annotation":"as_discrete",
// "parameters":{
// "label":"cut",
// "order_by":"..count.."
// }
// },{
// "aes":"fill",
// "annotation":"as_discrete",
// "parameters":{
// "label":"clarity",
// "order":1
// }
// }]
// },
// "data":{
// "@as_discrete@cut":["Premium","Very Good","Fair","Ideal","Good","Ideal","Premium","Very Good","Fair","Good","Premium","Very Good","Good","Ideal","Fair","Ideal","Good","Premium","Very Good","Fair","Good","Very Good","Ideal","Premium","Fair","Premium","Fair","Very Good","Good","Ideal","Very Good","Ideal","Premium","Good","Fair","Very Good","Ideal","Premium","Good","Fair"],
// "..count..":[205.0,84.0,210.0,146.0,96.0,1212.0,230.0,268.0,9.0,71.0,3575.0,3240.0,1560.0,4282.0,408.0,2598.0,1081.0,2949.0,2100.0,466.0,648.0,1775.0,3589.0,1989.0,170.0,3357.0,261.0,2591.0,978.0,5071.0,789.0,2047.0,616.0,186.0,17.0,1235.0,2606.0,870.0,286.0,69.0],
// "@as_discrete@clarity":["I1","I1","I1","I1","I1","IF","IF","IF","IF","IF","SI1","SI1","SI1","SI1","SI1","SI2","SI2","SI2","SI2","SI2","VS1","VS1","VS1","VS1","VS1","VS2","VS2","VS2","VS2","VS2","VVS1","VVS1","VVS1","VVS1","VVS1","VVS2","VVS2","VVS2","VVS2","VVS2"]
// }
// }]
// },
// "height":300
// }]
