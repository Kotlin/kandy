// %% [markdown]
// [Replica of the example from lets-plot(click)](https://nbviewer.org/github/JetBrains/lets-plot-kotlin/blob/master/docs/examples/jupyter-notebooks/error_bars.ipynb)

// %%
%useLatestDescriptors
%use ggdsl(0.1.4-dev-6)
// Out:
//             <div id="kotlin_out_0"/>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["DataFrame"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["DataFrame"] = resQueue;
//                 window["call_DataFrame"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/Kotlin/dataframe@d6467c1389bc031958acd5310fce39167b5cc581/src/main/resources/init.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_DataFrame"] = function(f) {f();};
//                         window.kotlinQueues["DataFrame"].forEach(function(f) {f();});
//                         window.kotlinQueues["DataFrame"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_DataFrame"] = function(f) {};
//                         window.kotlinQueues["DataFrame"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource DataFrame';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>
//                 <style>
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"]{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//                 </style>

// %%
val dataset: NamedData = mapOf(
    "supp" to listOf("OJ", "OJ", "OJ", "VC", "VC", "VC"),
    "dose" to listOf(0.5, 1.0, 2.0, 0.5, 1.0, 2.0),
    "length" to listOf(13.23, 22.70, 26.06, 7.98, 16.77, 26.14),
    "len_min" to listOf(11.83, 21.2, 24.50, 4.24, 15.26, 23.35),
    "len_max" to listOf(15.63, 24.9, 27.11, 10.72, 19.28, 28.93)
)

// %%
val supp = source<String>("supp")
val dose = source<Double>("dose")
val length = source<Double>("length")
val lenMin = source<Double>("len_min")
val lenMax = source<Double>("len_max")

// %%
plot(dataset) {
    x(dose)

    errorBar {
        yMin(lenMin)
        yMax(lenMax)

        // todo just line?
        borderLine.color(supp)

        width(.1)
    }

    line {
        y(length)

        color(supp)
    }

    points {
        y(length)

        color(supp)
     }
}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="CV15s2"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// },{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// }],
// "layers":[{
// "mapping":{
// "x":"dose",
// "ymin":"len_min",
// "ymax":"len_max",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "width":0.1,
// "position":"identity",
// "geom":"errorbar"
// },{
// "mapping":{
// "x":"dose",
// "y":"length",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14]
// },
// "position":"identity",
// "geom":"line"
// },{
// "mapping":{
// "x":"dose",
// "y":"length",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14]
// },
// "position":"identity",
// "geom":"point"
// }]
// };
//        var plotContainer = document.getElementById("CV15s2");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>

// %%
val pd = Position.Dodge(0.1)
plot(dataset) {
    x(dose)

    errorBar {
        yMin(lenMin)
        yMax(lenMax)

        borderLine.color(supp)

        width(.1)

        position = pd
    }

    line {
        y(length)

        color(supp)

        position = pd
    }

    points {
        y(length)

        color(supp)

        position = pd
     }
}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="R9ov37"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// },{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// }],
// "layers":[{
// "mapping":{
// "x":"dose",
// "ymin":"len_min",
// "ymax":"len_max",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "width":0.1,
// "position":{
// "name":"dodge",
// "width":0.1,
// "kind":"pos"
// },
// "geom":"errorbar"
// },{
// "mapping":{
// "x":"dose",
// "y":"length",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14]
// },
// "position":{
// "name":"dodge",
// "width":0.1,
// "kind":"pos"
// },
// "geom":"line"
// },{
// "mapping":{
// "x":"dose",
// "y":"length",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14]
// },
// "position":{
// "name":"dodge",
// "width":0.1,
// "kind":"pos"
// },
// "geom":"point"
// }]
// };
//        var plotContainer = document.getElementById("R9ov37");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>

// %%
plot(dataset) {
    x(dose)

    errorBar {
        yMin(lenMin)
        yMax(lenMax)

        borderLine.color(Color.BLACK)

        width(.1)

        position = pd
        group(supp)
    }

    line {
        y(length)

        color(supp)

        position = pd
    }

    points {
        y(length)

        color(supp)
        size(5.0)

        position = pd
     }
}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="6BVznu"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// },{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// }],
// "layers":[{
// "mapping":{
// "x":"dose",
// "ymin":"len_min",
// "ymax":"len_max",
// "group":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "color":"black",
// "width":0.1,
// "position":{
// "name":"dodge",
// "width":0.1,
// "kind":"pos"
// },
// "geom":"errorbar"
// },{
// "mapping":{
// "x":"dose",
// "y":"length",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14]
// },
// "position":{
// "name":"dodge",
// "width":0.1,
// "kind":"pos"
// },
// "geom":"line"
// },{
// "mapping":{
// "x":"dose",
// "y":"length",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14]
// },
// "size":5.0,
// "position":{
// "name":"dodge",
// "width":0.1,
// "kind":"pos"
// },
// "geom":"point"
// }]
// };
//        var plotContainer = document.getElementById("6BVznu");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>

// %%
val customColorScale = categorical<String, Color>(
    rangeValues = listOf(Color.ORANGE, Color.fromName("dark_green"))
)

// %%
plot(dataset) {
    x(dose)

    errorBar {
        yMin(lenMin)
        yMax(lenMax)

        borderLine.color(Color.BLACK)

        width(.1)

        position = pd
        group(supp)
    }

    line {
        y(length)

        color(supp.scaled(customColorScale))

        position = pd
    }

    points {
        y(length)

        symbol(Symbol.CIRCLE_FILLED)
        size(5.0)
        fillColor(Color.WHITE)
        color(supp.scaled(customColorScale))

        position = pd
     }

     layout {
         title = "The Effect of Vitamin C on Tooth Growth in Guinea Pigs" 
         size = 700 to 400
         // TODO Ok?
         xAxisLabel = "Dose (mg)"
         yAxisLabel = "Tooth length (mm)"
         
         theme {
             legend {
                 justification(1.0, 0.0)
                 position(1.0, 0.0)
             }
         }
     }
     
}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="IMAJdq"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"The Effect of Vitamin C on Tooth Growth in Guinea Pigs"
// },
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":700.0,
// "height":400.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// },{
// "aesthetic":"color",
// "values":["orange","dark_green"]
// },{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// },{
// "aesthetic":"color",
// "values":["orange","dark_green"]
// },{
// "aesthetic":"x",
// "name":"Dose (mg)"
// },{
// "aesthetic":"y",
// "name":"Tooth length (mm)"
// }],
// "layers":[{
// "mapping":{
// "x":"dose",
// "ymin":"len_min",
// "ymax":"len_max",
// "group":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "color":"black",
// "width":0.1,
// "position":{
// "name":"dodge",
// "width":0.1,
// "kind":"pos"
// },
// "geom":"errorbar"
// },{
// "mapping":{
// "x":"dose",
// "y":"length",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14]
// },
// "position":{
// "name":"dodge",
// "width":0.1,
// "kind":"pos"
// },
// "geom":"line"
// },{
// "mapping":{
// "x":"dose",
// "y":"length",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14]
// },
// "shape":21.0,
// "size":5.0,
// "position":{
// "name":"dodge",
// "width":0.1,
// "kind":"pos"
// },
// "geom":"point",
// "fill":"white"
// }],
// "theme":{
// "axis_ontop":false,
// "axis_ontop_y":false,
// "axis_ontop_x":false,
// "legend_justification":[1.0,0.0],
// "legend_position":[1.0,0.0]
// }
// };
//        var plotContainer = document.getElementById("IMAJdq");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>

// %%
plot(dataset) {
    x(dose)
    
    bar {
        y(length)

        color(supp.scaled(customColorScale))

        borderLine.color(Color.BLACK)

        position = Position.Dodge()
    }

    errorBar {
        yMin(lenMin)
        yMax(lenMax)

        borderLine.color(Color.BLACK)

        width(.1)

        position = Position.Dodge(0.9)
        group(supp)
    }
    
    
    layout {
         size = 700 to 400
         xAxisLabel = "Dose (mg)"
         yAxisLabel = "Tooth length (mm)"
        
         theme {
             legend {
                 justification(0.0, 1.0)
                 position(0.0, 1.0)
             }
         }
     }
}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="18j2oL"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":700.0,
// "height":400.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// },{
// "aesthetic":"fill",
// "values":["orange","dark_green"]
// },{
// "aesthetic":"x"
// },{
// "aesthetic":"x",
// "name":"Dose (mg)"
// },{
// "aesthetic":"y",
// "name":"Tooth length (mm)"
// }],
// "layers":[{
// "mapping":{
// "x":"dose",
// "y":"length",
// "fill":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14]
// },
// "color":"black",
// "position":"dodge",
// "geom":"bar"
// },{
// "mapping":{
// "x":"dose",
// "ymin":"len_min",
// "ymax":"len_max",
// "group":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "color":"black",
// "width":0.1,
// "position":{
// "name":"dodge",
// "width":0.9,
// "kind":"pos"
// },
// "geom":"errorbar"
// }],
// "theme":{
// "axis_ontop":false,
// "axis_ontop_y":false,
// "axis_ontop_x":false,
// "legend_justification":[0.0,1.0],
// "legend_position":[0.0,1.0]
// }
// };
//        var plotContainer = document.getElementById("18j2oL");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>

// %%
plot(dataset) {
    x(dose)

    crossBar {
        yMin(lenMin)
        yMax(lenMax)
        middle(length)

        fatten(5.0)

        borderLine.color(supp.scaled(customColorScale)) 
        position = Position.Dodge()
     }

     layout {
         size = 700 to 400
         xAxisLabel = "Dose (mg)"
         yAxisLabel = "Tooth length (mm)"
     }
}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="8Bp3Mq"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":700.0,
// "height":400.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"color",
// "values":["orange","dark_green"]
// },{
// "aesthetic":"x",
// "name":"Dose (mg)"
// },{
// "aesthetic":"y",
// "name":"Tooth length (mm)"
// }],
// "layers":[{
// "mapping":{
// "x":"dose",
// "ymin":"len_min",
// "ymax":"len_max",
// "middle":"length",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "position":"dodge",
// "geom":"crossbar",
// "fatten":5.0
// }]
// };
//        var plotContainer = document.getElementById("8Bp3Mq");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>

// %%
plot(dataset) {
    x(dose)

    lineRange {
        yMin(lenMin)
        yMax(lenMax)

        // todo just line?
        borderLine.color(supp.scaled(customColorScale))
        position = pd
    }

    line {
        y(length)
        color(supp.scaled(customColorScale))

        position = pd
    }
    
    layout {
         size = 700 to 400
         xAxisLabel = "Dose (mg)"
         yAxisLabel = "Tooth length (mm)"
     }
}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="Gu7wCJ"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":700.0,
// "height":400.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"color",
// "values":["orange","dark_green"]
// },{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// },{
// "aesthetic":"color",
// "values":["orange","dark_green"]
// },{
// "aesthetic":"x",
// "name":"Dose (mg)"
// },{
// "aesthetic":"y",
// "name":"Tooth length (mm)"
// }],
// "layers":[{
// "mapping":{
// "x":"dose",
// "ymin":"len_min",
// "ymax":"len_max",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "position":{
// "name":"dodge",
// "width":0.1,
// "kind":"pos"
// },
// "geom":"linerange"
// },{
// "mapping":{
// "x":"dose",
// "y":"length",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14]
// },
// "position":{
// "name":"dodge",
// "width":0.1,
// "kind":"pos"
// },
// "geom":"line"
// }]
// };
//        var plotContainer = document.getElementById("Gu7wCJ");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>

// %%
plot(dataset) {
    x(dose)

    pointRange {
        y(length)
        yMin(lenMin)
        yMax(lenMax)

        color(supp.scaled(customColorScale))
        position = pd
    }

    line {
        y(length)
        color(supp.scaled(customColorScale))

        position = pd
    }
    
    layout {
         size = 700 to 400
         xAxisLabel = "Dose (mg)"
         yAxisLabel = "Tooth length (mm)"
     }
}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="L5a3GB"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":700.0,
// "height":400.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// },{
// "aesthetic":"color",
// "values":["orange","dark_green"]
// },{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// },{
// "aesthetic":"color",
// "values":["orange","dark_green"]
// },{
// "aesthetic":"x",
// "name":"Dose (mg)"
// },{
// "aesthetic":"y",
// "name":"Tooth length (mm)"
// }],
// "layers":[{
// "mapping":{
// "x":"dose",
// "y":"length",
// "ymin":"len_min",
// "ymax":"len_max",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "position":{
// "name":"dodge",
// "width":0.1,
// "kind":"pos"
// },
// "geom":"pointrange"
// },{
// "mapping":{
// "x":"dose",
// "y":"length",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14]
// },
// "position":{
// "name":"dodge",
// "width":0.1,
// "kind":"pos"
// },
// "geom":"line"
// }]
// };
//        var plotContainer = document.getElementById("L5a3GB");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>

// %%
plot(dataset) {
    x(dose)

    line {
        y(length)
        color(supp.scaled(customColorScale))

        position = pd
    }

    pointRange {
        y(length)
        yMin(lenMin)
        yMax(lenMax)

        size(5.0)
        
        color(Color.fromRGB(230, 230, 230))
        
        innerPoint {
            fatten(1.0)
            symbol(Symbol.DIAMOND_FILLED)
            fillColor(supp.scaled(customColorScale))
        }
        
        position = pd
    }

    layout {
         size = 700 to 400
         xAxisLabel = "Dose (mg)"
         yAxisLabel = "Tooth length (mm)"
     }
}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="PKbpmo"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":700.0,
// "height":400.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// },{
// "aesthetic":"color",
// "values":["orange","dark_green"]
// },{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// },{
// "aesthetic":"fill",
// "values":["orange","dark_green"]
// },{
// "aesthetic":"x",
// "name":"Dose (mg)"
// },{
// "aesthetic":"y",
// "name":"Tooth length (mm)"
// }],
// "layers":[{
// "mapping":{
// "x":"dose",
// "y":"length",
// "color":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14]
// },
// "position":{
// "name":"dodge",
// "width":0.1,
// "kind":"pos"
// },
// "geom":"line"
// },{
// "mapping":{
// "x":"dose",
// "y":"length",
// "ymin":"len_min",
// "ymax":"len_max",
// "fill":"supp"
// },
// "stat":"identity",
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "size":5.0,
// "color":"#E6E6E6",
// "shape":23.0,
// "position":{
// "name":"dodge",
// "width":0.1,
// "kind":"pos"
// },
// "geom":"pointrange",
// "fatten":1.0
// }]
// };
//        var plotContainer = document.getElementById("PKbpmo");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>

// %% [markdown]
// https://nbviewer.org/github/JetBrains/lets-plot-kotlin/blob/master/docs/examples/jupyter-notebooks/facets.ipynb

// %%
%use dataframe

// %%
val mpgDF = DataFrame.readCSV("https://raw.githubusercontent.com/JetBrains/lets-plot-kotlin/master/docs/examples/data/mpg2.csv")
mpgDF.head(5)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_-1912602624"></table>
//
// <p>DataFrame: rowsCount = 5, columnsCount = 9</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"miles per gallon: java.math.BigDecimal\">miles per gallon</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">18,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">15,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">17,0</span></span>"] },
// { name: "<span title=\"number of cylinders: Int\">number of cylinders</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>"] },
// { name: "<span title=\"engine displacement (cu. inches): java.math.BigDecimal\">engine displacement (cu. inches)</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">307,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">350,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">318,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">304,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">302,0</span></span>"] },
// { name: "<span title=\"engine horsepower: Int\">engine horsepower</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">130</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">165</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">150</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">150</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">140</span></span>"] },
// { name: "<span title=\"vehicle weight (lbs.): Int\">vehicle weight (lbs.)</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">3504</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3693</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3436</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3433</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3449</span></span>"] },
// { name: "<span title=\"time to accelerate (sec.): java.math.BigDecimal\">time to accelerate (sec.)</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">12,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">11,5</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">11,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">12,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10,5</span></span>"] },
// { name: "<span title=\"model year: Int\">model year</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">70</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">70</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">70</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">70</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">70</span></span>"] },
// { name: "<span title=\"origin of car: String\">origin of car</span>", children: [], rightAlign: false, values: ["US","US","US","US","US"] },
// { name: "<span title=\"vehicle name: String\">vehicle name</span>", children: [], rightAlign: false, values: ["chevrolet chevelle malibu","buick skylark 320","plymouth satellite","amc rebel sst","ford torino"] },
// ], id: -1912602624, rootId: -1912602624, totalRows: 5 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-1912602624) });
//
//
//         </script>
//         </html>

// %%
mpgDF.schema()
// Out:
// miles per gallon: java.math.BigDecimal
// number of cylinders: Int
// engine displacement (cu. inches): java.math.BigDecimal
// engine horsepower: Int
// vehicle weight (lbs.): Int
// time to accelerate (sec.): java.math.BigDecimal
// model year: Int
// origin of car: String
// vehicle name: String

// %%
val datasetMpg = mpgDF.toNamedData()
val mpg = source<Double>("miles per gallon")
val ehp = source<Int>("engine horsepower")
val origin = source<String>("origin of car")
val noc = source<Int>("number of cylinders")

// %%
plot(datasetMpg) {
    x(ehp)
    y(mpg)
    points { color(origin) }
}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="CJzpRV"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// }],
// "layers":[{
// "mapping":{
// "x":"engine horsepower",
// "y":"miles per gallon",
// "color":"origin of car"
// },
// "stat":"identity",
// "data":{
// "engine horsepower":[130.0,165.0,150.0,150.0,140.0,198.0,220.0,215.0,225.0,190.0,170.0,160.0,150.0,225.0,95.0,95.0,97.0,85.0,88.0,46.0,87.0,90.0,95.0,113.0,90.0,215.0,200.0,210.0,193.0,88.0,90.0,95.0,100.0,105.0,100.0,88.0,100.0,165.0,175.0,153.0,150.0,180.0,170.0,175.0,110.0,72.0,100.0,88.0,86.0,90.0,70.0,76.0,65.0,69.0,60.0,70.0,95.0,80.0,54.0,90.0,86.0,165.0,175.0,150.0,153.0,150.0,208.0,155.0,160.0,190.0,97.0,150.0,130.0,140.0,150.0,112.0,76.0,87.0,69.0,86.0,92.0,97.0,80.0,88.0,175.0,150.0,145.0,137.0,150.0,198.0,150.0,158.0,150.0,215.0,225.0,175.0,105.0,100.0,100.0,88.0,95.0,46.0,150.0,167.0,170.0,180.0,100.0,88.0,72.0,94.0,90.0,85.0,107.0,90.0,145.0,230.0,49.0,75.0,91.0,112.0,150.0,110.0,122.0,180.0,95.0,100.0,100.0,67.0,80.0,65.0,75.0,100.0,110.0,105.0,140.0,150.0,150.0,140.0,150.0,83.0,67.0,78.0,52.0,61.0,75.0,75.0,75.0,97.0,93.0,67.0,95.0,105.0,72.0,72.0,170.0,145.0,150.0,148.0,110.0,105.0,110.0,95.0,110.0,110.0,129.0,75.0,83.0,100.0,78.0,96.0,71.0,97.0,97.0,70.0,90.0,95.0,88.0,98.0,115.0,53.0,86.0,81.0,92.0,79.0,83.0,140.0,150.0,120.0,152.0,100.0,105.0,81.0,90.0,52.0,60.0,70.0,53.0,100.0,78.0,110.0,95.0,71.0,70.0,75.0,72.0,102.0,150.0,88.0,108.0,120.0,180.0,145.0,130.0,150.0,68.0,80.0,58.0,96.0,70.0,145.0,110.0,145.0,130.0,110.0,105.0,100.0,98.0,180.0,170.0,190.0,149.0,78.0,88.0,75.
// },
// "position":"identity",
// "geom":"point"
// }]
// };
//        var plotContainer = document.getElementById("CJzpRV");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>

// %%
plot(datasetMpg) {
    x(ehp)
    y(mpg)
    points { color(origin) }

    facetGrid(noc)
}
// Out:
// Line_23.jupyter-kts (6:5 - 14) Overload resolution ambiguity:
// public fun PlotContext.facetGrid(x: DataSource<*>? = ..., y: ColumnReference<*>? = ..., scalesSharing: ScalesSharing? = ..., xOrder: OrderDirection = ..., yOrder: OrderDirection = ..., xFormat: String? = ..., yFormat: String? = ...): Unit defined in org.jetbrains.kotlinx.ggdsl.dataframe.letsplot
// public fun PlotContext.facetGrid(x: DataSource<*>? = ..., y: DataSource<*>? = ..., scalesSharing: ScalesSharing? = ..., xOrder: OrderDirection = ..., yOrder: OrderDirection = ..., xFormat: String? = ..., yFormat: String? = ...): Unit defined in org.jetbrains.kotlinx.ggdsl.letsplot.facet

// %%
plot(datasetMpg) {
    x(ehp)
    y(mpg)
    points { color(origin) }

    facetGrid ( 
        x = noc ,
        y = origin
    )
}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="DAUbxq"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x"
// },{
// "aesthetic":"y"
// }],
// "layers":[{
// "mapping":{
// "x":"engine horsepower",
// "y":"miles per gallon",
// "color":"origin of car"
// },
// "stat":"identity",
// "data":{
// "engine horsepower":[130.0,165.0,150.0,150.0,140.0,198.0,220.0,215.0,225.0,190.0,170.0,160.0,150.0,225.0,95.0,95.0,97.0,85.0,88.0,46.0,87.0,90.0,95.0,113.0,90.0,215.0,200.0,210.0,193.0,88.0,90.0,95.0,100.0,105.0,100.0,88.0,100.0,165.0,175.0,153.0,150.0,180.0,170.0,175.0,110.0,72.0,100.0,88.0,86.0,90.0,70.0,76.0,65.0,69.0,60.0,70.0,95.0,80.0,54.0,90.0,86.0,165.0,175.0,150.0,153.0,150.0,208.0,155.0,160.0,190.0,97.0,150.0,130.0,140.0,150.0,112.0,76.0,87.0,69.0,86.0,92.0,97.0,80.0,88.0,175.0,150.0,145.0,137.0,150.0,198.0,150.0,158.0,150.0,215.0,225.0,175.0,105.0,100.0,100.0,88.0,95.0,46.0,150.0,167.0,170.0,180.0,100.0,88.0,72.0,94.0,90.0,85.0,107.0,90.0,145.0,230.0,49.0,75.0,91.0,112.0,150.0,110.0,122.0,180.0,95.0,100.0,100.0,67.0,80.0,65.0,75.0,100.0,110.0,105.0,140.0,150.0,150.0,140.0,150.0,83.0,67.0,78.0,52.0,61.0,75.0,75.0,75.0,97.0,93.0,67.0,95.0,105.0,72.0,72.0,170.0,145.0,150.0,148.0,110.0,105.0,110.0,95.0,110.0,110.0,129.0,75.0,83.0,100.0,78.0,96.0,71.0,97.0,97.0,70.0,90.0,95.0,88.0,98.0,115.0,53.0,86.0,81.0,92.0,79.0,83.0,140.0,150.0,120.0,152.0,100.0,105.0,81.0,90.0,52.
28.0,26.4,24.3,19.1,34.3,29.8,31.3,37.0,32.2,46.6,27.9,40.8,44.3,43.4,36.4,30.0,44.6,33.8,29.8,32.7,23.7,35.0,32.4,27.2,26.6,25.8,23.5,30.0,39.1,39.0,35.1,32.3,37.0,37.7,34.1,34.7,34.4,29.9,33.0,33.7,32.4,32.9,31.6,28.1,30.7,25.4,24.2,22.4,26.6,20.2,17.6,28.0,27.0,34.0,31.0,29.0,27.0,24.0,36.0,37.0,31.0,38.0,36.0,36.0,36.0,34.0,38.0,32.0,38.0,25.0,38.0,26.0,22.0,32.0,36.0,27.0,27.0,44.0,32.0,28.0,31.0],
// "number of cylinders":[8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,4.0,6.0,6.0,6.0,4.0,4.0,4.0,4.0,4.0,4.0,6.0,8.0,8.0,8.0,8.0,4.0,4.0,4.0,6.0,6.0,6.0,6.0,6.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,6.0,4.0,6.0,6.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,3.0,8.0,8.0,8.0,8.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,8.0,6.0,6.0,6.0,6.0,6.0,4.0,8.0,8.0,8.0,8.0,6.0,4.0,4.0,4.0,3.0,4.0,6.0,4.0,8.0,8.0,4.0,4.0,4.0,4.0,8.0,4.0,6.0,8.0,6.0,6.0,6.0,4.0,4.0,4.0,4.0,6.0,6.0,6.0,8.0,8.0,8.0,8.0,8.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,6.0,6.0,6.0,6.0,8.0,8.0,8.0,8.0,6.0,6.0,6.0,6.0,6.0,8.0,8.0,4.0,4.0,6.0,4.0,4.0,4.0,4.0,6.0,4.0,6.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,8.0,8.0,8.0,8.0,6.0,6.0,6.0,6.0,4.0,4.0,4.0,4.0,6.0,6.0,6.0,6.0,4.0,4.0,4.0,4.0,4.0,8.0,4.0,6.0,6.0,8.0,8.0,8.0,8.0,4.0,4.0,4.0,4.0,4.0,8.0,8.0,8.0,8.0,6.0,6.0,6.0,6.

// %% [markdown]
// EXAMPLE WITH MPG

// %%
val mpgDF = DataFrame.readCSV("https://raw.githubusercontent.com/JetBrains/lets-plot-kotlin/master/docs/examples/data/mpg2.csv")
mpgDF.head(5)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//
//
//             </style>
//         </head>
//         <body>
//             <table class="dataframe" id="df_-1912602623"></table>
//
// <p>DataFrame: rowsCount = 5, columnsCount = 9</p>
//         </body>
//         <script>
//             /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"miles per gallon: java.math.BigDecimal\">miles per gallon</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">18,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">15,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">17,0</span></span>"] },
// { name: "<span title=\"number of cylinders: Int\">number of cylinders</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>"] },
// { name: "<span title=\"engine displacement (cu. inches): java.math.BigDecimal\">engine displacement (cu. inches)</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">307,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">350,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">318,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">304,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">302,0</span></span>"] },
// { name: "<span title=\"engine horsepower: Int\">engine horsepower</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">130</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">165</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">150</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">150</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">140</span></span>"] },
// { name: "<span title=\"vehicle weight (lbs.): Int\">vehicle weight (lbs.)</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">3504</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3693</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3436</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3433</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3449</span></span>"] },
// { name: "<span title=\"time to accelerate (sec.): java.math.BigDecimal\">time to accelerate (sec.)</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">12,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">11,5</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">11,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">12,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10,5</span></span>"] },
// { name: "<span title=\"model year: Int\">model year</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">70</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">70</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">70</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">70</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">70</span></span>"] },
// { name: "<span title=\"origin of car: String\">origin of car</span>", children: [], rightAlign: false, values: ["US","US","US","US","US"] },
// { name: "<span title=\"vehicle name: String\">vehicle name</span>", children: [], rightAlign: false, values: ["chevrolet chevelle malibu","buick skylark 320","plymouth satellite","amc rebel sst","ford torino"] },
// ], id: -1912602623, rootId: -1912602623, totalRows: 5 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-1912602623) });
//
//
//         </script>
//         </html>

// %%
mpgDF.create {plot { 
    x(`miles per gallon`.scaled(
        continuousPos(limits = 10.0 to 40.0)
    ))
    y(`engine horsepower`)
    points { 
       
        symbol(Symbol.DIAMOND_FILLED)
        fillColor(`origin of car`.scaled())
        color(Color.fromRGB(0, 0, 0))
         
        size(`number of cylinders`)
    }
   
    layout {
        size = 1000 to 600
        title = "Fuel consumption"
    }
}}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2